# %% [markdown]
# Atreish Ramlakhan<br> Aishwarya Singh<br> Nosson Weissman<br>
# April 22, 2021
# AIM 5001, Prof. James Topor  <br>
#
# # AIM 5001 Module 13
# ## PostgreSQL to MongoDB Data Migration
#
#
# *The task for the Module 13 Assignment is to migrate the content of a PostgreSQL database to MongoDB via
# Python, and then retrieve the data from MongoDB and load it into Pandas dataframes that conform to the
# format of the original PostgreSQL database tables. Specifically, you will use Python to retrieve the entire
# content of the Customer and Invoice tables from the Chinook database we’ve worked within in Modules 1 & 2
# from your PostgreSQL server, and then subsequently load that data into MongoDB. The manner in which you
# choose to store and manage the Chinook data within MongoDB is up to you as an SQL and NoSQL practitioner
# to decide.
# Then, using Python and your MongoDB data retrieval expertise, you will retrieve the required Chinook data
# from MongoDB and create and populate a pair of new Pandas dataframes, one for each of the original
# Chinook Customer and Invoice database tables. When finished with this process, your new Pandas dataframes
# should mirror the structure of the SQL tables contained within your PostgreSQL Chinook database.*

# %% [markdown]
# 1) Introduction (5 Points): Summarize the problem + explain the steps you plan to take to address the problem. <br>
# **Our goal is to migrate some tables from a Postgres database to a Mongo database while maintaining a similar structure.<br>
# We shall start by reviewing the structure of the orginal tables we intend to migrate.<br>
# We will use pandas to convert the tables to dataframes and ensure dataypes are valid types for a Mongo database.**

# %% [markdown]
# 2) PostgreSQL to MongoDB Migration (55 Points): Describe + show the steps you have taken to use
# Python to retrieve the Chinook data from your PostgreSQL server and subsequently load that data into
# MongoDB. This section should include any Python code used as well as an appropriate explanatory
# narrative that explains how you have formatted the Chinook data for storage within MongoDB.

# %%
# Install pymongo
# !pip install pymongo

# %%
#first import libraries
import pymongo
from pymongo import MongoClient
import psycopg2 as pg
import pandas as pd, numpy as np

# %% [markdown]
# ### Access SQL Database, Import Tables

# %%
import os
#here we retirive the databse password which is stored as an environment variable
#best practice not to save passwords as plaintext in notebooks
#(we can also create env variables for port, database, user, and sslmode)
password = os.getenv('POSTGRES_PASSWORD')

# %%
conn = pg.connect(
    host="localhost",
    port="5433",
    database= database_name,
    user="postgres",
    password=password,
    sslmode="disable")
query = """SELECT * FROM "Customer" """ 
customer = pd.read_sql_query(query, conn)
query = """SELECT * FROM "Invoice" """ 
invoice = pd.read_sql_query(query, conn)

# %% [markdown]
# ### Access Mongo Server, Create New Database

# %%
client = MongoClient('localhost', 27017)
# client = MongoClient('mongodb://localhost:27017/')
db = client.test_database
# db = client['test-database']

# %%
database_name = 'chinook'
db = client[database_name]

# %%
client.list_database_names()
# Out:
# ['admin', 'chinook', 'config', 'local', 'test_database']

# %%
# table_df = customer
# documents = []
# for i in table_df.index:
#      documents.append(customer.iloc[i].to_dict())
# collection = customers
# collection.insert_many(documents)
# customers
# cols = customer.columns
# first_row = customer.iloc[0]
# for col in cols:
#     if type(first_row[col]) == np.int64:
#         print(type(np.long(first_row[col])))
##InvalidDocument: cannot encode object: 1, of type: <class 'numpy.int64'>

# %%
#create a function to convert dataframe to collection
def table_df_to_mongo_collection(table_df):
    docs = []
    df_cols = [s for s in table_df.columns]
    for i in table_df.index:
        doc = {}
        for col in df_cols:
            #Mongo does not recognize np.int64
            #here we convert to n.long which is a valid type for Mongo
            #ideally, we should create a dict with numpy types 
            #which aren't recogniable in Mongo and their Mongo equivalent
            if type(table_df.iloc[i][col]) == np.int64:
                doc[col] = np.long(table_df.iloc[i][col])
            else:
                doc[col] = table_df.iloc[i][col]
        docs.append(doc)
    return docs

# %%
def convert_and_insert_df_as_collection(db, table_df, new_collection_name):
    if not (db and table_df and new_collection_name):
        raise Exception('''One of the parameters you've entered are of type None''')
    collection = db[new_collection_name]
    docs = table_df_to_mongo_collection(table_df)
    collection.insert_many(docs)
    
customers = db.invoices
customers.drop()
invoices = db.invoices
invoices.drop()
convert_and_insert_df_as_collection(db, customer, 'customers')
convert_and_insert_df_as_collection(db, invoice, 'invoices')
# [s for s in invoice.columns]

# %%
print('heyyy \U0001F923 \N{winking face}\N{snake}')
# Out:
# heyyy 🤣 😉🐍

# %%
client.list_database_names()
# Out:
# ['admin', 'chinook', 'config', 'local', 'test_database']

# %%
db = client.chinook

# %%
db.list_collection_names()
# Out:
# ['invoices', 'customers']

# %%
# customers = db.invoices
# customers.drop()
[s for s in db['invoices'].find()]
# Out:
# [{'_id': ObjectId('6081e178d46ebf23e5ecf24b'),
#   'InvoiceId': 1,
#   'CustomerId': 2,
#   'InvoiceDate': datetime.datetime(2009, 1, 1, 0, 0),
#   'BillingAddress': 'Theodor-Heuss-Straße 34',
#   'BillingCity': 'Stuttgart',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '70174',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf24c'),
#   'InvoiceId': 2,
#   'CustomerId': 4,
#   'InvoiceDate': datetime.datetime(2009, 1, 2, 0, 0),
#   'BillingAddress': 'Ullevålsveien 14',
#   'BillingCity': 'Oslo',
#   'BillingState': None,
#   'BillingCountry': 'Norway',
#   'BillingPostalCode': '0171',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf24d'),
#   'InvoiceId': 3,
#   'CustomerId': 8,
#   'InvoiceDate': datetime.datetime(2009, 1, 3, 0, 0),
#   'BillingAddress': 'Grétrystraat 63',
#   'BillingCity': 'Brussels',
#   'BillingState': None,
#   'BillingCountry': 'Belgium',
#   'BillingPostalCode': '1000',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf24e'),
#   'InvoiceId': 4,
#   'CustomerId': 14,
#   'InvoiceDate': datetime.datetime(2009, 1, 6, 0, 0),
#   'BillingAddress': '8210 111 ST NW',
#   'BillingCity': 'Edmonton',
#   'BillingState': 'AB',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'T6G 2C7',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf24f'),
#   'InvoiceId': 5,
#   'CustomerId': 23,
#   'InvoiceDate': datetime.datetime(2009, 1, 11, 0, 0),
#   'BillingAddress': '69 Salem Street',
#   'BillingCity': 'Boston',
#   'BillingState': 'MA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '2113',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf250'),
#   'InvoiceId': 6,
#   'CustomerId': 37,
#   'InvoiceDate': datetime.datetime(2009, 1, 19, 0, 0),
#   'BillingAddress': 'Berger Straße 10',
#   'BillingCity': 'Frankfurt',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '60316',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf251'),
#   'InvoiceId': 7,
#   'CustomerId': 38,
#   'InvoiceDate': datetime.datetime(2009, 2, 1, 0, 0),
#   'BillingAddress': 'Barbarossastraße 19',
#   'BillingCity': 'Berlin',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '10779',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf252'),
#   'InvoiceId': 8,
#   'CustomerId': 40,
#   'InvoiceDate': datetime.datetime(2009, 2, 1, 0, 0),
#   'BillingAddress': '8, Rue Hanovre',
#   'BillingCity': 'Paris',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '75002',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf253'),
#   'InvoiceId': 9,
#   'CustomerId': 42,
#   'InvoiceDate': datetime.datetime(2009, 2, 2, 0, 0),
#   'BillingAddress': '9, Place Louis Barthou',
#   'BillingCity': 'Bordeaux',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '33000',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf254'),
#   'InvoiceId': 10,
#   'CustomerId': 46,
#   'InvoiceDate': datetime.datetime(2009, 2, 3, 0, 0),
#   'BillingAddress': '3 Chatham Street',
#   'BillingCity': 'Dublin',
#   'BillingState': 'Dublin',
#   'BillingCountry': 'Ireland',
#   'BillingPostalCode': None,
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf255'),
#   'InvoiceId': 11,
#   'CustomerId': 52,
#   'InvoiceDate': datetime.datetime(2009, 2, 6, 0, 0),
#   'BillingAddress': '202 Hoxton Street',
#   'BillingCity': 'London',
#   'BillingState': None,
#   'BillingCountry': 'United Kingdom',
#   'BillingPostalCode': 'N1 5LH',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf256'),
#   'InvoiceId': 12,
#   'CustomerId': 2,
#   'InvoiceDate': datetime.datetime(2009, 2, 11, 0, 0),
#   'BillingAddress': 'Theodor-Heuss-Straße 34',
#   'BillingCity': 'Stuttgart',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '70174',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf257'),
#   'InvoiceId': 13,
#   'CustomerId': 16,
#   'InvoiceDate': datetime.datetime(2009, 2, 19, 0, 0),
#   'BillingAddress': '1600 Amphitheatre Parkway',
#   'BillingCity': 'Mountain View',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '94043-1351',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf258'),
#   'InvoiceId': 14,
#   'CustomerId': 17,
#   'InvoiceDate': datetime.datetime(2009, 3, 4, 0, 0),
#   'BillingAddress': '1 Microsoft Way',
#   'BillingCity': 'Redmond',
#   'BillingState': 'WA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '98052-8300',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf259'),
#   'InvoiceId': 15,
#   'CustomerId': 19,
#   'InvoiceDate': datetime.datetime(2009, 3, 4, 0, 0),
#   'BillingAddress': '1 Infinite Loop',
#   'BillingCity': 'Cupertino',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '95014',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf25a'),
#   'InvoiceId': 16,
#   'CustomerId': 21,
#   'InvoiceDate': datetime.datetime(2009, 3, 5, 0, 0),
#   'BillingAddress': '801 W 4th Street',
#   'BillingCity': 'Reno',
#   'BillingState': 'NV',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '89503',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf25b'),
#   'InvoiceId': 17,
#   'CustomerId': 25,
#   'InvoiceDate': datetime.datetime(2009, 3, 6, 0, 0),
#   'BillingAddress': '319 N. Frances Street',
#   'BillingCity': 'Madison',
#   'BillingState': 'WI',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '53703',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf25c'),
#   'InvoiceId': 18,
#   'CustomerId': 31,
#   'InvoiceDate': datetime.datetime(2009, 3, 9, 0, 0),
#   'BillingAddress': '194A Chain Lake Drive',
#   'BillingCity': 'Halifax',
#   'BillingState': 'NS',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'B3S 1C5',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf25d'),
#   'InvoiceId': 19,
#   'CustomerId': 40,
#   'InvoiceDate': datetime.datetime(2009, 3, 14, 0, 0),
#   'BillingAddress': '8, Rue Hanovre',
#   'BillingCity': 'Paris',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '75002',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf25e'),
#   'InvoiceId': 20,
#   'CustomerId': 54,
#   'InvoiceDate': datetime.datetime(2009, 3, 22, 0, 0),
#   'BillingAddress': '110 Raeburn Pl',
#   'BillingCity': 'Edinburgh',
#   'BillingState': None,
#   'BillingCountry': 'United Kingdom',
#   'BillingPostalCode': 'EH4 1HH',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf25f'),
#   'InvoiceId': 21,
#   'CustomerId': 55,
#   'InvoiceDate': datetime.datetime(2009, 4, 4, 0, 0),
#   'BillingAddress': '421 Bourke Street',
#   'BillingCity': 'Sidney',
#   'BillingState': 'NSW',
#   'BillingCountry': 'Australia',
#   'BillingPostalCode': '2010',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf260'),
#   'InvoiceId': 22,
#   'CustomerId': 57,
#   'InvoiceDate': datetime.datetime(2009, 4, 4, 0, 0),
#   'BillingAddress': 'Calle Lira, 198',
#   'BillingCity': 'Santiago',
#   'BillingState': None,
#   'BillingCountry': 'Chile',
#   'BillingPostalCode': None,
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf261'),
#   'InvoiceId': 23,
#   'CustomerId': 59,
#   'InvoiceDate': datetime.datetime(2009, 4, 5, 0, 0),
#   'BillingAddress': '3,Raj Bhavan Road',
#   'BillingCity': 'Bangalore',
#   'BillingState': None,
#   'BillingCountry': 'India',
#   'BillingPostalCode': '560001',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf262'),
#   'InvoiceId': 24,
#   'CustomerId': 4,
#   'InvoiceDate': datetime.datetime(2009, 4, 6, 0, 0),
#   'BillingAddress': 'Ullevålsveien 14',
#   'BillingCity': 'Oslo',
#   'BillingState': None,
#   'BillingCountry': 'Norway',
#   'BillingPostalCode': '0171',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf263'),
#   'InvoiceId': 25,
#   'CustomerId': 10,
#   'InvoiceDate': datetime.datetime(2009, 4, 9, 0, 0),
#   'BillingAddress': 'Rua Dr. Falcão Filho, 155',
#   'BillingCity': 'São Paulo',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '01007-010',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf264'),
#   'InvoiceId': 26,
#   'CustomerId': 19,
#   'InvoiceDate': datetime.datetime(2009, 4, 14, 0, 0),
#   'BillingAddress': '1 Infinite Loop',
#   'BillingCity': 'Cupertino',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '95014',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf265'),
#   'InvoiceId': 27,
#   'CustomerId': 33,
#   'InvoiceDate': datetime.datetime(2009, 4, 22, 0, 0),
#   'BillingAddress': '5112 48 Street',
#   'BillingCity': 'Yellowknife',
#   'BillingState': 'NT',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'X1A 1N6',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf266'),
#   'InvoiceId': 28,
#   'CustomerId': 34,
#   'InvoiceDate': datetime.datetime(2009, 5, 5, 0, 0),
#   'BillingAddress': 'Rua da Assunção 53',
#   'BillingCity': 'Lisbon',
#   'BillingState': None,
#   'BillingCountry': 'Portugal',
#   'BillingPostalCode': None,
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf267'),
#   'InvoiceId': 29,
#   'CustomerId': 36,
#   'InvoiceDate': datetime.datetime(2009, 5, 5, 0, 0),
#   'BillingAddress': 'Tauentzienstraße 8',
#   'BillingCity': 'Berlin',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '10789',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf268'),
#   'InvoiceId': 30,
#   'CustomerId': 38,
#   'InvoiceDate': datetime.datetime(2009, 5, 6, 0, 0),
#   'BillingAddress': 'Barbarossastraße 19',
#   'BillingCity': 'Berlin',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '10779',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf269'),
#   'InvoiceId': 31,
#   'CustomerId': 42,
#   'InvoiceDate': datetime.datetime(2009, 5, 7, 0, 0),
#   'BillingAddress': '9, Place Louis Barthou',
#   'BillingCity': 'Bordeaux',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '33000',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf26a'),
#   'InvoiceId': 32,
#   'CustomerId': 48,
#   'InvoiceDate': datetime.datetime(2009, 5, 10, 0, 0),
#   'BillingAddress': 'Lijnbaansgracht 120bg',
#   'BillingCity': 'Amsterdam',
#   'BillingState': 'VV',
#   'BillingCountry': 'Netherlands',
#   'BillingPostalCode': '1016',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf26b'),
#   'InvoiceId': 33,
#   'CustomerId': 57,
#   'InvoiceDate': datetime.datetime(2009, 5, 15, 0, 0),
#   'BillingAddress': 'Calle Lira, 198',
#   'BillingCity': 'Santiago',
#   'BillingState': None,
#   'BillingCountry': 'Chile',
#   'BillingPostalCode': None,
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf26c'),
#   'InvoiceId': 34,
#   'CustomerId': 12,
#   'InvoiceDate': datetime.datetime(2009, 5, 23, 0, 0),
#   'BillingAddress': 'Praça Pio X, 119',
#   'BillingCity': 'Rio de Janeiro',
#   'BillingState': 'RJ',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '20040-020',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf26d'),
#   'InvoiceId': 35,
#   'CustomerId': 13,
#   'InvoiceDate': datetime.datetime(2009, 6, 5, 0, 0),
#   'BillingAddress': 'Qe 7 Bloco G',
#   'BillingCity': 'Brasília',
#   'BillingState': 'DF',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '71020-677',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf26e'),
#   'InvoiceId': 36,
#   'CustomerId': 15,
#   'InvoiceDate': datetime.datetime(2009, 6, 5, 0, 0),
#   'BillingAddress': '700 W Pender Street',
#   'BillingCity': 'Vancouver',
#   'BillingState': 'BC',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'V6C 1G8',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf26f'),
#   'InvoiceId': 37,
#   'CustomerId': 17,
#   'InvoiceDate': datetime.datetime(2009, 6, 6, 0, 0),
#   'BillingAddress': '1 Microsoft Way',
#   'BillingCity': 'Redmond',
#   'BillingState': 'WA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '98052-8300',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf270'),
#   'InvoiceId': 38,
#   'CustomerId': 21,
#   'InvoiceDate': datetime.datetime(2009, 6, 7, 0, 0),
#   'BillingAddress': '801 W 4th Street',
#   'BillingCity': 'Reno',
#   'BillingState': 'NV',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '89503',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf271'),
#   'InvoiceId': 39,
#   'CustomerId': 27,
#   'InvoiceDate': datetime.datetime(2009, 6, 10, 0, 0),
#   'BillingAddress': '1033 N Park Ave',
#   'BillingCity': 'Tucson',
#   'BillingState': 'AZ',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '85719',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf272'),
#   'InvoiceId': 40,
#   'CustomerId': 36,
#   'InvoiceDate': datetime.datetime(2009, 6, 15, 0, 0),
#   'BillingAddress': 'Tauentzienstraße 8',
#   'BillingCity': 'Berlin',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '10789',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf273'),
#   'InvoiceId': 41,
#   'CustomerId': 50,
#   'InvoiceDate': datetime.datetime(2009, 6, 23, 0, 0),
#   'BillingAddress': 'C/ San Bernardo 85',
#   'BillingCity': 'Madrid',
#   'BillingState': None,
#   'BillingCountry': 'Spain',
#   'BillingPostalCode': '28015',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf274'),
#   'InvoiceId': 42,
#   'CustomerId': 51,
#   'InvoiceDate': datetime.datetime(2009, 7, 6, 0, 0),
#   'BillingAddress': 'Celsiusg. 9',
#   'BillingCity': 'Stockholm',
#   'BillingState': None,
#   'BillingCountry': 'Sweden',
#   'BillingPostalCode': '11230',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf275'),
#   'InvoiceId': 43,
#   'CustomerId': 53,
#   'InvoiceDate': datetime.datetime(2009, 7, 6, 0, 0),
#   'BillingAddress': '113 Lupus St',
#   'BillingCity': 'London',
#   'BillingState': None,
#   'BillingCountry': 'United Kingdom',
#   'BillingPostalCode': 'SW1V 3EN',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf276'),
#   'InvoiceId': 44,
#   'CustomerId': 55,
#   'InvoiceDate': datetime.datetime(2009, 7, 7, 0, 0),
#   'BillingAddress': '421 Bourke Street',
#   'BillingCity': 'Sidney',
#   'BillingState': 'NSW',
#   'BillingCountry': 'Australia',
#   'BillingPostalCode': '2010',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf277'),
#   'InvoiceId': 45,
#   'CustomerId': 59,
#   'InvoiceDate': datetime.datetime(2009, 7, 8, 0, 0),
#   'BillingAddress': '3,Raj Bhavan Road',
#   'BillingCity': 'Bangalore',
#   'BillingState': None,
#   'BillingCountry': 'India',
#   'BillingPostalCode': '560001',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf278'),
#   'InvoiceId': 46,
#   'CustomerId': 6,
#   'InvoiceDate': datetime.datetime(2009, 7, 11, 0, 0),
#   'BillingAddress': 'Rilská 3174/6',
#   'BillingCity': 'Prague',
#   'BillingState': None,
#   'BillingCountry': 'Czech Republic',
#   'BillingPostalCode': '14300',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf279'),
#   'InvoiceId': 47,
#   'CustomerId': 15,
#   'InvoiceDate': datetime.datetime(2009, 7, 16, 0, 0),
#   'BillingAddress': '700 W Pender Street',
#   'BillingCity': 'Vancouver',
#   'BillingState': 'BC',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'V6C 1G8',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf27a'),
#   'InvoiceId': 48,
#   'CustomerId': 29,
#   'InvoiceDate': datetime.datetime(2009, 7, 24, 0, 0),
#   'BillingAddress': '796 Dundas Street West',
#   'BillingCity': 'Toronto',
#   'BillingState': 'ON',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'M6J 1V1',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf27b'),
#   'InvoiceId': 49,
#   'CustomerId': 30,
#   'InvoiceDate': datetime.datetime(2009, 8, 6, 0, 0),
#   'BillingAddress': '230 Elgin Street',
#   'BillingCity': 'Ottawa',
#   'BillingState': 'ON',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'K2P 1L7',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf27c'),
#   'InvoiceId': 50,
#   'CustomerId': 32,
#   'InvoiceDate': datetime.datetime(2009, 8, 6, 0, 0),
#   'BillingAddress': '696 Osborne Street',
#   'BillingCity': 'Winnipeg',
#   'BillingState': 'MB',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'R3L 2B9',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf27d'),
#   'InvoiceId': 51,
#   'CustomerId': 34,
#   'InvoiceDate': datetime.datetime(2009, 8, 7, 0, 0),
#   'BillingAddress': 'Rua da Assunção 53',
#   'BillingCity': 'Lisbon',
#   'BillingState': None,
#   'BillingCountry': 'Portugal',
#   'BillingPostalCode': None,
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf27e'),
#   'InvoiceId': 52,
#   'CustomerId': 38,
#   'InvoiceDate': datetime.datetime(2009, 8, 8, 0, 0),
#   'BillingAddress': 'Barbarossastraße 19',
#   'BillingCity': 'Berlin',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '10779',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf27f'),
#   'InvoiceId': 53,
#   'CustomerId': 44,
#   'InvoiceDate': datetime.datetime(2009, 8, 11, 0, 0),
#   'BillingAddress': 'Porthaninkatu 9',
#   'BillingCity': 'Helsinki',
#   'BillingState': None,
#   'BillingCountry': 'Finland',
#   'BillingPostalCode': '00530',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf280'),
#   'InvoiceId': 54,
#   'CustomerId': 53,
#   'InvoiceDate': datetime.datetime(2009, 8, 16, 0, 0),
#   'BillingAddress': '113 Lupus St',
#   'BillingCity': 'London',
#   'BillingState': None,
#   'BillingCountry': 'United Kingdom',
#   'BillingPostalCode': 'SW1V 3EN',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf281'),
#   'InvoiceId': 55,
#   'CustomerId': 8,
#   'InvoiceDate': datetime.datetime(2009, 8, 24, 0, 0),
#   'BillingAddress': 'Grétrystraat 63',
#   'BillingCity': 'Brussels',
#   'BillingState': None,
#   'BillingCountry': 'Belgium',
#   'BillingPostalCode': '1000',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf282'),
#   'InvoiceId': 56,
#   'CustomerId': 9,
#   'InvoiceDate': datetime.datetime(2009, 9, 6, 0, 0),
#   'BillingAddress': 'Sønder Boulevard 51',
#   'BillingCity': 'Copenhagen',
#   'BillingState': None,
#   'BillingCountry': 'Denmark',
#   'BillingPostalCode': '1720',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf283'),
#   'InvoiceId': 57,
#   'CustomerId': 11,
#   'InvoiceDate': datetime.datetime(2009, 9, 6, 0, 0),
#   'BillingAddress': 'Av. Paulista, 2022',
#   'BillingCity': 'São Paulo',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '01310-200',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf284'),
#   'InvoiceId': 58,
#   'CustomerId': 13,
#   'InvoiceDate': datetime.datetime(2009, 9, 7, 0, 0),
#   'BillingAddress': 'Qe 7 Bloco G',
#   'BillingCity': 'Brasília',
#   'BillingState': 'DF',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '71020-677',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf285'),
#   'InvoiceId': 59,
#   'CustomerId': 17,
#   'InvoiceDate': datetime.datetime(2009, 9, 8, 0, 0),
#   'BillingAddress': '1 Microsoft Way',
#   'BillingCity': 'Redmond',
#   'BillingState': 'WA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '98052-8300',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf286'),
#   'InvoiceId': 60,
#   'CustomerId': 23,
#   'InvoiceDate': datetime.datetime(2009, 9, 11, 0, 0),
#   'BillingAddress': '69 Salem Street',
#   'BillingCity': 'Boston',
#   'BillingState': 'MA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '2113',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf287'),
#   'InvoiceId': 61,
#   'CustomerId': 32,
#   'InvoiceDate': datetime.datetime(2009, 9, 16, 0, 0),
#   'BillingAddress': '696 Osborne Street',
#   'BillingCity': 'Winnipeg',
#   'BillingState': 'MB',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'R3L 2B9',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf288'),
#   'InvoiceId': 62,
#   'CustomerId': 46,
#   'InvoiceDate': datetime.datetime(2009, 9, 24, 0, 0),
#   'BillingAddress': '3 Chatham Street',
#   'BillingCity': 'Dublin',
#   'BillingState': 'Dublin',
#   'BillingCountry': 'Ireland',
#   'BillingPostalCode': None,
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf289'),
#   'InvoiceId': 63,
#   'CustomerId': 47,
#   'InvoiceDate': datetime.datetime(2009, 10, 7, 0, 0),
#   'BillingAddress': 'Via Degli Scipioni, 43',
#   'BillingCity': 'Rome',
#   'BillingState': 'RM',
#   'BillingCountry': 'Italy',
#   'BillingPostalCode': '00192',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf28a'),
#   'InvoiceId': 64,
#   'CustomerId': 49,
#   'InvoiceDate': datetime.datetime(2009, 10, 7, 0, 0),
#   'BillingAddress': 'Ordynacka 10',
#   'BillingCity': 'Warsaw',
#   'BillingState': None,
#   'BillingCountry': 'Poland',
#   'BillingPostalCode': '00-358',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf28b'),
#   'InvoiceId': 65,
#   'CustomerId': 51,
#   'InvoiceDate': datetime.datetime(2009, 10, 8, 0, 0),
#   'BillingAddress': 'Celsiusg. 9',
#   'BillingCity': 'Stockholm',
#   'BillingState': None,
#   'BillingCountry': 'Sweden',
#   'BillingPostalCode': '11230',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf28c'),
#   'InvoiceId': 66,
#   'CustomerId': 55,
#   'InvoiceDate': datetime.datetime(2009, 10, 9, 0, 0),
#   'BillingAddress': '421 Bourke Street',
#   'BillingCity': 'Sidney',
#   'BillingState': 'NSW',
#   'BillingCountry': 'Australia',
#   'BillingPostalCode': '2010',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf28d'),
#   'InvoiceId': 67,
#   'CustomerId': 2,
#   'InvoiceDate': datetime.datetime(2009, 10, 12, 0, 0),
#   'BillingAddress': 'Theodor-Heuss-Straße 34',
#   'BillingCity': 'Stuttgart',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '70174',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf28e'),
#   'InvoiceId': 68,
#   'CustomerId': 11,
#   'InvoiceDate': datetime.datetime(2009, 10, 17, 0, 0),
#   'BillingAddress': 'Av. Paulista, 2022',
#   'BillingCity': 'São Paulo',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '01310-200',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf28f'),
#   'InvoiceId': 69,
#   'CustomerId': 25,
#   'InvoiceDate': datetime.datetime(2009, 10, 25, 0, 0),
#   'BillingAddress': '319 N. Frances Street',
#   'BillingCity': 'Madison',
#   'BillingState': 'WI',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '53703',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf290'),
#   'InvoiceId': 70,
#   'CustomerId': 26,
#   'InvoiceDate': datetime.datetime(2009, 11, 7, 0, 0),
#   'BillingAddress': '2211 W Berry Street',
#   'BillingCity': 'Fort Worth',
#   'BillingState': 'TX',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '76110',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf291'),
#   'InvoiceId': 71,
#   'CustomerId': 28,
#   'InvoiceDate': datetime.datetime(2009, 11, 7, 0, 0),
#   'BillingAddress': '302 S 700 E',
#   'BillingCity': 'Salt Lake City',
#   'BillingState': 'UT',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '84102',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf292'),
#   'InvoiceId': 72,
#   'CustomerId': 30,
#   'InvoiceDate': datetime.datetime(2009, 11, 8, 0, 0),
#   'BillingAddress': '230 Elgin Street',
#   'BillingCity': 'Ottawa',
#   'BillingState': 'ON',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'K2P 1L7',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf293'),
#   'InvoiceId': 73,
#   'CustomerId': 34,
#   'InvoiceDate': datetime.datetime(2009, 11, 9, 0, 0),
#   'BillingAddress': 'Rua da Assunção 53',
#   'BillingCity': 'Lisbon',
#   'BillingState': None,
#   'BillingCountry': 'Portugal',
#   'BillingPostalCode': None,
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf294'),
#   'InvoiceId': 74,
#   'CustomerId': 40,
#   'InvoiceDate': datetime.datetime(2009, 11, 12, 0, 0),
#   'BillingAddress': '8, Rue Hanovre',
#   'BillingCity': 'Paris',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '75002',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf295'),
#   'InvoiceId': 75,
#   'CustomerId': 49,
#   'InvoiceDate': datetime.datetime(2009, 11, 17, 0, 0),
#   'BillingAddress': 'Ordynacka 10',
#   'BillingCity': 'Warsaw',
#   'BillingState': None,
#   'BillingCountry': 'Poland',
#   'BillingPostalCode': '00-358',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf296'),
#   'InvoiceId': 76,
#   'CustomerId': 4,
#   'InvoiceDate': datetime.datetime(2009, 11, 25, 0, 0),
#   'BillingAddress': 'Ullevålsveien 14',
#   'BillingCity': 'Oslo',
#   'BillingState': None,
#   'BillingCountry': 'Norway',
#   'BillingPostalCode': '0171',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf297'),
#   'InvoiceId': 77,
#   'CustomerId': 5,
#   'InvoiceDate': datetime.datetime(2009, 12, 8, 0, 0),
#   'BillingAddress': 'Klanova 9/506',
#   'BillingCity': 'Prague',
#   'BillingState': None,
#   'BillingCountry': 'Czech Republic',
#   'BillingPostalCode': '14700',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf298'),
#   'InvoiceId': 78,
#   'CustomerId': 7,
#   'InvoiceDate': datetime.datetime(2009, 12, 8, 0, 0),
#   'BillingAddress': 'Rotenturmstraße 4, 1010 Innere Stadt',
#   'BillingCity': 'Vienne',
#   'BillingState': None,
#   'BillingCountry': 'Austria',
#   'BillingPostalCode': '1010',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf299'),
#   'InvoiceId': 79,
#   'CustomerId': 9,
#   'InvoiceDate': datetime.datetime(2009, 12, 9, 0, 0),
#   'BillingAddress': 'Sønder Boulevard 51',
#   'BillingCity': 'Copenhagen',
#   'BillingState': None,
#   'BillingCountry': 'Denmark',
#   'BillingPostalCode': '1720',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf29a'),
#   'InvoiceId': 80,
#   'CustomerId': 13,
#   'InvoiceDate': datetime.datetime(2009, 12, 10, 0, 0),
#   'BillingAddress': 'Qe 7 Bloco G',
#   'BillingCity': 'Brasília',
#   'BillingState': 'DF',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '71020-677',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf29b'),
#   'InvoiceId': 81,
#   'CustomerId': 19,
#   'InvoiceDate': datetime.datetime(2009, 12, 13, 0, 0),
#   'BillingAddress': '1 Infinite Loop',
#   'BillingCity': 'Cupertino',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '95014',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf29c'),
#   'InvoiceId': 82,
#   'CustomerId': 28,
#   'InvoiceDate': datetime.datetime(2009, 12, 18, 0, 0),
#   'BillingAddress': '302 S 700 E',
#   'BillingCity': 'Salt Lake City',
#   'BillingState': 'UT',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '84102',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf29d'),
#   'InvoiceId': 83,
#   'CustomerId': 42,
#   'InvoiceDate': datetime.datetime(2009, 12, 26, 0, 0),
#   'BillingAddress': '9, Place Louis Barthou',
#   'BillingCity': 'Bordeaux',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '33000',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf29e'),
#   'InvoiceId': 84,
#   'CustomerId': 43,
#   'InvoiceDate': datetime.datetime(2010, 1, 8, 0, 0),
#   'BillingAddress': '68, Rue Jouvence',
#   'BillingCity': 'Dijon',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '21000',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf29f'),
#   'InvoiceId': 85,
#   'CustomerId': 45,
#   'InvoiceDate': datetime.datetime(2010, 1, 8, 0, 0),
#   'BillingAddress': 'Erzsébet krt. 58.',
#   'BillingCity': 'Budapest',
#   'BillingState': None,
#   'BillingCountry': 'Hungary',
#   'BillingPostalCode': 'H-1073',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a0'),
#   'InvoiceId': 86,
#   'CustomerId': 47,
#   'InvoiceDate': datetime.datetime(2010, 1, 9, 0, 0),
#   'BillingAddress': 'Via Degli Scipioni, 43',
#   'BillingCity': 'Rome',
#   'BillingState': 'RM',
#   'BillingCountry': 'Italy',
#   'BillingPostalCode': '00192',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a1'),
#   'InvoiceId': 87,
#   'CustomerId': 51,
#   'InvoiceDate': datetime.datetime(2010, 1, 10, 0, 0),
#   'BillingAddress': 'Celsiusg. 9',
#   'BillingCity': 'Stockholm',
#   'BillingState': None,
#   'BillingCountry': 'Sweden',
#   'BillingPostalCode': '11230',
#   'Total': 6.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a2'),
#   'InvoiceId': 88,
#   'CustomerId': 57,
#   'InvoiceDate': datetime.datetime(2010, 1, 13, 0, 0),
#   'BillingAddress': 'Calle Lira, 198',
#   'BillingCity': 'Santiago',
#   'BillingState': None,
#   'BillingCountry': 'Chile',
#   'BillingPostalCode': None,
#   'Total': 17.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a3'),
#   'InvoiceId': 89,
#   'CustomerId': 7,
#   'InvoiceDate': datetime.datetime(2010, 1, 18, 0, 0),
#   'BillingAddress': 'Rotenturmstraße 4, 1010 Innere Stadt',
#   'BillingCity': 'Vienne',
#   'BillingState': None,
#   'BillingCountry': 'Austria',
#   'BillingPostalCode': '1010',
#   'Total': 18.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a4'),
#   'InvoiceId': 90,
#   'CustomerId': 21,
#   'InvoiceDate': datetime.datetime(2010, 1, 26, 0, 0),
#   'BillingAddress': '801 W 4th Street',
#   'BillingCity': 'Reno',
#   'BillingState': 'NV',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '89503',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a5'),
#   'InvoiceId': 91,
#   'CustomerId': 22,
#   'InvoiceDate': datetime.datetime(2010, 2, 8, 0, 0),
#   'BillingAddress': '120 S Orange Ave',
#   'BillingCity': 'Orlando',
#   'BillingState': 'FL',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '32801',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a6'),
#   'InvoiceId': 92,
#   'CustomerId': 24,
#   'InvoiceDate': datetime.datetime(2010, 2, 8, 0, 0),
#   'BillingAddress': '162 E Superior Street',
#   'BillingCity': 'Chicago',
#   'BillingState': 'IL',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '60611',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a7'),
#   'InvoiceId': 93,
#   'CustomerId': 26,
#   'InvoiceDate': datetime.datetime(2010, 2, 9, 0, 0),
#   'BillingAddress': '2211 W Berry Street',
#   'BillingCity': 'Fort Worth',
#   'BillingState': 'TX',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '76110',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a8'),
#   'InvoiceId': 94,
#   'CustomerId': 30,
#   'InvoiceDate': datetime.datetime(2010, 2, 10, 0, 0),
#   'BillingAddress': '230 Elgin Street',
#   'BillingCity': 'Ottawa',
#   'BillingState': 'ON',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'K2P 1L7',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a9'),
#   'InvoiceId': 95,
#   'CustomerId': 36,
#   'InvoiceDate': datetime.datetime(2010, 2, 13, 0, 0),
#   'BillingAddress': 'Tauentzienstraße 8',
#   'BillingCity': 'Berlin',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '10789',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2aa'),
#   'InvoiceId': 96,
#   'CustomerId': 45,
#   'InvoiceDate': datetime.datetime(2010, 2, 18, 0, 0),
#   'BillingAddress': 'Erzsébet krt. 58.',
#   'BillingCity': 'Budapest',
#   'BillingState': None,
#   'BillingCountry': 'Hungary',
#   'BillingPostalCode': 'H-1073',
#   'Total': 21.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2ab'),
#   'InvoiceId': 97,
#   'CustomerId': 59,
#   'InvoiceDate': datetime.datetime(2010, 2, 26, 0, 0),
#   'BillingAddress': '3,Raj Bhavan Road',
#   'BillingCity': 'Bangalore',
#   'BillingState': None,
#   'BillingCountry': 'India',
#   'BillingPostalCode': '560001',
#   'Total': 1.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2ac'),
#   'InvoiceId': 98,
#   'CustomerId': 1,
#   'InvoiceDate': datetime.datetime(2010, 3, 11, 0, 0),
#   'BillingAddress': 'Av. Brigadeiro Faria Lima, 2170',
#   'BillingCity': 'São José dos Campos',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '12227-000',
#   'Total': 3.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2ad'),
#   'InvoiceId': 99,
#   'CustomerId': 3,
#   'InvoiceDate': datetime.datetime(2010, 3, 11, 0, 0),
#   'BillingAddress': '1498 rue Bélanger',
#   'BillingCity': 'Montréal',
#   'BillingState': 'QC',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'H2G 1A7',
#   'Total': 3.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2ae'),
#   'InvoiceId': 100,
#   'CustomerId': 5,
#   'InvoiceDate': datetime.datetime(2010, 3, 12, 0, 0),
#   'BillingAddress': 'Klanova 9/506',
#   'BillingCity': 'Prague',
#   'BillingState': None,
#   'BillingCountry': 'Czech Republic',
#   'BillingPostalCode': '14700',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2af'),
#   'InvoiceId': 101,
#   'CustomerId': 9,
#   'InvoiceDate': datetime.datetime(2010, 3, 13, 0, 0),
#   'BillingAddress': 'Sønder Boulevard 51',
#   'BillingCity': 'Copenhagen',
#   'BillingState': None,
#   'BillingCountry': 'Denmark',
#   'BillingPostalCode': '1720',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b0'),
#   'InvoiceId': 102,
#   'CustomerId': 15,
#   'InvoiceDate': datetime.datetime(2010, 3, 16, 0, 0),
#   'BillingAddress': '700 W Pender Street',
#   'BillingCity': 'Vancouver',
#   'BillingState': 'BC',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'V6C 1G8',
#   'Total': 9.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b1'),
#   'InvoiceId': 103,
#   'CustomerId': 24,
#   'InvoiceDate': datetime.datetime(2010, 3, 21, 0, 0),
#   'BillingAddress': '162 E Superior Street',
#   'BillingCity': 'Chicago',
#   'BillingState': 'IL',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '60611',
#   'Total': 15.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b2'),
#   'InvoiceId': 104,
#   'CustomerId': 38,
#   'InvoiceDate': datetime.datetime(2010, 3, 29, 0, 0),
#   'BillingAddress': 'Barbarossastraße 19',
#   'BillingCity': 'Berlin',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '10779',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b3'),
#   'InvoiceId': 105,
#   'CustomerId': 39,
#   'InvoiceDate': datetime.datetime(2010, 4, 11, 0, 0),
#   'BillingAddress': '4, Rue Milton',
#   'BillingCity': 'Paris',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '75009',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b4'),
#   'InvoiceId': 106,
#   'CustomerId': 41,
#   'InvoiceDate': datetime.datetime(2010, 4, 11, 0, 0),
#   'BillingAddress': '11, Place Bellecour',
#   'BillingCity': 'Lyon',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '69002',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b5'),
#   'InvoiceId': 107,
#   'CustomerId': 43,
#   'InvoiceDate': datetime.datetime(2010, 4, 12, 0, 0),
#   'BillingAddress': '68, Rue Jouvence',
#   'BillingCity': 'Dijon',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '21000',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b6'),
#   'InvoiceId': 108,
#   'CustomerId': 47,
#   'InvoiceDate': datetime.datetime(2010, 4, 13, 0, 0),
#   'BillingAddress': 'Via Degli Scipioni, 43',
#   'BillingCity': 'Rome',
#   'BillingState': 'RM',
#   'BillingCountry': 'Italy',
#   'BillingPostalCode': '00192',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b7'),
#   'InvoiceId': 109,
#   'CustomerId': 53,
#   'InvoiceDate': datetime.datetime(2010, 4, 16, 0, 0),
#   'BillingAddress': '113 Lupus St',
#   'BillingCity': 'London',
#   'BillingState': None,
#   'BillingCountry': 'United Kingdom',
#   'BillingPostalCode': 'SW1V 3EN',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b8'),
#   'InvoiceId': 110,
#   'CustomerId': 3,
#   'InvoiceDate': datetime.datetime(2010, 4, 21, 0, 0),
#   'BillingAddress': '1498 rue Bélanger',
#   'BillingCity': 'Montréal',
#   'BillingState': 'QC',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'H2G 1A7',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b9'),
#   'InvoiceId': 111,
#   'CustomerId': 17,
#   'InvoiceDate': datetime.datetime(2010, 4, 29, 0, 0),
#   'BillingAddress': '1 Microsoft Way',
#   'BillingCity': 'Redmond',
#   'BillingState': 'WA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '98052-8300',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2ba'),
#   'InvoiceId': 112,
#   'CustomerId': 18,
#   'InvoiceDate': datetime.datetime(2010, 5, 12, 0, 0),
#   'BillingAddress': '627 Broadway',
#   'BillingCity': 'New York',
#   'BillingState': 'NY',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '10012-2612',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2bb'),
#   'InvoiceId': 113,
#   'CustomerId': 20,
#   'InvoiceDate': datetime.datetime(2010, 5, 12, 0, 0),
#   'BillingAddress': '541 Del Medio Avenue',
#   'BillingCity': 'Mountain View',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '94040-111',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2bc'),
#   'InvoiceId': 114,
#   'CustomerId': 22,
#   'InvoiceDate': datetime.datetime(2010, 5, 13, 0, 0),
#   'BillingAddress': '120 S Orange Ave',
#   'BillingCity': 'Orlando',
#   'BillingState': 'FL',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '32801',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2bd'),
#   'InvoiceId': 115,
#   'CustomerId': 26,
#   'InvoiceDate': datetime.datetime(2010, 5, 14, 0, 0),
#   'BillingAddress': '2211 W Berry Street',
#   'BillingCity': 'Fort Worth',
#   'BillingState': 'TX',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '76110',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2be'),
#   'InvoiceId': 116,
#   'CustomerId': 32,
#   'InvoiceDate': datetime.datetime(2010, 5, 17, 0, 0),
#   'BillingAddress': '696 Osborne Street',
#   'BillingCity': 'Winnipeg',
#   'BillingState': 'MB',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'R3L 2B9',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2bf'),
#   'InvoiceId': 117,
#   'CustomerId': 41,
#   'InvoiceDate': datetime.datetime(2010, 5, 22, 0, 0),
#   'BillingAddress': '11, Place Bellecour',
#   'BillingCity': 'Lyon',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '69002',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c0'),
#   'InvoiceId': 118,
#   'CustomerId': 55,
#   'InvoiceDate': datetime.datetime(2010, 5, 30, 0, 0),
#   'BillingAddress': '421 Bourke Street',
#   'BillingCity': 'Sidney',
#   'BillingState': 'NSW',
#   'BillingCountry': 'Australia',
#   'BillingPostalCode': '2010',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c1'),
#   'InvoiceId': 119,
#   'CustomerId': 56,
#   'InvoiceDate': datetime.datetime(2010, 6, 12, 0, 0),
#   'BillingAddress': '307 Macacha Güemes',
#   'BillingCity': 'Buenos Aires',
#   'BillingState': None,
#   'BillingCountry': 'Argentina',
#   'BillingPostalCode': '1106',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c2'),
#   'InvoiceId': 120,
#   'CustomerId': 58,
#   'InvoiceDate': datetime.datetime(2010, 6, 12, 0, 0),
#   'BillingAddress': '12,Community Centre',
#   'BillingCity': 'Delhi',
#   'BillingState': None,
#   'BillingCountry': 'India',
#   'BillingPostalCode': '110017',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c3'),
#   'InvoiceId': 121,
#   'CustomerId': 1,
#   'InvoiceDate': datetime.datetime(2010, 6, 13, 0, 0),
#   'BillingAddress': 'Av. Brigadeiro Faria Lima, 2170',
#   'BillingCity': 'São José dos Campos',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '12227-000',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c4'),
#   'InvoiceId': 122,
#   'CustomerId': 5,
#   'InvoiceDate': datetime.datetime(2010, 6, 14, 0, 0),
#   'BillingAddress': 'Klanova 9/506',
#   'BillingCity': 'Prague',
#   'BillingState': None,
#   'BillingCountry': 'Czech Republic',
#   'BillingPostalCode': '14700',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c5'),
#   'InvoiceId': 123,
#   'CustomerId': 11,
#   'InvoiceDate': datetime.datetime(2010, 6, 17, 0, 0),
#   'BillingAddress': 'Av. Paulista, 2022',
#   'BillingCity': 'São Paulo',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '01310-200',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c6'),
#   'InvoiceId': 124,
#   'CustomerId': 20,
#   'InvoiceDate': datetime.datetime(2010, 6, 22, 0, 0),
#   'BillingAddress': '541 Del Medio Avenue',
#   'BillingCity': 'Mountain View',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '94040-111',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c7'),
#   'InvoiceId': 125,
#   'CustomerId': 34,
#   'InvoiceDate': datetime.datetime(2010, 6, 30, 0, 0),
#   'BillingAddress': 'Rua da Assunção 53',
#   'BillingCity': 'Lisbon',
#   'BillingState': None,
#   'BillingCountry': 'Portugal',
#   'BillingPostalCode': None,
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c8'),
#   'InvoiceId': 126,
#   'CustomerId': 35,
#   'InvoiceDate': datetime.datetime(2010, 7, 13, 0, 0),
#   'BillingAddress': 'Rua dos Campeões Europeus de Viena, 4350',
#   'BillingCity': 'Porto',
#   'BillingState': None,
#   'BillingCountry': 'Portugal',
#   'BillingPostalCode': None,
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c9'),
#   'InvoiceId': 127,
#   'CustomerId': 37,
#   'InvoiceDate': datetime.datetime(2010, 7, 13, 0, 0),
#   'BillingAddress': 'Berger Straße 10',
#   'BillingCity': 'Frankfurt',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '60316',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2ca'),
#   'InvoiceId': 128,
#   'CustomerId': 39,
#   'InvoiceDate': datetime.datetime(2010, 7, 14, 0, 0),
#   'BillingAddress': '4, Rue Milton',
#   'BillingCity': 'Paris',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '75009',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2cb'),
#   'InvoiceId': 129,
#   'CustomerId': 43,
#   'InvoiceDate': datetime.datetime(2010, 7, 15, 0, 0),
#   'BillingAddress': '68, Rue Jouvence',
#   'BillingCity': 'Dijon',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '21000',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2cc'),
#   'InvoiceId': 130,
#   'CustomerId': 49,
#   'InvoiceDate': datetime.datetime(2010, 7, 18, 0, 0),
#   'BillingAddress': 'Ordynacka 10',
#   'BillingCity': 'Warsaw',
#   'BillingState': None,
#   'BillingCountry': 'Poland',
#   'BillingPostalCode': '00-358',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2cd'),
#   'InvoiceId': 131,
#   'CustomerId': 58,
#   'InvoiceDate': datetime.datetime(2010, 7, 23, 0, 0),
#   'BillingAddress': '12,Community Centre',
#   'BillingCity': 'Delhi',
#   'BillingState': None,
#   'BillingCountry': 'India',
#   'BillingPostalCode': '110017',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2ce'),
#   'InvoiceId': 132,
#   'CustomerId': 13,
#   'InvoiceDate': datetime.datetime(2010, 7, 31, 0, 0),
#   'BillingAddress': 'Qe 7 Bloco G',
#   'BillingCity': 'Brasília',
#   'BillingState': 'DF',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '71020-677',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2cf'),
#   'InvoiceId': 133,
#   'CustomerId': 14,
#   'InvoiceDate': datetime.datetime(2010, 8, 13, 0, 0),
#   'BillingAddress': '8210 111 ST NW',
#   'BillingCity': 'Edmonton',
#   'BillingState': 'AB',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'T6G 2C7',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d0'),
#   'InvoiceId': 134,
#   'CustomerId': 16,
#   'InvoiceDate': datetime.datetime(2010, 8, 13, 0, 0),
#   'BillingAddress': '1600 Amphitheatre Parkway',
#   'BillingCity': 'Mountain View',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '94043-1351',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d1'),
#   'InvoiceId': 135,
#   'CustomerId': 18,
#   'InvoiceDate': datetime.datetime(2010, 8, 14, 0, 0),
#   'BillingAddress': '627 Broadway',
#   'BillingCity': 'New York',
#   'BillingState': 'NY',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '10012-2612',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d2'),
#   'InvoiceId': 136,
#   'CustomerId': 22,
#   'InvoiceDate': datetime.datetime(2010, 8, 15, 0, 0),
#   'BillingAddress': '120 S Orange Ave',
#   'BillingCity': 'Orlando',
#   'BillingState': 'FL',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '32801',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d3'),
#   'InvoiceId': 137,
#   'CustomerId': 28,
#   'InvoiceDate': datetime.datetime(2010, 8, 18, 0, 0),
#   'BillingAddress': '302 S 700 E',
#   'BillingCity': 'Salt Lake City',
#   'BillingState': 'UT',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '84102',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d4'),
#   'InvoiceId': 138,
#   'CustomerId': 37,
#   'InvoiceDate': datetime.datetime(2010, 8, 23, 0, 0),
#   'BillingAddress': 'Berger Straße 10',
#   'BillingCity': 'Frankfurt',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '60316',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d5'),
#   'InvoiceId': 139,
#   'CustomerId': 51,
#   'InvoiceDate': datetime.datetime(2010, 8, 31, 0, 0),
#   'BillingAddress': 'Celsiusg. 9',
#   'BillingCity': 'Stockholm',
#   'BillingState': None,
#   'BillingCountry': 'Sweden',
#   'BillingPostalCode': '11230',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d6'),
#   'InvoiceId': 140,
#   'CustomerId': 52,
#   'InvoiceDate': datetime.datetime(2010, 9, 13, 0, 0),
#   'BillingAddress': '202 Hoxton Street',
#   'BillingCity': 'London',
#   'BillingState': None,
#   'BillingCountry': 'United Kingdom',
#   'BillingPostalCode': 'N1 5LH',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d7'),
#   'InvoiceId': 141,
#   'CustomerId': 54,
#   'InvoiceDate': datetime.datetime(2010, 9, 13, 0, 0),
#   'BillingAddress': '110 Raeburn Pl',
#   'BillingCity': 'Edinburgh',
#   'BillingState': None,
#   'BillingCountry': 'United Kingdom',
#   'BillingPostalCode': 'EH4 1HH',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d8'),
#   'InvoiceId': 142,
#   'CustomerId': 56,
#   'InvoiceDate': datetime.datetime(2010, 9, 14, 0, 0),
#   'BillingAddress': '307 Macacha Güemes',
#   'BillingCity': 'Buenos Aires',
#   'BillingState': None,
#   'BillingCountry': 'Argentina',
#   'BillingPostalCode': '1106',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d9'),
#   'InvoiceId': 143,
#   'CustomerId': 1,
#   'InvoiceDate': datetime.datetime(2010, 9, 15, 0, 0),
#   'BillingAddress': 'Av. Brigadeiro Faria Lima, 2170',
#   'BillingCity': 'São José dos Campos',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '12227-000',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2da'),
#   'InvoiceId': 144,
#   'CustomerId': 7,
#   'InvoiceDate': datetime.datetime(2010, 9, 18, 0, 0),
#   'BillingAddress': 'Rotenturmstraße 4, 1010 Innere Stadt',
#   'BillingCity': 'Vienne',
#   'BillingState': None,
#   'BillingCountry': 'Austria',
#   'BillingPostalCode': '1010',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2db'),
#   'InvoiceId': 145,
#   'CustomerId': 16,
#   'InvoiceDate': datetime.datetime(2010, 9, 23, 0, 0),
#   'BillingAddress': '1600 Amphitheatre Parkway',
#   'BillingCity': 'Mountain View',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '94043-1351',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2dc'),
#   'InvoiceId': 146,
#   'CustomerId': 30,
#   'InvoiceDate': datetime.datetime(2010, 10, 1, 0, 0),
#   'BillingAddress': '230 Elgin Street',
#   'BillingCity': 'Ottawa',
#   'BillingState': 'ON',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'K2P 1L7',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2dd'),
#   'InvoiceId': 147,
#   'CustomerId': 31,
#   'InvoiceDate': datetime.datetime(2010, 10, 14, 0, 0),
#   'BillingAddress': '194A Chain Lake Drive',
#   'BillingCity': 'Halifax',
#   'BillingState': 'NS',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'B3S 1C5',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2de'),
#   'InvoiceId': 148,
#   'CustomerId': 33,
#   'InvoiceDate': datetime.datetime(2010, 10, 14, 0, 0),
#   'BillingAddress': '5112 48 Street',
#   'BillingCity': 'Yellowknife',
#   'BillingState': 'NT',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'X1A 1N6',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2df'),
#   'InvoiceId': 149,
#   'CustomerId': 35,
#   'InvoiceDate': datetime.datetime(2010, 10, 15, 0, 0),
#   'BillingAddress': 'Rua dos Campeões Europeus de Viena, 4350',
#   'BillingCity': 'Porto',
#   'BillingState': None,
#   'BillingCountry': 'Portugal',
#   'BillingPostalCode': None,
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2e0'),
#   'InvoiceId': 150,
#   'CustomerId': 39,
#   'InvoiceDate': datetime.datetime(2010, 10, 16, 0, 0),
#   'BillingAddress': '4, Rue Milton',
#   'BillingCity': 'Paris',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '75009',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2e1'),
#   'InvoiceId': 151,
#   'CustomerId': 45,
#   'InvoiceDate': datetime.datetime(2010, 10, 19, 0, 0),
#   'BillingAddress': 'Erzsébet krt. 58.',
#   'BillingCity': 'Budapest',
#   'BillingState': None,
#   'BillingCountry': 'Hungary',
#   'BillingPostalCode': 'H-1073',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2e2'),
#   'InvoiceId': 152,
#   'CustomerId': 54,
#   'InvoiceDate': datetime.datetime(2010, 10, 24, 0, 0),
#   'BillingAddress': '110 Raeburn Pl',
# ...
#   'BillingPostalCode': 'T6G 2C7',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3b5'),
#   'InvoiceId': 363,
#   'CustomerId': 28,
#   'InvoiceDate': datetime.datetime(2013, 5, 19, 0, 0),
#   'BillingAddress': '302 S 700 E',
#   'BillingCity': 'Salt Lake City',
#   'BillingState': 'UT',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '84102',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3b6'),
#   'InvoiceId': 364,
#   'CustomerId': 29,
#   'InvoiceDate': datetime.datetime(2013, 6, 1, 0, 0),
#   'BillingAddress': '796 Dundas Street West',
#   'BillingCity': 'Toronto',
#   'BillingState': 'ON',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'M6J 1V1',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3b7'),
#   'InvoiceId': 365,
#   'CustomerId': 31,
#   'InvoiceDate': datetime.datetime(2013, 6, 1, 0, 0),
#   'BillingAddress': '194A Chain Lake Drive',
#   'BillingCity': 'Halifax',
#   'BillingState': 'NS',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'B3S 1C5',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3b8'),
#   'InvoiceId': 366,
#   'CustomerId': 33,
#   'InvoiceDate': datetime.datetime(2013, 6, 2, 0, 0),
#   'BillingAddress': '5112 48 Street',
#   'BillingCity': 'Yellowknife',
#   'BillingState': 'NT',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'X1A 1N6',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3b9'),
#   'InvoiceId': 367,
#   'CustomerId': 37,
#   'InvoiceDate': datetime.datetime(2013, 6, 3, 0, 0),
#   'BillingAddress': 'Berger Straße 10',
#   'BillingCity': 'Frankfurt',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '60316',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3ba'),
#   'InvoiceId': 368,
#   'CustomerId': 43,
#   'InvoiceDate': datetime.datetime(2013, 6, 6, 0, 0),
#   'BillingAddress': '68, Rue Jouvence',
#   'BillingCity': 'Dijon',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '21000',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3bb'),
#   'InvoiceId': 369,
#   'CustomerId': 52,
#   'InvoiceDate': datetime.datetime(2013, 6, 11, 0, 0),
#   'BillingAddress': '202 Hoxton Street',
#   'BillingCity': 'London',
#   'BillingState': None,
#   'BillingCountry': 'United Kingdom',
#   'BillingPostalCode': 'N1 5LH',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3bc'),
#   'InvoiceId': 370,
#   'CustomerId': 7,
#   'InvoiceDate': datetime.datetime(2013, 6, 19, 0, 0),
#   'BillingAddress': 'Rotenturmstraße 4, 1010 Innere Stadt',
#   'BillingCity': 'Vienne',
#   'BillingState': None,
#   'BillingCountry': 'Austria',
#   'BillingPostalCode': '1010',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3bd'),
#   'InvoiceId': 371,
#   'CustomerId': 8,
#   'InvoiceDate': datetime.datetime(2013, 7, 2, 0, 0),
#   'BillingAddress': 'Grétrystraat 63',
#   'BillingCity': 'Brussels',
#   'BillingState': None,
#   'BillingCountry': 'Belgium',
#   'BillingPostalCode': '1000',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3be'),
#   'InvoiceId': 372,
#   'CustomerId': 10,
#   'InvoiceDate': datetime.datetime(2013, 7, 2, 0, 0),
#   'BillingAddress': 'Rua Dr. Falcão Filho, 155',
#   'BillingCity': 'São Paulo',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '01007-010',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3bf'),
#   'InvoiceId': 373,
#   'CustomerId': 12,
#   'InvoiceDate': datetime.datetime(2013, 7, 3, 0, 0),
#   'BillingAddress': 'Praça Pio X, 119',
#   'BillingCity': 'Rio de Janeiro',
#   'BillingState': 'RJ',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '20040-020',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c0'),
#   'InvoiceId': 374,
#   'CustomerId': 16,
#   'InvoiceDate': datetime.datetime(2013, 7, 4, 0, 0),
#   'BillingAddress': '1600 Amphitheatre Parkway',
#   'BillingCity': 'Mountain View',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '94043-1351',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c1'),
#   'InvoiceId': 375,
#   'CustomerId': 22,
#   'InvoiceDate': datetime.datetime(2013, 7, 7, 0, 0),
#   'BillingAddress': '120 S Orange Ave',
#   'BillingCity': 'Orlando',
#   'BillingState': 'FL',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '32801',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c2'),
#   'InvoiceId': 376,
#   'CustomerId': 31,
#   'InvoiceDate': datetime.datetime(2013, 7, 12, 0, 0),
#   'BillingAddress': '194A Chain Lake Drive',
#   'BillingCity': 'Halifax',
#   'BillingState': 'NS',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'B3S 1C5',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c3'),
#   'InvoiceId': 377,
#   'CustomerId': 45,
#   'InvoiceDate': datetime.datetime(2013, 7, 20, 0, 0),
#   'BillingAddress': 'Erzsébet krt. 58.',
#   'BillingCity': 'Budapest',
#   'BillingState': None,
#   'BillingCountry': 'Hungary',
#   'BillingPostalCode': 'H-1073',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c4'),
#   'InvoiceId': 378,
#   'CustomerId': 46,
#   'InvoiceDate': datetime.datetime(2013, 8, 2, 0, 0),
#   'BillingAddress': '3 Chatham Street',
#   'BillingCity': 'Dublin',
#   'BillingState': 'Dublin',
#   'BillingCountry': 'Ireland',
#   'BillingPostalCode': None,
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c5'),
#   'InvoiceId': 379,
#   'CustomerId': 48,
#   'InvoiceDate': datetime.datetime(2013, 8, 2, 0, 0),
#   'BillingAddress': 'Lijnbaansgracht 120bg',
#   'BillingCity': 'Amsterdam',
#   'BillingState': 'VV',
#   'BillingCountry': 'Netherlands',
#   'BillingPostalCode': '1016',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c6'),
#   'InvoiceId': 380,
#   'CustomerId': 50,
#   'InvoiceDate': datetime.datetime(2013, 8, 3, 0, 0),
#   'BillingAddress': 'C/ San Bernardo 85',
#   'BillingCity': 'Madrid',
#   'BillingState': None,
#   'BillingCountry': 'Spain',
#   'BillingPostalCode': '28015',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c7'),
#   'InvoiceId': 381,
#   'CustomerId': 54,
#   'InvoiceDate': datetime.datetime(2013, 8, 4, 0, 0),
#   'BillingAddress': '110 Raeburn Pl',
#   'BillingCity': 'Edinburgh',
#   'BillingState': None,
#   'BillingCountry': 'United Kingdom',
#   'BillingPostalCode': 'EH4 1HH',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c8'),
#   'InvoiceId': 382,
#   'CustomerId': 1,
#   'InvoiceDate': datetime.datetime(2013, 8, 7, 0, 0),
#   'BillingAddress': 'Av. Brigadeiro Faria Lima, 2170',
#   'BillingCity': 'São José dos Campos',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '12227-000',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c9'),
#   'InvoiceId': 383,
#   'CustomerId': 10,
#   'InvoiceDate': datetime.datetime(2013, 8, 12, 0, 0),
#   'BillingAddress': 'Rua Dr. Falcão Filho, 155',
#   'BillingCity': 'São Paulo',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '01007-010',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3ca'),
#   'InvoiceId': 384,
#   'CustomerId': 24,
#   'InvoiceDate': datetime.datetime(2013, 8, 20, 0, 0),
#   'BillingAddress': '162 E Superior Street',
#   'BillingCity': 'Chicago',
#   'BillingState': 'IL',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '60611',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3cb'),
#   'InvoiceId': 385,
#   'CustomerId': 25,
#   'InvoiceDate': datetime.datetime(2013, 9, 2, 0, 0),
#   'BillingAddress': '319 N. Frances Street',
#   'BillingCity': 'Madison',
#   'BillingState': 'WI',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '53703',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3cc'),
#   'InvoiceId': 386,
#   'CustomerId': 27,
#   'InvoiceDate': datetime.datetime(2013, 9, 2, 0, 0),
#   'BillingAddress': '1033 N Park Ave',
#   'BillingCity': 'Tucson',
#   'BillingState': 'AZ',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '85719',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3cd'),
#   'InvoiceId': 387,
#   'CustomerId': 29,
#   'InvoiceDate': datetime.datetime(2013, 9, 3, 0, 0),
#   'BillingAddress': '796 Dundas Street West',
#   'BillingCity': 'Toronto',
#   'BillingState': 'ON',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'M6J 1V1',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3ce'),
#   'InvoiceId': 388,
#   'CustomerId': 33,
#   'InvoiceDate': datetime.datetime(2013, 9, 4, 0, 0),
#   'BillingAddress': '5112 48 Street',
#   'BillingCity': 'Yellowknife',
#   'BillingState': 'NT',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'X1A 1N6',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3cf'),
#   'InvoiceId': 389,
#   'CustomerId': 39,
#   'InvoiceDate': datetime.datetime(2013, 9, 7, 0, 0),
#   'BillingAddress': '4, Rue Milton',
#   'BillingCity': 'Paris',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '75009',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d0'),
#   'InvoiceId': 390,
#   'CustomerId': 48,
#   'InvoiceDate': datetime.datetime(2013, 9, 12, 0, 0),
#   'BillingAddress': 'Lijnbaansgracht 120bg',
#   'BillingCity': 'Amsterdam',
#   'BillingState': 'VV',
#   'BillingCountry': 'Netherlands',
#   'BillingPostalCode': '1016',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d1'),
#   'InvoiceId': 391,
#   'CustomerId': 3,
#   'InvoiceDate': datetime.datetime(2013, 9, 20, 0, 0),
#   'BillingAddress': '1498 rue Bélanger',
#   'BillingCity': 'Montréal',
#   'BillingState': 'QC',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'H2G 1A7',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d2'),
#   'InvoiceId': 392,
#   'CustomerId': 4,
#   'InvoiceDate': datetime.datetime(2013, 10, 3, 0, 0),
#   'BillingAddress': 'Ullevålsveien 14',
#   'BillingCity': 'Oslo',
#   'BillingState': None,
#   'BillingCountry': 'Norway',
#   'BillingPostalCode': '0171',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d3'),
#   'InvoiceId': 393,
#   'CustomerId': 6,
#   'InvoiceDate': datetime.datetime(2013, 10, 3, 0, 0),
#   'BillingAddress': 'Rilská 3174/6',
#   'BillingCity': 'Prague',
#   'BillingState': None,
#   'BillingCountry': 'Czech Republic',
#   'BillingPostalCode': '14300',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d4'),
#   'InvoiceId': 394,
#   'CustomerId': 8,
#   'InvoiceDate': datetime.datetime(2013, 10, 4, 0, 0),
#   'BillingAddress': 'Grétrystraat 63',
#   'BillingCity': 'Brussels',
#   'BillingState': None,
#   'BillingCountry': 'Belgium',
#   'BillingPostalCode': '1000',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d5'),
#   'InvoiceId': 395,
#   'CustomerId': 12,
#   'InvoiceDate': datetime.datetime(2013, 10, 5, 0, 0),
#   'BillingAddress': 'Praça Pio X, 119',
#   'BillingCity': 'Rio de Janeiro',
#   'BillingState': 'RJ',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '20040-020',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d6'),
#   'InvoiceId': 396,
#   'CustomerId': 18,
#   'InvoiceDate': datetime.datetime(2013, 10, 8, 0, 0),
#   'BillingAddress': '627 Broadway',
#   'BillingCity': 'New York',
#   'BillingState': 'NY',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '10012-2612',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d7'),
#   'InvoiceId': 397,
#   'CustomerId': 27,
#   'InvoiceDate': datetime.datetime(2013, 10, 13, 0, 0),
#   'BillingAddress': '1033 N Park Ave',
#   'BillingCity': 'Tucson',
#   'BillingState': 'AZ',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '85719',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d8'),
#   'InvoiceId': 398,
#   'CustomerId': 41,
#   'InvoiceDate': datetime.datetime(2013, 10, 21, 0, 0),
#   'BillingAddress': '11, Place Bellecour',
#   'BillingCity': 'Lyon',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '69002',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d9'),
#   'InvoiceId': 399,
#   'CustomerId': 42,
#   'InvoiceDate': datetime.datetime(2013, 11, 3, 0, 0),
#   'BillingAddress': '9, Place Louis Barthou',
#   'BillingCity': 'Bordeaux',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '33000',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3da'),
#   'InvoiceId': 400,
#   'CustomerId': 44,
#   'InvoiceDate': datetime.datetime(2013, 11, 3, 0, 0),
#   'BillingAddress': 'Porthaninkatu 9',
#   'BillingCity': 'Helsinki',
#   'BillingState': None,
#   'BillingCountry': 'Finland',
#   'BillingPostalCode': '00530',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3db'),
#   'InvoiceId': 401,
#   'CustomerId': 46,
#   'InvoiceDate': datetime.datetime(2013, 11, 4, 0, 0),
#   'BillingAddress': '3 Chatham Street',
#   'BillingCity': 'Dublin',
#   'BillingState': 'Dublin',
#   'BillingCountry': 'Ireland',
#   'BillingPostalCode': None,
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3dc'),
#   'InvoiceId': 402,
#   'CustomerId': 50,
#   'InvoiceDate': datetime.datetime(2013, 11, 5, 0, 0),
#   'BillingAddress': 'C/ San Bernardo 85',
#   'BillingCity': 'Madrid',
#   'BillingState': None,
#   'BillingCountry': 'Spain',
#   'BillingPostalCode': '28015',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3dd'),
#   'InvoiceId': 403,
#   'CustomerId': 56,
#   'InvoiceDate': datetime.datetime(2013, 11, 8, 0, 0),
#   'BillingAddress': '307 Macacha Güemes',
#   'BillingCity': 'Buenos Aires',
#   'BillingState': None,
#   'BillingCountry': 'Argentina',
#   'BillingPostalCode': '1106',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3de'),
#   'InvoiceId': 404,
#   'CustomerId': 6,
#   'InvoiceDate': datetime.datetime(2013, 11, 13, 0, 0),
#   'BillingAddress': 'Rilská 3174/6',
#   'BillingCity': 'Prague',
#   'BillingState': None,
#   'BillingCountry': 'Czech Republic',
#   'BillingPostalCode': '14300',
#   'Total': 25.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3df'),
#   'InvoiceId': 405,
#   'CustomerId': 20,
#   'InvoiceDate': datetime.datetime(2013, 11, 21, 0, 0),
#   'BillingAddress': '541 Del Medio Avenue',
#   'BillingCity': 'Mountain View',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '94040-111',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3e0'),
#   'InvoiceId': 406,
#   'CustomerId': 21,
#   'InvoiceDate': datetime.datetime(2013, 12, 4, 0, 0),
#   'BillingAddress': '801 W 4th Street',
#   'BillingCity': 'Reno',
#   'BillingState': 'NV',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '89503',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3e1'),
#   'InvoiceId': 407,
#   'CustomerId': 23,
#   'InvoiceDate': datetime.datetime(2013, 12, 4, 0, 0),
#   'BillingAddress': '69 Salem Street',
#   'BillingCity': 'Boston',
#   'BillingState': 'MA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '2113',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3e2'),
#   'InvoiceId': 408,
#   'CustomerId': 25,
#   'InvoiceDate': datetime.datetime(2013, 12, 5, 0, 0),
#   'BillingAddress': '319 N. Frances Street',
#   'BillingCity': 'Madison',
#   'BillingState': 'WI',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '53703',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3e3'),
#   'InvoiceId': 409,
#   'CustomerId': 29,
#   'InvoiceDate': datetime.datetime(2013, 12, 6, 0, 0),
#   'BillingAddress': '796 Dundas Street West',
#   'BillingCity': 'Toronto',
#   'BillingState': 'ON',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'M6J 1V1',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3e4'),
#   'InvoiceId': 410,
#   'CustomerId': 35,
#   'InvoiceDate': datetime.datetime(2013, 12, 9, 0, 0),
#   'BillingAddress': 'Rua dos Campeões Europeus de Viena, 4350',
#   'BillingCity': 'Porto',
#   'BillingState': None,
#   'BillingCountry': 'Portugal',
#   'BillingPostalCode': None,
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3e5'),
#   'InvoiceId': 411,
#   'CustomerId': 44,
#   'InvoiceDate': datetime.datetime(2013, 12, 14, 0, 0),
#   'BillingAddress': 'Porthaninkatu 9',
#   'BillingCity': 'Helsinki',
#   'BillingState': None,
#   'BillingCountry': 'Finland',
#   'BillingPostalCode': '00530',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3e6'),
#   'InvoiceId': 412,
#   'CustomerId': 58,
#   'InvoiceDate': datetime.datetime(2013, 12, 22, 0, 0),
#   'BillingAddress': '12,Community Centre',
#   'BillingCity': 'Delhi',
#   'BillingState': None,
#   'BillingCountry': 'India',
#   'BillingPostalCode': '110017',
#   'Total': 1.99}]

# %% [markdown]
# 3) MongoDB to Pandas Migration (40 Points): Describe + show the steps you have taken in Python to
# retrieve the Chinook data from MongoDB and create + populate the required Pandas dataframes that
# mirror the structure of the SQL tables contained within your PostgreSQL Chinook database. This
# section should include any Python code used for Data Preparation as well as an appropriate
# explanatory narrative.
# Your Jupyter Notebook deliverable should be similar to that of a publication-quality / professional caliber
# document and should include clearly labeled graphics, high-quality formatting, clearly defined section and
# sub-section headers, and be free of spelling and grammar errors. Furthermore, your Pythion code should
# include succinct explanatory comments.
# Upload / submit your Jupyter Notebook within the provided M13 Assignment Canvas submission portal. Be
# sure to save your Notebook using the following nomenclature: first initial_last name_M13_assn" (e.g.,
# J_Smith_M13_assn). Small groups should identity all group members at the start of the Jupyter Notebook
# and each team member should submit their own copy of the team’s work within Canvas

# %%
for customer in customers.find():
    print(customer)
# Out:
# {'_id': ObjectId('6081e178d46ebf23e5ecf24b'), 'InvoiceId': 1, 'CustomerId': 2, 'InvoiceDate': datetime.datetime(2009, 1, 1, 0, 0), 'BillingAddress': 'Theodor-Heuss-Straße 34', 'BillingCity': 'Stuttgart', 'BillingState': None, 'BillingCountry': 'Germany', 'BillingPostalCode': '70174', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf24c'), 'InvoiceId': 2, 'CustomerId': 4, 'InvoiceDate': datetime.datetime(2009, 1, 2, 0, 0), 'BillingAddress': 'Ullevålsveien 14', 'BillingCity': 'Oslo', 'BillingState': None, 'BillingCountry': 'Norway', 'BillingPostalCode': '0171', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf24d'), 'InvoiceId': 3, 'CustomerId': 8, 'InvoiceDate': datetime.datetime(2009, 1, 3, 0, 0), 'BillingAddress': 'Grétrystraat 63', 'BillingCity': 'Brussels', 'BillingState': None, 'BillingCountry': 'Belgium', 'BillingPostalCode': '1000', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf24e'), 'InvoiceId': 4, 'CustomerId': 14, 'InvoiceDate': datetime.datetime(2009, 1, 6, 0, 0), 'BillingAddress': '8210 111 ST NW', 'BillingCity': 'Edmonton', 'BillingState': 'AB', 'BillingCountry': 'Canada', 'BillingPostalCode': 'T6G 2C7', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf24f'), 'InvoiceId': 5, 'CustomerId': 23, 'InvoiceDate': datetime.datetime(2009, 1, 11, 0, 0), 'BillingAddress': '69 Salem Street', 'BillingCity': 'Boston', 'BillingState': 'MA', 'BillingCountry': 'USA', 'BillingPostalCode': '2113', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf250'), 'InvoiceId': 6, 'CustomerId': 37, 'InvoiceDate': datetime.datetime(2009, 1, 19, 0, 0), 'BillingAddress': 'Berger Straße 10', 'BillingCity': 'Frankfurt', 'BillingState': None, 'BillingCountry': 'Germany', 'BillingPostalCode': '60316', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf251'), 'InvoiceId': 7, 'CustomerId': 38, 'InvoiceDate': datetime.datetime(2009, 2, 1, 0, 0), 'BillingAddress': 'Barbarossastraße 19', 'BillingCity': 'Berlin', 'BillingState': None, 'BillingCountry': 'Germany', 'BillingPostalCode': '10779', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf252'), 'InvoiceId': 8, 'CustomerId': 40, 'InvoiceDate': datetime.datetime(2009, 2, 1, 0, 0), 'BillingAddress': '8, Rue Hanovre', 'BillingCity': 'Paris', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '75002', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf253'), 'InvoiceId': 9, 'CustomerId': 42, 'InvoiceDate': datetime.datetime(2009, 2, 2, 0, 0), 'BillingAddress': '9, Place Louis Barthou', 'BillingCity': 'Bordeaux', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '33000', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf254'), 'InvoiceId': 10, 'CustomerId': 46, 'InvoiceDate': datetime.datetime(2009, 2, 3, 0, 0), 'BillingAddress': '3 Chatham Street', 'BillingCity': 'Dublin', 'BillingState': 'Dublin', 'BillingCountry': 'Ireland', 'BillingPostalCode': None, 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf255'), 'InvoiceId': 11, 'CustomerId': 52, 'InvoiceDate': datetime.datetime(2009, 2, 6, 0, 0), 'BillingAddress': '202 Hoxton Street', 'BillingCity': 'London', 'BillingState': None, 'BillingCountry': 'United Kingdom', 'BillingPostalCode': 'N1 5LH', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf256'), 'InvoiceId': 12, 'CustomerId': 2, 'InvoiceDate': datetime.datetime(2009, 2, 11, 0, 0), 'BillingAddress': 'Theodor-Heuss-Straße 34', 'BillingCity': 'Stuttgart', 'BillingState': None, 'BillingCountry': 'Germany', 'BillingPostalCode': '70174', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf257'), 'InvoiceId': 13, 'CustomerId': 16, 'InvoiceDate': datetime.datetime(2009, 2, 19, 0, 0), 'BillingAddress': '1600 Amphitheatre Parkway', 'BillingCity': 'Mountain View', 'BillingState': 'CA', 'BillingCountry': 'USA', 'BillingPostalCode': '94043-1351', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf258'), 'InvoiceId': 14, 'CustomerId': 17, 'InvoiceDate': datetime.datetime(2009, 3, 4, 0, 0), 'BillingAddress': '1 Microsoft Way', 'BillingCity': 'Redmond', 'BillingState': 'WA', 'BillingCountry': 'USA', 'BillingPostalCode': '98052-8300', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf259'), 'InvoiceId': 15, 'CustomerId': 19, 'InvoiceDate': datetime.datetime(2009, 3, 4, 0, 0), 'BillingAddress': '1 Infinite Loop', 'BillingCity': 'Cupertino', 'BillingState': 'CA', 'BillingCountry': 'USA', 'BillingPostalCode': '95014', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf25a'), 'InvoiceId': 16, 'CustomerId': 21, 'InvoiceDate': datetime.datetime(2009, 3, 5, 0, 0), 'BillingAddress': '801 W 4th Street', 'BillingCity': 'Reno', 'BillingState': 'NV', 'BillingCountry': 'USA', 'BillingPostalCode': '89503', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf25b'), 'InvoiceId': 17, 'CustomerId': 25, 'InvoiceDate': datetime.datetime(2009, 3, 6, 0, 0), 'BillingAddress': '319 N. Frances Street', 'BillingCity': 'Madison', 'BillingState': 'WI', 'BillingCountry': 'USA', 'BillingPostalCode': '53703', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf25c'), 'InvoiceId': 18, 'CustomerId': 31, 'InvoiceDate': datetime.datetime(2009, 3, 9, 0, 0), 'BillingAddress': '194A Chain Lake Drive', 'BillingCity': 'Halifax', 'BillingState': 'NS', 'BillingCountry': 'Canada', 'BillingPostalCode': 'B3S 1C5', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf25d'), 'InvoiceId': 19, 'CustomerId': 40, 'InvoiceDate': datetime.datetime(2009, 3, 14, 0, 0), 'BillingAddress': '8, Rue Hanovre', 'BillingCity': 'Paris', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '75002', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf25e'), 'InvoiceId': 20, 'CustomerId': 54, 'InvoiceDate': datetime.datetime(2009, 3, 22, 0, 0), 'BillingAddress': '110 Raeburn Pl', 'BillingCity': 'Edinburgh', 'BillingState': None, 'BillingCountry': 'United Kingdom', 'BillingPostalCode': 'EH4 1HH', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf25f'), 'InvoiceId': 21, 'CustomerId': 55, 'InvoiceDate': datetime.datetime(2009, 4, 4, 0, 0), 'BillingAddress': '421 Bourke Street', 'BillingCity': 'Sidney', 'BillingState': 'NSW', 'BillingCountry': 'Australia', 'BillingPostalCode': '2010', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf260'), 'InvoiceId': 22, 'CustomerId': 57, 'InvoiceDate': datetime.datetime(2009, 4, 4, 0, 0), 'BillingAddress': 'Calle Lira, 198', 'BillingCity': 'Santiago', 'BillingState': None, 'BillingCountry': 'Chile', 'BillingPostalCode': None, 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf261'), 'InvoiceId': 23, 'CustomerId': 59, 'InvoiceDate': datetime.datetime(2009, 4, 5, 0, 0), 'BillingAddress': '3,Raj Bhavan Road', 'BillingCity': 'Bangalore', 'BillingState': None, 'BillingCountry': 'India', 'BillingPostalCode': '560001', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf262'), 'InvoiceId': 24, 'CustomerId': 4, 'InvoiceDate': datetime.datetime(2009, 4, 6, 0, 0), 'BillingAddress': 'Ullevålsveien 14', 'BillingCity': 'Oslo', 'BillingState': None, 'BillingCountry': 'Norway', 'BillingPostalCode': '0171', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf263'), 'InvoiceId': 25, 'CustomerId': 10, 'InvoiceDate': datetime.datetime(2009, 4, 9, 0, 0), 'BillingAddress': 'Rua Dr. Falcão Filho, 155', 'BillingCity': 'São Paulo', 'BillingState': 'SP', 'BillingCountry': 'Brazil', 'BillingPostalCode': '01007-010', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf264'), 'InvoiceId': 26, 'CustomerId': 19, 'InvoiceDate': datetime.datetime(2009, 4, 14, 0, 0), 'BillingAddress': '1 Infinite Loop', 'BillingCity': 'Cupertino', 'BillingState': 'CA', 'BillingCountry': 'USA', 'BillingPostalCode': '95014', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf265'), 'InvoiceId': 27, 'CustomerId': 33, 'InvoiceDate': datetime.datetime(2009, 4, 22, 0, 0), 'BillingAddress': '5112 48 Street', 'BillingCity': 'Yellowknife', 'BillingState': 'NT', 'BillingCountry': 'Canada', 'BillingPostalCode': 'X1A 1N6', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf266'), 'InvoiceId': 28, 'CustomerId': 34, 'InvoiceDate': datetime.datetime(2009, 5, 5, 0, 0), 'BillingAddress': 'Rua da Assunção 53', 'BillingCity': 'Lisbon', 'BillingState': None, 'BillingCountry': 'Portugal', 'BillingPostalCode': None, 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf267'), 'InvoiceId': 29, 'CustomerId': 36, 'InvoiceDate': datetime.datetime(2009, 5, 5, 0, 0), 'BillingAddress': 'Tauentzienstraße 8', 'BillingCity': 'Berlin', 'BillingState': None, 'BillingCountry': 'Germany', 'BillingPostalCode': '10789', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf268'), 'InvoiceId': 30, 'CustomerId': 38, 'InvoiceDate': datetime.datetime(2009, 5, 6, 0, 0), 'BillingAddress': 'Barbarossastraße 19', 'BillingCity': 'Berlin', 'BillingState': None, 'BillingCountry': 'Germany', 'BillingPostalCode': '10779', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf269'), 'InvoiceId': 31, 'CustomerId': 42, 'InvoiceDate': datetime.datetime(2009, 5, 7, 0, 0), 'BillingAddress': '9, Place Louis Barthou', 'BillingCity': 'Bordeaux', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '33000', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf26a'), 'InvoiceId': 32, 'CustomerId': 48, 'InvoiceDate': datetime.datetime(2009, 5, 10, 0, 0), 'BillingAddress': 'Lijnbaansgracht 120bg', 'BillingCity': 'Amsterdam', 'BillingState': 'VV', 'BillingCountry': 'Netherlands', 'BillingPostalCode': '1016', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf26b'), 'InvoiceId': 33, 'CustomerId': 57, 'InvoiceDate': datetime.datetime(2009, 5, 15, 0, 0), 'BillingAddress': 'Calle Lira, 198', 'BillingCity': 'Santiago', 'BillingState': None, 'BillingCountry': 'Chile', 'BillingPostalCode': None, 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf26c'), 'InvoiceId': 34, 'CustomerId': 12, 'InvoiceDate': datetime.datetime(2009, 5, 23, 0, 0), 'BillingAddress': 'Praça Pio X, 119', 'BillingCity': 'Rio de Janeiro', 'BillingState': 'RJ', 'BillingCountry': 'Brazil', 'BillingPostalCode': '20040-020', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf26d'), 'InvoiceId': 35, 'CustomerId': 13, 'InvoiceDate': datetime.datetime(2009, 6, 5, 0, 0), 'BillingAddress': 'Qe 7 Bloco G', 'BillingCity': 'Brasília', 'BillingState': 'DF', 'BillingCountry': 'Brazil', 'BillingPostalCode': '71020-677', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf26e'), 'InvoiceId': 36, 'CustomerId': 15, 'InvoiceDate': datetime.datetime(2009, 6, 5, 0, 0), 'BillingAddress': '700 W Pender Street', 'BillingCity': 'Vancouver', 'BillingState': 'BC', 'BillingCountry': 'Canada', 'BillingPostalCode': 'V6C 1G8', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf26f'), 'InvoiceId': 37, 'CustomerId': 17, 'InvoiceDate': datetime.datetime(2009, 6, 6, 0, 0), 'BillingAddress': '1 Microsoft Way', 'BillingCity': 'Redmond', 'BillingState': 'WA', 'BillingCountry': 'USA', 'BillingPostalCode': '98052-8300', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf270'), 'InvoiceId': 38, 'CustomerId': 21, 'InvoiceDate': datetime.datetime(2009, 6, 7, 0, 0), 'BillingAddress': '801 W 4th Street', 'BillingCity': 'Reno', 'BillingState': 'NV', 'BillingCountry': 'USA', 'BillingPostalCode': '89503', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf271'), 'InvoiceId': 39, 'CustomerId': 27, 'InvoiceDate': datetime.datetime(2009, 6, 10, 0, 0), 'BillingAddress': '1033 N Park Ave', 'BillingCity': 'Tucson', 'BillingState': 'AZ', 'BillingCountry': 'USA', 'BillingPostalCode': '85719', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf272'), 'InvoiceId': 40, 'CustomerId': 36, 'InvoiceDate': datetime.datetime(2009, 6, 15, 0, 0), 'BillingAddress': 'Tauentzienstraße 8', 'BillingCity': 'Berlin', 'BillingState': None, 'BillingCountry': 'Germany', 'BillingPostalCode': '10789', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf273'), 'InvoiceId': 41, 'CustomerId': 50, 'InvoiceDate': datetime.datetime(2009, 6, 23, 0, 0), 'BillingAddress': 'C/ San Bernardo 85', 'BillingCity': 'Madrid', 'BillingState': None, 'BillingCountry': 'Spain', 'BillingPostalCode': '28015', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf274'), 'InvoiceId': 42, 'CustomerId': 51, 'InvoiceDate': datetime.datetime(2009, 7, 6, 0, 0), 'BillingAddress': 'Celsiusg. 9', 'BillingCity': 'Stockholm', 'BillingState': None, 'BillingCountry': 'Sweden', 'BillingPostalCode': '11230', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf275'), 'InvoiceId': 43, 'CustomerId': 53, 'InvoiceDate': datetime.datetime(2009, 7, 6, 0, 0), 'BillingAddress': '113 Lupus St', 'BillingCity': 'London', 'BillingState': None, 'BillingCountry': 'United Kingdom', 'BillingPostalCode': 'SW1V 3EN', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf276'), 'InvoiceId': 44, 'CustomerId': 55, 'InvoiceDate': datetime.datetime(2009, 7, 7, 0, 0), 'BillingAddress': '421 Bourke Street', 'BillingCity': 'Sidney', 'BillingState': 'NSW', 'BillingCountry': 'Australia', 'BillingPostalCode': '2010', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf277'), 'InvoiceId': 45, 'CustomerId': 59, 'InvoiceDate': datetime.datetime(2009, 7, 8, 0, 0), 'BillingAddress': '3,Raj Bhavan Road', 'BillingCity': 'Bangalore', 'BillingState': None, 'BillingCountry': 'India', 'BillingPostalCode': '560001', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf278'), 'InvoiceId': 46, 'CustomerId': 6, 'InvoiceDate': datetime.datetime(2009, 7, 11, 0, 0), 'BillingAddress': 'Rilská 3174/6', 'BillingCity': 'Prague', 'BillingState': None, 'BillingCountry': 'Czech Republic', 'BillingPostalCode': '14300', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf279'), 'InvoiceId': 47, 'CustomerId': 15, 'InvoiceDate': datetime.datetime(2009, 7, 16, 0, 0), 'BillingAddress': '700 W Pender Street', 'BillingCity': 'Vancouver', 'BillingState': 'BC', 'BillingCountry': 'Canada', 'BillingPostalCode': 'V6C 1G8', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf27a'), 'InvoiceId': 48, 'CustomerId': 29, 'InvoiceDate': datetime.datetime(2009, 7, 24, 0, 0), 'BillingAddress': '796 Dundas Street West', 'BillingCity': 'Toronto', 'BillingState': 'ON', 'BillingCountry': 'Canada', 'BillingPostalCode': 'M6J 1V1', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf27b'), 'InvoiceId': 49, 'CustomerId': 30, 'InvoiceDate': datetime.datetime(2009, 8, 6, 0, 0), 'BillingAddress': '230 Elgin Street', 'BillingCity': 'Ottawa', 'BillingState': 'ON', 'BillingCountry': 'Canada', 'BillingPostalCode': 'K2P 1L7', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf27c'), 'InvoiceId': 50, 'CustomerId': 32, 'InvoiceDate': datetime.datetime(2009, 8, 6, 0, 0), 'BillingAddress': '696 Osborne Street', 'BillingCity': 'Winnipeg', 'BillingState': 'MB', 'BillingCountry': 'Canada', 'BillingPostalCode': 'R3L 2B9', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf27d'), 'InvoiceId': 51, 'CustomerId': 34, 'InvoiceDate': datetime.datetime(2009, 8, 7, 0, 0), 'BillingAddress': 'Rua da Assunção 53', 'BillingCity': 'Lisbon', 'BillingState': None, 'BillingCountry': 'Portugal', 'BillingPostalCode': None, 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf27e'), 'InvoiceId': 52, 'CustomerId': 38, 'InvoiceDate': datetime.datetime(2009, 8, 8, 0, 0), 'BillingAddress': 'Barbarossastraße 19', 'BillingCity': 'Berlin', 'BillingState': None, 'BillingCountry': 'Germany', 'BillingPostalCode': '10779', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf27f'), 'InvoiceId': 53, 'CustomerId': 44, 'InvoiceDate': datetime.datetime(2009, 8, 11, 0, 0), 'BillingAddress': 'Porthaninkatu 9', 'BillingCity': 'Helsinki', 'BillingState': None, 'BillingCountry': 'Finland', 'BillingPostalCode': '00530', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf280'), 'InvoiceId': 54, 'CustomerId': 53, 'InvoiceDate': datetime.datetime(2009, 8, 16, 0, 0), 'BillingAddress': '113 Lupus St', 'BillingCity': 'London', 'BillingState': None, 'BillingCountry': 'United Kingdom', 'BillingPostalCode': 'SW1V 3EN', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf281'), 'InvoiceId': 55, 'CustomerId': 8, 'InvoiceDate': datetime.datetime(2009, 8, 24, 0, 0), 'BillingAddress': 'Grétrystraat 63', 'BillingCity': 'Brussels', 'BillingState': None, 'BillingCountry': 'Belgium', 'BillingPostalCode': '1000', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf282'), 'InvoiceId': 56, 'CustomerId': 9, 'InvoiceDate': datetime.datetime(2009, 9, 6, 0, 0), 'BillingAddress': 'Sønder Boulevard 51', 'BillingCity': 'Copenhagen', 'BillingState': None, 'BillingCountry': 'Denmark', 'BillingPostalCode': '1720', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf283'), 'InvoiceId': 57, 'CustomerId': 11, 'InvoiceDate': datetime.datetime(2009, 9, 6, 0, 0), 'BillingAddress': 'Av. Paulista, 2022', 'BillingCity': 'São Paulo', 'BillingState': 'SP', 'BillingCountry': 'Brazil', 'BillingPostalCode': '01310-200', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf284'), 'InvoiceId': 58, 'CustomerId': 13, 'InvoiceDate': datetime.datetime(2009, 9, 7, 0, 0), 'BillingAddress': 'Qe 7 Bloco G', 'BillingCity': 'Brasília', 'BillingState': 'DF', 'BillingCountry': 'Brazil', 'BillingPostalCode': '71020-677', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf285'), 'InvoiceId': 59, 'CustomerId': 17, 'InvoiceDate': datetime.datetime(2009, 9, 8, 0, 0), 'BillingAddress': '1 Microsoft Way', 'BillingCity': 'Redmond', 'BillingState': 'WA', 'BillingCountry': 'USA', 'BillingPostalCode': '98052-8300', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf286'), 'InvoiceId': 60, 'CustomerId': 23, 'InvoiceDate': datetime.datetime(2009, 9, 11, 0, 0), 'BillingAddress': '69 Salem Street', 'BillingCity': 'Boston', 'BillingState': 'MA', 'BillingCountry': 'USA', 'BillingPostalCode': '2113', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf287'), 'InvoiceId': 61, 'CustomerId': 32, 'InvoiceDate': datetime.datetime(2009, 9, 16, 0, 0), 'BillingAddress': '696 Osborne Street', 'BillingCity': 'Winnipeg', 'BillingState': 'MB', 'BillingCountry': 'Canada', 'BillingPostalCode': 'R3L 2B9', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf288'), 'InvoiceId': 62, 'CustomerId': 46, 'InvoiceDate': datetime.datetime(2009, 9, 24, 0, 0), 'BillingAddress': '3 Chatham Street', 'BillingCity': 'Dublin', 'BillingState': 'Dublin', 'BillingCountry': 'Ireland', 'BillingPostalCode': None, 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf289'), 'InvoiceId': 63, 'CustomerId': 47, 'InvoiceDate': datetime.datetime(2009, 10, 7, 0, 0), 'BillingAddress': 'Via Degli Scipioni, 43', 'BillingCity': 'Rome', 'BillingState': 'RM', 'BillingCountry': 'Italy', 'BillingPostalCode': '00192', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf28a'), 'InvoiceId': 64, 'CustomerId': 49, 'InvoiceDate': datetime.datetime(2009, 10, 7, 0, 0), 'BillingAddress': 'Ordynacka 10', 'BillingCity': 'Warsaw', 'BillingState': None, 'BillingCountry': 'Poland', 'BillingPostalCode': '00-358', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf28b'), 'InvoiceId': 65, 'CustomerId': 51, 'InvoiceDate': datetime.datetime(2009, 10, 8, 0, 0), 'BillingAddress': 'Celsiusg. 9', 'BillingCity': 'Stockholm', 'BillingState': None, 'BillingCountry': 'Sweden', 'BillingPostalCode': '11230', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf28c'), 'InvoiceId': 66, 'CustomerId': 55, 'InvoiceDate': datetime.datetime(2009, 10, 9, 0, 0), 'BillingAddress': '421 Bourke Street', 'BillingCity': 'Sidney', 'BillingState': 'NSW', 'BillingCountry': 'Australia', 'BillingPostalCode': '2010', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf28d'), 'InvoiceId': 67, 'CustomerId': 2, 'InvoiceDate': datetime.datetime(2009, 10, 12, 0, 0), 'BillingAddress': 'Theodor-Heuss-Straße 34', 'BillingCity': 'Stuttgart', 'BillingState': None, 'BillingCountry': 'Germany', 'BillingPostalCode': '70174', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf28e'), 'InvoiceId': 68, 'CustomerId': 11, 'InvoiceDate': datetime.datetime(2009, 10, 17, 0, 0), 'BillingAddress': 'Av. Paulista, 2022', 'BillingCity': 'São Paulo', 'BillingState': 'SP', 'BillingCountry': 'Brazil', 'BillingPostalCode': '01310-200', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf28f'), 'InvoiceId': 69, 'CustomerId': 25, 'InvoiceDate': datetime.datetime(2009, 10, 25, 0, 0), 'BillingAddress': '319 N. Frances Street', 'BillingCity': 'Madison', 'BillingState': 'WI', 'BillingCountry': 'USA', 'BillingPostalCode': '53703', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf290'), 'InvoiceId': 70, 'CustomerId': 26, 'InvoiceDate': datetime.datetime(2009, 11, 7, 0, 0), 'BillingAddress': '2211 W Berry Street', 'BillingCity': 'Fort Worth', 'BillingState': 'TX', 'BillingCountry': 'USA', 'BillingPostalCode': '76110', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf291'), 'InvoiceId': 71, 'CustomerId': 28, 'InvoiceDate': datetime.datetime(2009, 11, 7, 0, 0), 'BillingAddress': '302 S 700 E', 'BillingCity': 'Salt Lake City', 'BillingState': 'UT', 'BillingCountry': 'USA', 'BillingPostalCode': '84102', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf292'), 'InvoiceId': 72, 'CustomerId': 30, 'InvoiceDate': datetime.datetime(2009, 11, 8, 0, 0), 'BillingAddress': '230 Elgin Street', 'BillingCity': 'Ottawa', 'BillingState': 'ON', 'BillingCountry': 'Canada', 'BillingPostalCode': 'K2P 1L7', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf293'), 'InvoiceId': 73, 'CustomerId': 34, 'InvoiceDate': datetime.datetime(2009, 11, 9, 0, 0), 'BillingAddress': 'Rua da Assunção 53', 'BillingCity': 'Lisbon', 'BillingState': None, 'BillingCountry': 'Portugal', 'BillingPostalCode': None, 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf294'), 'InvoiceId': 74, 'CustomerId': 40, 'InvoiceDate': datetime.datetime(2009, 11, 12, 0, 0), 'BillingAddress': '8, Rue Hanovre', 'BillingCity': 'Paris', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '75002', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf295'), 'InvoiceId': 75, 'CustomerId': 49, 'InvoiceDate': datetime.datetime(2009, 11, 17, 0, 0), 'BillingAddress': 'Ordynacka 10', 'BillingCity': 'Warsaw', 'BillingState': None, 'BillingCountry': 'Poland', 'BillingPostalCode': '00-358', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf296'), 'InvoiceId': 76, 'CustomerId': 4, 'InvoiceDate': datetime.datetime(2009, 11, 25, 0, 0), 'BillingAddress': 'Ullevålsveien 14', 'BillingCity': 'Oslo', 'BillingState': None, 'BillingCountry': 'Norway', 'BillingPostalCode': '0171', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf297'), 'InvoiceId': 77, 'CustomerId': 5, 'InvoiceDate': datetime.datetime(2009, 12, 8, 0, 0), 'BillingAddress': 'Klanova 9/506', 'BillingCity': 'Prague', 'BillingState': None, 'BillingCountry': 'Czech Republic', 'BillingPostalCode': '14700', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf298'), 'InvoiceId': 78, 'CustomerId': 7, 'InvoiceDate': datetime.datetime(2009, 12, 8, 0, 0), 'BillingAddress': 'Rotenturmstraße 4, 1010 Innere Stadt', 'BillingCity': 'Vienne', 'BillingState': None, 'BillingCountry': 'Austria', 'BillingPostalCode': '1010', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf299'), 'InvoiceId': 79, 'CustomerId': 9, 'InvoiceDate': datetime.datetime(2009, 12, 9, 0, 0), 'BillingAddress': 'Sønder Boulevard 51', 'BillingCity': 'Copenhagen', 'BillingState': None, 'BillingCountry': 'Denmark', 'BillingPostalCode': '1720', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf29a'), 'InvoiceId': 80, 'CustomerId': 13, 'InvoiceDate': datetime.datetime(2009, 12, 10, 0, 0), 'BillingAddress': 'Qe 7 Bloco G', 'BillingCity': 'Brasília', 'BillingState': 'DF', 'BillingCountry': 'Brazil', 'BillingPostalCode': '71020-677', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf29b'), 'InvoiceId': 81, 'CustomerId': 19, 'InvoiceDate': datetime.datetime(2009, 12, 13, 0, 0), 'BillingAddress': '1 Infinite Loop', 'BillingCity': 'Cupertino', 'BillingState': 'CA', 'BillingCountry': 'USA', 'BillingPostalCode': '95014', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf29c'), 'InvoiceId': 82, 'CustomerId': 28, 'InvoiceDate': datetime.datetime(2009, 12, 18, 0, 0), 'BillingAddress': '302 S 700 E', 'BillingCity': 'Salt Lake City', 'BillingState': 'UT', 'BillingCountry': 'USA', 'BillingPostalCode': '84102', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf29d'), 'InvoiceId': 83, 'CustomerId': 42, 'InvoiceDate': datetime.datetime(2009, 12, 26, 0, 0), 'BillingAddress': '9, Place Louis Barthou', 'BillingCity': 'Bordeaux', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '33000', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf29e'), 'InvoiceId': 84, 'CustomerId': 43, 'InvoiceDate': datetime.datetime(2010, 1, 8, 0, 0), 'BillingAddress': '68, Rue Jouvence', 'BillingCity': 'Dijon', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '21000', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf29f'), 'InvoiceId': 85, 'CustomerId': 45, 'InvoiceDate': datetime.datetime(2010, 1, 8, 0, 0), 'BillingAddress': 'Erzsébet krt. 58.', 'BillingCity': 'Budapest', 'BillingState': None, 'BillingCountry': 'Hungary', 'BillingPostalCode': 'H-1073', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2a0'), 'InvoiceId': 86, 'CustomerId': 47, 'InvoiceDate': datetime.datetime(2010, 1, 9, 0, 0), 'BillingAddress': 'Via Degli Scipioni, 43', 'BillingCity': 'Rome', 'BillingState': 'RM', 'BillingCountry': 'Italy', 'BillingPostalCode': '00192', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2a1'), 'InvoiceId': 87, 'CustomerId': 51, 'InvoiceDate': datetime.datetime(2010, 1, 10, 0, 0), 'BillingAddress': 'Celsiusg. 9', 'BillingCity': 'Stockholm', 'BillingState': None, 'BillingCountry': 'Sweden', 'BillingPostalCode': '11230', 'Total': 6.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2a2'), 'InvoiceId': 88, 'CustomerId': 57, 'InvoiceDate': datetime.datetime(2010, 1, 13, 0, 0), 'BillingAddress': 'Calle Lira, 198', 'BillingCity': 'Santiago', 'BillingState': None, 'BillingCountry': 'Chile', 'BillingPostalCode': None, 'Total': 17.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2a3'), 'InvoiceId': 89, 'CustomerId': 7, 'InvoiceDate': datetime.datetime(2010, 1, 18, 0, 0), 'BillingAddress': 'Rotenturmstraße 4, 1010 Innere Stadt', 'BillingCity': 'Vienne', 'BillingState': None, 'BillingCountry': 'Austria', 'BillingPostalCode': '1010', 'Total': 18.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2a4'), 'InvoiceId': 90, 'CustomerId': 21, 'InvoiceDate': datetime.datetime(2010, 1, 26, 0, 0), 'BillingAddress': '801 W 4th Street', 'BillingCity': 'Reno', 'BillingState': 'NV', 'BillingCountry': 'USA', 'BillingPostalCode': '89503', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2a5'), 'InvoiceId': 91, 'CustomerId': 22, 'InvoiceDate': datetime.datetime(2010, 2, 8, 0, 0), 'BillingAddress': '120 S Orange Ave', 'BillingCity': 'Orlando', 'BillingState': 'FL', 'BillingCountry': 'USA', 'BillingPostalCode': '32801', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2a6'), 'InvoiceId': 92, 'CustomerId': 24, 'InvoiceDate': datetime.datetime(2010, 2, 8, 0, 0), 'BillingAddress': '162 E Superior Street', 'BillingCity': 'Chicago', 'BillingState': 'IL', 'BillingCountry': 'USA', 'BillingPostalCode': '60611', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2a7'), 'InvoiceId': 93, 'CustomerId': 26, 'InvoiceDate': datetime.datetime(2010, 2, 9, 0, 0), 'BillingAddress': '2211 W Berry Street', 'BillingCity': 'Fort Worth', 'BillingState': 'TX', 'BillingCountry': 'USA', 'BillingPostalCode': '76110', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2a8'), 'InvoiceId': 94, 'CustomerId': 30, 'InvoiceDate': datetime.datetime(2010, 2, 10, 0, 0), 'BillingAddress': '230 Elgin Street', 'BillingCity': 'Ottawa', 'BillingState': 'ON', 'BillingCountry': 'Canada', 'BillingPostalCode': 'K2P 1L7', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2a9'), 'InvoiceId': 95, 'CustomerId': 36, 'InvoiceDate': datetime.datetime(2010, 2, 13, 0, 0), 'BillingAddress': 'Tauentzienstraße 8', 'BillingCity': 'Berlin', 'BillingState': None, 'BillingCountry': 'Germany', 'BillingPostalCode': '10789', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2aa'), 'InvoiceId': 96, 'CustomerId': 45, 'InvoiceDate': datetime.datetime(2010, 2, 18, 0, 0), 'BillingAddress': 'Erzsébet krt. 58.', 'BillingCity': 'Budapest', 'BillingState': None, 'BillingCountry': 'Hungary', 'BillingPostalCode': 'H-1073', 'Total': 21.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2ab'), 'InvoiceId': 97, 'CustomerId': 59, 'InvoiceDate': datetime.datetime(2010, 2, 26, 0, 0), 'BillingAddress': '3,Raj Bhavan Road', 'BillingCity': 'Bangalore', 'BillingState': None, 'BillingCountry': 'India', 'BillingPostalCode': '560001', 'Total': 1.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2ac'), 'InvoiceId': 98, 'CustomerId': 1, 'InvoiceDate': datetime.datetime(2010, 3, 11, 0, 0), 'BillingAddress': 'Av. Brigadeiro Faria Lima, 2170', 'BillingCity': 'São José dos Campos', 'BillingState': 'SP', 'BillingCountry': 'Brazil', 'BillingPostalCode': '12227-000', 'Total': 3.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2ad'), 'InvoiceId': 99, 'CustomerId': 3, 'InvoiceDate': datetime.datetime(2010, 3, 11, 0, 0), 'BillingAddress': '1498 rue Bélanger', 'BillingCity': 'Montréal', 'BillingState': 'QC', 'BillingCountry': 'Canada', 'BillingPostalCode': 'H2G 1A7', 'Total': 3.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2ae'), 'InvoiceId': 100, 'CustomerId': 5, 'InvoiceDate': datetime.datetime(2010, 3, 12, 0, 0), 'BillingAddress': 'Klanova 9/506', 'BillingCity': 'Prague', 'BillingState': None, 'BillingCountry': 'Czech Republic', 'BillingPostalCode': '14700', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2af'), 'InvoiceId': 101, 'CustomerId': 9, 'InvoiceDate': datetime.datetime(2010, 3, 13, 0, 0), 'BillingAddress': 'Sønder Boulevard 51', 'BillingCity': 'Copenhagen', 'BillingState': None, 'BillingCountry': 'Denmark', 'BillingPostalCode': '1720', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2b0'), 'InvoiceId': 102, 'CustomerId': 15, 'InvoiceDate': datetime.datetime(2010, 3, 16, 0, 0), 'BillingAddress': '700 W Pender Street', 'BillingCity': 'Vancouver', 'BillingState': 'BC', 'BillingCountry': 'Canada', 'BillingPostalCode': 'V6C 1G8', 'Total': 9.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2b1'), 'InvoiceId': 103, 'CustomerId': 24, 'InvoiceDate': datetime.datetime(2010, 3, 21, 0, 0), 'BillingAddress': '162 E Superior Street', 'BillingCity': 'Chicago', 'BillingState': 'IL', 'BillingCountry': 'USA', 'BillingPostalCode': '60611', 'Total': 15.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2b2'), 'InvoiceId': 104, 'CustomerId': 38, 'InvoiceDate': datetime.datetime(2010, 3, 29, 0, 0), 'BillingAddress': 'Barbarossastraße 19', 'BillingCity': 'Berlin', 'BillingState': None, 'BillingCountry': 'Germany', 'BillingPostalCode': '10779', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2b3'), 'InvoiceId': 105, 'CustomerId': 39, 'InvoiceDate': datetime.datetime(2010, 4, 11, 0, 0), 'BillingAddress': '4, Rue Milton', 'BillingCity': 'Paris', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '75009', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2b4'), 'InvoiceId': 106, 'CustomerId': 41, 'InvoiceDate': datetime.datetime(2010, 4, 11, 0, 0), 'BillingAddress': '11, Place Bellecour', 'BillingCity': 'Lyon', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '69002', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2b5'), 'InvoiceId': 107, 'CustomerId': 43, 'InvoiceDate': datetime.datetime(2010, 4, 12, 0, 0), 'BillingAddress': '68, Rue Jouvence', 'BillingCity': 'Dijon', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '21000', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2b6'), 'InvoiceId': 108, 'CustomerId': 47, 'InvoiceDate': datetime.datetime(2010, 4, 13, 0, 0), 'BillingAddress': 'Via Degli Scipioni, 43', 'BillingCity': 'Rome', 'BillingState': 'RM', 'BillingCountry': 'Italy', 'BillingPostalCode': '00192', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2b7'), 'InvoiceId': 109, 'CustomerId': 53, 'InvoiceDate': datetime.datetime(2010, 4, 16, 0, 0), 'BillingAddress': '113 Lupus St', 'BillingCity': 'London', 'BillingState': None, 'BillingCountry': 'United Kingdom', 'BillingPostalCode': 'SW1V 3EN', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2b8'), 'InvoiceId': 110, 'CustomerId': 3, 'InvoiceDate': datetime.datetime(2010, 4, 21, 0, 0), 'BillingAddress': '1498 rue Bélanger', 'BillingCity': 'Montréal', 'BillingState': 'QC', 'BillingCountry': 'Canada', 'BillingPostalCode': 'H2G 1A7', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2b9'), 'InvoiceId': 111, 'CustomerId': 17, 'InvoiceDate': datetime.datetime(2010, 4, 29, 0, 0), 'BillingAddress': '1 Microsoft Way', 'BillingCity': 'Redmond', 'BillingState': 'WA', 'BillingCountry': 'USA', 'BillingPostalCode': '98052-8300', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2ba'), 'InvoiceId': 112, 'CustomerId': 18, 'InvoiceDate': datetime.datetime(2010, 5, 12, 0, 0), 'BillingAddress': '627 Broadway', 'BillingCity': 'New York', 'BillingState': 'NY', 'BillingCountry': 'USA', 'BillingPostalCode': '10012-2612', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2bb'), 'InvoiceId': 113, 'CustomerId': 20, 'InvoiceDate': datetime.datetime(2010, 5, 12, 0, 0), 'BillingAddress': '541 Del Medio Avenue', 'BillingCity': 'Mountain View', 'BillingState': 'CA', 'BillingCountry': 'USA', 'BillingPostalCode': '94040-111', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2bc'), 'InvoiceId': 114, 'CustomerId': 22, 'InvoiceDate': datetime.datetime(2010, 5, 13, 0, 0), 'BillingAddress': '120 S Orange Ave', 'BillingCity': 'Orlando', 'BillingState': 'FL', 'BillingCountry': 'USA', 'BillingPostalCode': '32801', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2bd'), 'InvoiceId': 115, 'CustomerId': 26, 'InvoiceDate': datetime.datetime(2010, 5, 14, 0, 0), 'BillingAddress': '2211 W Berry Street', 'BillingCity': 'Fort Worth', 'BillingState': 'TX', 'BillingCountry': 'USA', 'BillingPostalCode': '76110', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2be'), 'InvoiceId': 116, 'CustomerId': 32, 'InvoiceDate': datetime.datetime(2010, 5, 17, 0, 0), 'BillingAddress': '696 Osborne Street', 'BillingCity': 'Winnipeg', 'BillingState': 'MB', 'BillingCountry': 'Canada', 'BillingPostalCode': 'R3L 2B9', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2bf'), 'InvoiceId': 117, 'CustomerId': 41, 'InvoiceDate': datetime.datetime(2010, 5, 22, 0, 0), 'BillingAddress': '11, Place Bellecour', 'BillingCity': 'Lyon', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '69002', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2c0'), 'InvoiceId': 118, 'CustomerId': 55, 'InvoiceDate': datetime.datetime(2010, 5, 30, 0, 0), 'BillingAddress': '421 Bourke Street', 'BillingCity': 'Sidney', 'BillingState': 'NSW', 'BillingCountry': 'Australia', 'BillingPostalCode': '2010', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2c1'), 'InvoiceId': 119, 'CustomerId': 56, 'InvoiceDate': datetime.datetime(2010, 6, 12, 0, 0), 'BillingAddress': '307 Macacha Güemes', 'BillingCity': 'Buenos Aires', 'BillingState': None, 'BillingCountry': 'Argentina', 'BillingPostalCode': '1106', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2c2'), 'InvoiceId': 120, 'CustomerId': 58, 'InvoiceDate': datetime.datetime(2010, 6, 12, 0, 0), 'BillingAddress': '12,Community Centre', 'BillingCity': 'Delhi', 'BillingState': None, 'BillingCountry': 'India', 'BillingPostalCode': '110017', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2c3'), 'InvoiceId': 121, 'CustomerId': 1, 'InvoiceDate': datetime.datetime(2010, 6, 13, 0, 0), 'BillingAddress': 'Av. Brigadeiro Faria Lima, 2170', 'BillingCity': 'São José dos Campos', 'BillingState': 'SP', 'BillingCountry': 'Brazil', 'BillingPostalCode': '12227-000', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2c4'), 'InvoiceId': 122, 'CustomerId': 5, 'InvoiceDate': datetime.datetime(2010, 6, 14, 0, 0), 'BillingAddress': 'Klanova 9/506', 'BillingCity': 'Prague', 'BillingState': None, 'BillingCountry': 'Czech Republic', 'BillingPostalCode': '14700', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2c5'), 'InvoiceId': 123, 'CustomerId': 11, 'InvoiceDate': datetime.datetime(2010, 6, 17, 0, 0), 'BillingAddress': 'Av. Paulista, 2022', 'BillingCity': 'São Paulo', 'BillingState': 'SP', 'BillingCountry': 'Brazil', 'BillingPostalCode': '01310-200', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2c6'), 'InvoiceId': 124, 'CustomerId': 20, 'InvoiceDate': datetime.datetime(2010, 6, 22, 0, 0), 'BillingAddress': '541 Del Medio Avenue', 'BillingCity': 'Mountain View', 'BillingState': 'CA', 'BillingCountry': 'USA', 'BillingPostalCode': '94040-111', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2c7'), 'InvoiceId': 125, 'CustomerId': 34, 'InvoiceDate': datetime.datetime(2010, 6, 30, 0, 0), 'BillingAddress': 'Rua da Assunção 53', 'BillingCity': 'Lisbon', 'BillingState': None, 'BillingCountry': 'Portugal', 'BillingPostalCode': None, 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2c8'), 'InvoiceId': 126, 'CustomerId': 35, 'InvoiceDate': datetime.datetime(2010, 7, 13, 0, 0), 'BillingAddress': 'Rua dos Campeões Europeus de Viena, 4350', 'BillingCity': 'Porto', 'BillingState': None, 'BillingCountry': 'Portugal', 'BillingPostalCode': None, 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2c9'), 'InvoiceId': 127, 'CustomerId': 37, 'InvoiceDate': datetime.datetime(2010, 7, 13, 0, 0), 'BillingAddress': 'Berger Straße 10', 'BillingCity': 'Frankfurt', 'BillingState': None, 'BillingCountry': 'Germany', 'BillingPostalCode': '60316', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2ca'), 'InvoiceId': 128, 'CustomerId': 39, 'InvoiceDate': datetime.datetime(2010, 7, 14, 0, 0), 'BillingAddress': '4, Rue Milton', 'BillingCity': 'Paris', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '75009', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2cb'), 'InvoiceId': 129, 'CustomerId': 43, 'InvoiceDate': datetime.datetime(2010, 7, 15, 0, 0), 'BillingAddress': '68, Rue Jouvence', 'BillingCity': 'Dijon', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '21000', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2cc'), 'InvoiceId': 130, 'CustomerId': 49, 'InvoiceDate': datetime.datetime(2010, 7, 18, 0, 0), 'BillingAddress': 'Ordynacka 10', 'BillingCity': 'Warsaw', 'BillingState': None, 'BillingCountry': 'Poland', 'BillingPostalCode': '00-358', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2cd'), 'InvoiceId': 131, 'CustomerId': 58, 'InvoiceDate': datetime.datetime(2010, 7, 23, 0, 0), 'BillingAddress': '12,Community Centre', 'BillingCity': 'Delhi', 'BillingState': None, 'BillingCountry': 'India', 'BillingPostalCode': '110017', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2ce'), 'InvoiceId': 132, 'CustomerId': 13, 'InvoiceDate': datetime.datetime(2010, 7, 31, 0, 0), 'BillingAddress': 'Qe 7 Bloco G', 'BillingCity': 'Brasília', 'BillingState': 'DF', 'BillingCountry': 'Brazil', 'BillingPostalCode': '71020-677', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2cf'), 'InvoiceId': 133, 'CustomerId': 14, 'InvoiceDate': datetime.datetime(2010, 8, 13, 0, 0), 'BillingAddress': '8210 111 ST NW', 'BillingCity': 'Edmonton', 'BillingState': 'AB', 'BillingCountry': 'Canada', 'BillingPostalCode': 'T6G 2C7', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2d0'), 'InvoiceId': 134, 'CustomerId': 16, 'InvoiceDate': datetime.datetime(2010, 8, 13, 0, 0), 'BillingAddress': '1600 Amphitheatre Parkway', 'BillingCity': 'Mountain View', 'BillingState': 'CA', 'BillingCountry': 'USA', 'BillingPostalCode': '94043-1351', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2d1'), 'InvoiceId': 135, 'CustomerId': 18, 'InvoiceDate': datetime.datetime(2010, 8, 14, 0, 0), 'BillingAddress': '627 Broadway', 'BillingCity': 'New York', 'BillingState': 'NY', 'BillingCountry': 'USA', 'BillingPostalCode': '10012-2612', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2d2'), 'InvoiceId': 136, 'CustomerId': 22, 'InvoiceDate': datetime.datetime(2010, 8, 15, 0, 0), 'BillingAddress': '120 S Orange Ave', 'BillingCity': 'Orlando', 'BillingState': 'FL', 'BillingCountry': 'USA', 'BillingPostalCode': '32801', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2d3'), 'InvoiceId': 137, 'CustomerId': 28, 'InvoiceDate': datetime.datetime(2010, 8, 18, 0, 0), 'BillingAddress': '302 S 700 E', 'BillingCity': 'Salt Lake City', 'BillingState': 'UT', 'BillingCountry': 'USA', 'BillingPostalCode': '84102', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2d4'), 'InvoiceId': 138, 'CustomerId': 37, 'InvoiceDate': datetime.datetime(2010, 8, 23, 0, 0), 'BillingAddress': 'Berger Straße 10', 'BillingCity': 'Frankfurt', 'BillingState': None, 'BillingCountry': 'Germany', 'BillingPostalCode': '60316', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2d5'), 'InvoiceId': 139, 'CustomerId': 51, 'InvoiceDate': datetime.datetime(2010, 8, 31, 0, 0), 'BillingAddress': 'Celsiusg. 9', 'BillingCity': 'Stockholm', 'BillingState': None, 'BillingCountry': 'Sweden', 'BillingPostalCode': '11230', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2d6'), 'InvoiceId': 140, 'CustomerId': 52, 'InvoiceDate': datetime.datetime(2010, 9, 13, 0, 0), 'BillingAddress': '202 Hoxton Street', 'BillingCity': 'London', 'BillingState': None, 'BillingCountry': 'United Kingdom', 'BillingPostalCode': 'N1 5LH', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2d7'), 'InvoiceId': 141, 'CustomerId': 54, 'InvoiceDate': datetime.datetime(2010, 9, 13, 0, 0), 'BillingAddress': '110 Raeburn Pl', 'BillingCity': 'Edinburgh', 'BillingState': None, 'BillingCountry': 'United Kingdom', 'BillingPostalCode': 'EH4 1HH', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2d8'), 'InvoiceId': 142, 'CustomerId': 56, 'InvoiceDate': datetime.datetime(2010, 9, 14, 0, 0), 'BillingAddress': '307 Macacha Güemes', 'BillingCity': 'Buenos Aires', 'BillingState': None, 'BillingCountry': 'Argentina', 'BillingPostalCode': '1106', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2d9'), 'InvoiceId': 143, 'CustomerId': 1, 'InvoiceDate': datetime.datetime(2010, 9, 15, 0, 0), 'BillingAddress': 'Av. Brigadeiro Faria Lima, 2170', 'BillingCity': 'São José dos Campos', 'BillingState': 'SP', 'BillingCountry': 'Brazil', 'BillingPostalCode': '12227-000', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2da'), 'InvoiceId': 144, 'CustomerId': 7, 'InvoiceDate': datetime.datetime(2010, 9, 18, 0, 0), 'BillingAddress': 'Rotenturmstraße 4, 1010 Innere Stadt', 'BillingCity': 'Vienne', 'BillingState': None, 'BillingCountry': 'Austria', 'BillingPostalCode': '1010', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2db'), 'InvoiceId': 145, 'CustomerId': 16, 'InvoiceDate': datetime.datetime(2010, 9, 23, 0, 0), 'BillingAddress': '1600 Amphitheatre Parkway', 'BillingCity': 'Mountain View', 'BillingState': 'CA', 'BillingCountry': 'USA', 'BillingPostalCode': '94043-1351', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2dc'), 'InvoiceId': 146, 'CustomerId': 30, 'InvoiceDate': datetime.datetime(2010, 10, 1, 0, 0), 'BillingAddress': '230 Elgin Street', 'BillingCity': 'Ottawa', 'BillingState': 'ON', 'BillingCountry': 'Canada', 'BillingPostalCode': 'K2P 1L7', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2dd'), 'InvoiceId': 147, 'CustomerId': 31, 'InvoiceDate': datetime.datetime(2010, 10, 14, 0, 0), 'BillingAddress': '194A Chain Lake Drive', 'BillingCity': 'Halifax', 'BillingState': 'NS', 'BillingCountry': 'Canada', 'BillingPostalCode': 'B3S 1C5', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2de'), 'InvoiceId': 148, 'CustomerId': 33, 'InvoiceDate': datetime.datetime(2010, 10, 14, 0, 0), 'BillingAddress': '5112 48 Street', 'BillingCity': 'Yellowknife', 'BillingState': 'NT', 'BillingCountry': 'Canada', 'BillingPostalCode': 'X1A 1N6', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2df'), 'InvoiceId': 149, 'CustomerId': 35, 'InvoiceDate': datetime.datetime(2010, 10, 15, 0, 0), 'BillingAddress': 'Rua dos Campeões Europeus de Viena, 4350', 'BillingCity': 'Porto', 'BillingState': None, 'BillingCountry': 'Portugal', 'BillingPostalCode': None, 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2e0'), 'InvoiceId': 150, 'CustomerId': 39, 'InvoiceDate': datetime.datetime(2010, 10, 16, 0, 0), 'BillingAddress': '4, Rue Milton', 'BillingCity': 'Paris', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '75009', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2e1'), 'InvoiceId': 151, 'CustomerId': 45, 'InvoiceDate': datetime.datetime(2010, 10, 19, 0, 0), 'BillingAddress': 'Erzsébet krt. 58.', 'BillingCity': 'Budapest', 'BillingState': None, 'BillingCountry': 'Hungary', 'BillingPostalCode': 'H-1073', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2e2'), 'InvoiceId': 152, 'CustomerId': 54, 'InvoiceDate': datetime.datetime(2010, 10, 24, 0, 0), 'BillingAddress': '110 Raeburn Pl', 'BillingCity': 'Edinburgh', 'BillingState': None, 'BillingCountry': 'United Kingdom', 'BillingPostalCode': 'EH4 1HH', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2e3'), 'InvoiceId': 153, 'CustomerId': 9, 'InvoiceDate': datetime.datetime(2010, 11, 1, 0, 0), 'BillingAddress': 'Sønder Boulevard 51', 'BillingCity': 'Copenhagen', 'BillingState': None, 'BillingCountry': 'Denmark', 'BillingPostalCode': '1720', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2e4'), 'InvoiceId': 154, 'CustomerId': 10, 'InvoiceDate': datetime.datetime(2010, 11, 14, 0, 0), 'BillingAddress': 'Rua Dr. Falcão Filho, 155', 'BillingCity': 'São Paulo', 'BillingState': 'SP', 'BillingCountry': 'Brazil', 'BillingPostalCode': '01007-010', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2e5'), 'InvoiceId': 155, 'CustomerId': 12, 'InvoiceDate': datetime.datetime(2010, 11, 14, 0, 0), 'BillingAddress': 'Praça Pio X, 119', 'BillingCity': 'Rio de Janeiro', 'BillingState': 'RJ', 'BillingCountry': 'Brazil', 'BillingPostalCode': '20040-020', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2e6'), 'InvoiceId': 156, 'CustomerId': 14, 'InvoiceDate': datetime.datetime(2010, 11, 15, 0, 0), 'BillingAddress': '8210 111 ST NW', 'BillingCity': 'Edmonton', 'BillingState': 'AB', 'BillingCountry': 'Canada', 'BillingPostalCode': 'T6G 2C7', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2e7'), 'InvoiceId': 157, 'CustomerId': 18, 'InvoiceDate': datetime.datetime(2010, 11, 16, 0, 0), 'BillingAddress': '627 Broadway', 'BillingCity': 'New York', 'BillingState': 'NY', 'BillingCountry': 'USA', 'BillingPostalCode': '10012-2612', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2e8'), 'InvoiceId': 158, 'CustomerId': 24, 'InvoiceDate': datetime.datetime(2010, 11, 19, 0, 0), 'BillingAddress': '162 E Superior Street', 'BillingCity': 'Chicago', 'BillingState': 'IL', 'BillingCountry': 'USA', 'BillingPostalCode': '60611', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2e9'), 'InvoiceId': 159, 'CustomerId': 33, 'InvoiceDate': datetime.datetime(2010, 11, 24, 0, 0), 'BillingAddress': '5112 48 Street', 'BillingCity': 'Yellowknife', 'BillingState': 'NT', 'BillingCountry': 'Canada', 'BillingPostalCode': 'X1A 1N6', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2ea'), 'InvoiceId': 160, 'CustomerId': 47, 'InvoiceDate': datetime.datetime(2010, 12, 2, 0, 0), 'BillingAddress': 'Via Degli Scipioni, 43', 'BillingCity': 'Rome', 'BillingState': 'RM', 'BillingCountry': 'Italy', 'BillingPostalCode': '00192', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf2eb'), 'InvoiceId': 161, 'CustomerId': 48, 'InvoiceDate': datetime.datetime(2010, 12, 15, 0, 0), 'BillingAddress': 'Lijnbaansgracht 120bg', 'BillingCity': 'Amsterdam', 'BillingState': 'VV', 'BillingCountry': 'Netherlands', 'BillingPostalCode': '1016', 'Total': 1.98}
# ...
# {'_id': ObjectId('6081e178d46ebf23e5ecf3b2'), 'InvoiceId': 360, 'CustomerId': 58, 'InvoiceDate': datetime.datetime(2013, 5, 3, 0, 0), 'BillingAddress': '12,Community Centre', 'BillingCity': 'Delhi', 'BillingState': None, 'BillingCountry': 'India', 'BillingPostalCode': '110017', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3b3'), 'InvoiceId': 361, 'CustomerId': 5, 'InvoiceDate': datetime.datetime(2013, 5, 6, 0, 0), 'BillingAddress': 'Klanova 9/506', 'BillingCity': 'Prague', 'BillingState': None, 'BillingCountry': 'Czech Republic', 'BillingPostalCode': '14700', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3b4'), 'InvoiceId': 362, 'CustomerId': 14, 'InvoiceDate': datetime.datetime(2013, 5, 11, 0, 0), 'BillingAddress': '8210 111 ST NW', 'BillingCity': 'Edmonton', 'BillingState': 'AB', 'BillingCountry': 'Canada', 'BillingPostalCode': 'T6G 2C7', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3b5'), 'InvoiceId': 363, 'CustomerId': 28, 'InvoiceDate': datetime.datetime(2013, 5, 19, 0, 0), 'BillingAddress': '302 S 700 E', 'BillingCity': 'Salt Lake City', 'BillingState': 'UT', 'BillingCountry': 'USA', 'BillingPostalCode': '84102', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3b6'), 'InvoiceId': 364, 'CustomerId': 29, 'InvoiceDate': datetime.datetime(2013, 6, 1, 0, 0), 'BillingAddress': '796 Dundas Street West', 'BillingCity': 'Toronto', 'BillingState': 'ON', 'BillingCountry': 'Canada', 'BillingPostalCode': 'M6J 1V1', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3b7'), 'InvoiceId': 365, 'CustomerId': 31, 'InvoiceDate': datetime.datetime(2013, 6, 1, 0, 0), 'BillingAddress': '194A Chain Lake Drive', 'BillingCity': 'Halifax', 'BillingState': 'NS', 'BillingCountry': 'Canada', 'BillingPostalCode': 'B3S 1C5', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3b8'), 'InvoiceId': 366, 'CustomerId': 33, 'InvoiceDate': datetime.datetime(2013, 6, 2, 0, 0), 'BillingAddress': '5112 48 Street', 'BillingCity': 'Yellowknife', 'BillingState': 'NT', 'BillingCountry': 'Canada', 'BillingPostalCode': 'X1A 1N6', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3b9'), 'InvoiceId': 367, 'CustomerId': 37, 'InvoiceDate': datetime.datetime(2013, 6, 3, 0, 0), 'BillingAddress': 'Berger Straße 10', 'BillingCity': 'Frankfurt', 'BillingState': None, 'BillingCountry': 'Germany', 'BillingPostalCode': '60316', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3ba'), 'InvoiceId': 368, 'CustomerId': 43, 'InvoiceDate': datetime.datetime(2013, 6, 6, 0, 0), 'BillingAddress': '68, Rue Jouvence', 'BillingCity': 'Dijon', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '21000', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3bb'), 'InvoiceId': 369, 'CustomerId': 52, 'InvoiceDate': datetime.datetime(2013, 6, 11, 0, 0), 'BillingAddress': '202 Hoxton Street', 'BillingCity': 'London', 'BillingState': None, 'BillingCountry': 'United Kingdom', 'BillingPostalCode': 'N1 5LH', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3bc'), 'InvoiceId': 370, 'CustomerId': 7, 'InvoiceDate': datetime.datetime(2013, 6, 19, 0, 0), 'BillingAddress': 'Rotenturmstraße 4, 1010 Innere Stadt', 'BillingCity': 'Vienne', 'BillingState': None, 'BillingCountry': 'Austria', 'BillingPostalCode': '1010', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3bd'), 'InvoiceId': 371, 'CustomerId': 8, 'InvoiceDate': datetime.datetime(2013, 7, 2, 0, 0), 'BillingAddress': 'Grétrystraat 63', 'BillingCity': 'Brussels', 'BillingState': None, 'BillingCountry': 'Belgium', 'BillingPostalCode': '1000', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3be'), 'InvoiceId': 372, 'CustomerId': 10, 'InvoiceDate': datetime.datetime(2013, 7, 2, 0, 0), 'BillingAddress': 'Rua Dr. Falcão Filho, 155', 'BillingCity': 'São Paulo', 'BillingState': 'SP', 'BillingCountry': 'Brazil', 'BillingPostalCode': '01007-010', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3bf'), 'InvoiceId': 373, 'CustomerId': 12, 'InvoiceDate': datetime.datetime(2013, 7, 3, 0, 0), 'BillingAddress': 'Praça Pio X, 119', 'BillingCity': 'Rio de Janeiro', 'BillingState': 'RJ', 'BillingCountry': 'Brazil', 'BillingPostalCode': '20040-020', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3c0'), 'InvoiceId': 374, 'CustomerId': 16, 'InvoiceDate': datetime.datetime(2013, 7, 4, 0, 0), 'BillingAddress': '1600 Amphitheatre Parkway', 'BillingCity': 'Mountain View', 'BillingState': 'CA', 'BillingCountry': 'USA', 'BillingPostalCode': '94043-1351', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3c1'), 'InvoiceId': 375, 'CustomerId': 22, 'InvoiceDate': datetime.datetime(2013, 7, 7, 0, 0), 'BillingAddress': '120 S Orange Ave', 'BillingCity': 'Orlando', 'BillingState': 'FL', 'BillingCountry': 'USA', 'BillingPostalCode': '32801', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3c2'), 'InvoiceId': 376, 'CustomerId': 31, 'InvoiceDate': datetime.datetime(2013, 7, 12, 0, 0), 'BillingAddress': '194A Chain Lake Drive', 'BillingCity': 'Halifax', 'BillingState': 'NS', 'BillingCountry': 'Canada', 'BillingPostalCode': 'B3S 1C5', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3c3'), 'InvoiceId': 377, 'CustomerId': 45, 'InvoiceDate': datetime.datetime(2013, 7, 20, 0, 0), 'BillingAddress': 'Erzsébet krt. 58.', 'BillingCity': 'Budapest', 'BillingState': None, 'BillingCountry': 'Hungary', 'BillingPostalCode': 'H-1073', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3c4'), 'InvoiceId': 378, 'CustomerId': 46, 'InvoiceDate': datetime.datetime(2013, 8, 2, 0, 0), 'BillingAddress': '3 Chatham Street', 'BillingCity': 'Dublin', 'BillingState': 'Dublin', 'BillingCountry': 'Ireland', 'BillingPostalCode': None, 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3c5'), 'InvoiceId': 379, 'CustomerId': 48, 'InvoiceDate': datetime.datetime(2013, 8, 2, 0, 0), 'BillingAddress': 'Lijnbaansgracht 120bg', 'BillingCity': 'Amsterdam', 'BillingState': 'VV', 'BillingCountry': 'Netherlands', 'BillingPostalCode': '1016', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3c6'), 'InvoiceId': 380, 'CustomerId': 50, 'InvoiceDate': datetime.datetime(2013, 8, 3, 0, 0), 'BillingAddress': 'C/ San Bernardo 85', 'BillingCity': 'Madrid', 'BillingState': None, 'BillingCountry': 'Spain', 'BillingPostalCode': '28015', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3c7'), 'InvoiceId': 381, 'CustomerId': 54, 'InvoiceDate': datetime.datetime(2013, 8, 4, 0, 0), 'BillingAddress': '110 Raeburn Pl', 'BillingCity': 'Edinburgh', 'BillingState': None, 'BillingCountry': 'United Kingdom', 'BillingPostalCode': 'EH4 1HH', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3c8'), 'InvoiceId': 382, 'CustomerId': 1, 'InvoiceDate': datetime.datetime(2013, 8, 7, 0, 0), 'BillingAddress': 'Av. Brigadeiro Faria Lima, 2170', 'BillingCity': 'São José dos Campos', 'BillingState': 'SP', 'BillingCountry': 'Brazil', 'BillingPostalCode': '12227-000', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3c9'), 'InvoiceId': 383, 'CustomerId': 10, 'InvoiceDate': datetime.datetime(2013, 8, 12, 0, 0), 'BillingAddress': 'Rua Dr. Falcão Filho, 155', 'BillingCity': 'São Paulo', 'BillingState': 'SP', 'BillingCountry': 'Brazil', 'BillingPostalCode': '01007-010', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3ca'), 'InvoiceId': 384, 'CustomerId': 24, 'InvoiceDate': datetime.datetime(2013, 8, 20, 0, 0), 'BillingAddress': '162 E Superior Street', 'BillingCity': 'Chicago', 'BillingState': 'IL', 'BillingCountry': 'USA', 'BillingPostalCode': '60611', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3cb'), 'InvoiceId': 385, 'CustomerId': 25, 'InvoiceDate': datetime.datetime(2013, 9, 2, 0, 0), 'BillingAddress': '319 N. Frances Street', 'BillingCity': 'Madison', 'BillingState': 'WI', 'BillingCountry': 'USA', 'BillingPostalCode': '53703', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3cc'), 'InvoiceId': 386, 'CustomerId': 27, 'InvoiceDate': datetime.datetime(2013, 9, 2, 0, 0), 'BillingAddress': '1033 N Park Ave', 'BillingCity': 'Tucson', 'BillingState': 'AZ', 'BillingCountry': 'USA', 'BillingPostalCode': '85719', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3cd'), 'InvoiceId': 387, 'CustomerId': 29, 'InvoiceDate': datetime.datetime(2013, 9, 3, 0, 0), 'BillingAddress': '796 Dundas Street West', 'BillingCity': 'Toronto', 'BillingState': 'ON', 'BillingCountry': 'Canada', 'BillingPostalCode': 'M6J 1V1', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3ce'), 'InvoiceId': 388, 'CustomerId': 33, 'InvoiceDate': datetime.datetime(2013, 9, 4, 0, 0), 'BillingAddress': '5112 48 Street', 'BillingCity': 'Yellowknife', 'BillingState': 'NT', 'BillingCountry': 'Canada', 'BillingPostalCode': 'X1A 1N6', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3cf'), 'InvoiceId': 389, 'CustomerId': 39, 'InvoiceDate': datetime.datetime(2013, 9, 7, 0, 0), 'BillingAddress': '4, Rue Milton', 'BillingCity': 'Paris', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '75009', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3d0'), 'InvoiceId': 390, 'CustomerId': 48, 'InvoiceDate': datetime.datetime(2013, 9, 12, 0, 0), 'BillingAddress': 'Lijnbaansgracht 120bg', 'BillingCity': 'Amsterdam', 'BillingState': 'VV', 'BillingCountry': 'Netherlands', 'BillingPostalCode': '1016', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3d1'), 'InvoiceId': 391, 'CustomerId': 3, 'InvoiceDate': datetime.datetime(2013, 9, 20, 0, 0), 'BillingAddress': '1498 rue Bélanger', 'BillingCity': 'Montréal', 'BillingState': 'QC', 'BillingCountry': 'Canada', 'BillingPostalCode': 'H2G 1A7', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3d2'), 'InvoiceId': 392, 'CustomerId': 4, 'InvoiceDate': datetime.datetime(2013, 10, 3, 0, 0), 'BillingAddress': 'Ullevålsveien 14', 'BillingCity': 'Oslo', 'BillingState': None, 'BillingCountry': 'Norway', 'BillingPostalCode': '0171', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3d3'), 'InvoiceId': 393, 'CustomerId': 6, 'InvoiceDate': datetime.datetime(2013, 10, 3, 0, 0), 'BillingAddress': 'Rilská 3174/6', 'BillingCity': 'Prague', 'BillingState': None, 'BillingCountry': 'Czech Republic', 'BillingPostalCode': '14300', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3d4'), 'InvoiceId': 394, 'CustomerId': 8, 'InvoiceDate': datetime.datetime(2013, 10, 4, 0, 0), 'BillingAddress': 'Grétrystraat 63', 'BillingCity': 'Brussels', 'BillingState': None, 'BillingCountry': 'Belgium', 'BillingPostalCode': '1000', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3d5'), 'InvoiceId': 395, 'CustomerId': 12, 'InvoiceDate': datetime.datetime(2013, 10, 5, 0, 0), 'BillingAddress': 'Praça Pio X, 119', 'BillingCity': 'Rio de Janeiro', 'BillingState': 'RJ', 'BillingCountry': 'Brazil', 'BillingPostalCode': '20040-020', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3d6'), 'InvoiceId': 396, 'CustomerId': 18, 'InvoiceDate': datetime.datetime(2013, 10, 8, 0, 0), 'BillingAddress': '627 Broadway', 'BillingCity': 'New York', 'BillingState': 'NY', 'BillingCountry': 'USA', 'BillingPostalCode': '10012-2612', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3d7'), 'InvoiceId': 397, 'CustomerId': 27, 'InvoiceDate': datetime.datetime(2013, 10, 13, 0, 0), 'BillingAddress': '1033 N Park Ave', 'BillingCity': 'Tucson', 'BillingState': 'AZ', 'BillingCountry': 'USA', 'BillingPostalCode': '85719', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3d8'), 'InvoiceId': 398, 'CustomerId': 41, 'InvoiceDate': datetime.datetime(2013, 10, 21, 0, 0), 'BillingAddress': '11, Place Bellecour', 'BillingCity': 'Lyon', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '69002', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3d9'), 'InvoiceId': 399, 'CustomerId': 42, 'InvoiceDate': datetime.datetime(2013, 11, 3, 0, 0), 'BillingAddress': '9, Place Louis Barthou', 'BillingCity': 'Bordeaux', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '33000', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3da'), 'InvoiceId': 400, 'CustomerId': 44, 'InvoiceDate': datetime.datetime(2013, 11, 3, 0, 0), 'BillingAddress': 'Porthaninkatu 9', 'BillingCity': 'Helsinki', 'BillingState': None, 'BillingCountry': 'Finland', 'BillingPostalCode': '00530', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3db'), 'InvoiceId': 401, 'CustomerId': 46, 'InvoiceDate': datetime.datetime(2013, 11, 4, 0, 0), 'BillingAddress': '3 Chatham Street', 'BillingCity': 'Dublin', 'BillingState': 'Dublin', 'BillingCountry': 'Ireland', 'BillingPostalCode': None, 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3dc'), 'InvoiceId': 402, 'CustomerId': 50, 'InvoiceDate': datetime.datetime(2013, 11, 5, 0, 0), 'BillingAddress': 'C/ San Bernardo 85', 'BillingCity': 'Madrid', 'BillingState': None, 'BillingCountry': 'Spain', 'BillingPostalCode': '28015', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3dd'), 'InvoiceId': 403, 'CustomerId': 56, 'InvoiceDate': datetime.datetime(2013, 11, 8, 0, 0), 'BillingAddress': '307 Macacha Güemes', 'BillingCity': 'Buenos Aires', 'BillingState': None, 'BillingCountry': 'Argentina', 'BillingPostalCode': '1106', 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3de'), 'InvoiceId': 404, 'CustomerId': 6, 'InvoiceDate': datetime.datetime(2013, 11, 13, 0, 0), 'BillingAddress': 'Rilská 3174/6', 'BillingCity': 'Prague', 'BillingState': None, 'BillingCountry': 'Czech Republic', 'BillingPostalCode': '14300', 'Total': 25.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3df'), 'InvoiceId': 405, 'CustomerId': 20, 'InvoiceDate': datetime.datetime(2013, 11, 21, 0, 0), 'BillingAddress': '541 Del Medio Avenue', 'BillingCity': 'Mountain View', 'BillingState': 'CA', 'BillingCountry': 'USA', 'BillingPostalCode': '94040-111', 'Total': 0.99}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3e0'), 'InvoiceId': 406, 'CustomerId': 21, 'InvoiceDate': datetime.datetime(2013, 12, 4, 0, 0), 'BillingAddress': '801 W 4th Street', 'BillingCity': 'Reno', 'BillingState': 'NV', 'BillingCountry': 'USA', 'BillingPostalCode': '89503', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3e1'), 'InvoiceId': 407, 'CustomerId': 23, 'InvoiceDate': datetime.datetime(2013, 12, 4, 0, 0), 'BillingAddress': '69 Salem Street', 'BillingCity': 'Boston', 'BillingState': 'MA', 'BillingCountry': 'USA', 'BillingPostalCode': '2113', 'Total': 1.98}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3e2'), 'InvoiceId': 408, 'CustomerId': 25, 'InvoiceDate': datetime.datetime(2013, 12, 5, 0, 0), 'BillingAddress': '319 N. Frances Street', 'BillingCity': 'Madison', 'BillingState': 'WI', 'BillingCountry': 'USA', 'BillingPostalCode': '53703', 'Total': 3.96}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3e3'), 'InvoiceId': 409, 'CustomerId': 29, 'InvoiceDate': datetime.datetime(2013, 12, 6, 0, 0), 'BillingAddress': '796 Dundas Street West', 'BillingCity': 'Toronto', 'BillingState': 'ON', 'BillingCountry': 'Canada', 'BillingPostalCode': 'M6J 1V1', 'Total': 5.94}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3e4'), 'InvoiceId': 410, 'CustomerId': 35, 'InvoiceDate': datetime.datetime(2013, 12, 9, 0, 0), 'BillingAddress': 'Rua dos Campeões Europeus de Viena, 4350', 'BillingCity': 'Porto', 'BillingState': None, 'BillingCountry': 'Portugal', 'BillingPostalCode': None, 'Total': 8.91}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3e5'), 'InvoiceId': 411, 'CustomerId': 44, 'InvoiceDate': datetime.datetime(2013, 12, 14, 0, 0), 'BillingAddress': 'Porthaninkatu 9', 'BillingCity': 'Helsinki', 'BillingState': None, 'BillingCountry': 'Finland', 'BillingPostalCode': '00530', 'Total': 13.86}
# {'_id': ObjectId('6081e178d46ebf23e5ecf3e6'), 'InvoiceId': 412, 'CustomerId': 58, 'InvoiceDate': datetime.datetime(2013, 12, 22, 0, 0), 'BillingAddress': '12,Community Centre', 'BillingCity': 'Delhi', 'BillingState': None, 'BillingCountry': 'India', 'BillingPostalCode': '110017', 'Total': 1.99}

# %%
# customers = db.invoices
# customers.drop()
[s for s in db['invoices'].find()]
# Out:
# [{'_id': ObjectId('6081e178d46ebf23e5ecf24b'),
#   'InvoiceId': 1,
#   'CustomerId': 2,
#   'InvoiceDate': datetime.datetime(2009, 1, 1, 0, 0),
#   'BillingAddress': 'Theodor-Heuss-Straße 34',
#   'BillingCity': 'Stuttgart',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '70174',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf24c'),
#   'InvoiceId': 2,
#   'CustomerId': 4,
#   'InvoiceDate': datetime.datetime(2009, 1, 2, 0, 0),
#   'BillingAddress': 'Ullevålsveien 14',
#   'BillingCity': 'Oslo',
#   'BillingState': None,
#   'BillingCountry': 'Norway',
#   'BillingPostalCode': '0171',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf24d'),
#   'InvoiceId': 3,
#   'CustomerId': 8,
#   'InvoiceDate': datetime.datetime(2009, 1, 3, 0, 0),
#   'BillingAddress': 'Grétrystraat 63',
#   'BillingCity': 'Brussels',
#   'BillingState': None,
#   'BillingCountry': 'Belgium',
#   'BillingPostalCode': '1000',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf24e'),
#   'InvoiceId': 4,
#   'CustomerId': 14,
#   'InvoiceDate': datetime.datetime(2009, 1, 6, 0, 0),
#   'BillingAddress': '8210 111 ST NW',
#   'BillingCity': 'Edmonton',
#   'BillingState': 'AB',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'T6G 2C7',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf24f'),
#   'InvoiceId': 5,
#   'CustomerId': 23,
#   'InvoiceDate': datetime.datetime(2009, 1, 11, 0, 0),
#   'BillingAddress': '69 Salem Street',
#   'BillingCity': 'Boston',
#   'BillingState': 'MA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '2113',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf250'),
#   'InvoiceId': 6,
#   'CustomerId': 37,
#   'InvoiceDate': datetime.datetime(2009, 1, 19, 0, 0),
#   'BillingAddress': 'Berger Straße 10',
#   'BillingCity': 'Frankfurt',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '60316',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf251'),
#   'InvoiceId': 7,
#   'CustomerId': 38,
#   'InvoiceDate': datetime.datetime(2009, 2, 1, 0, 0),
#   'BillingAddress': 'Barbarossastraße 19',
#   'BillingCity': 'Berlin',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '10779',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf252'),
#   'InvoiceId': 8,
#   'CustomerId': 40,
#   'InvoiceDate': datetime.datetime(2009, 2, 1, 0, 0),
#   'BillingAddress': '8, Rue Hanovre',
#   'BillingCity': 'Paris',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '75002',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf253'),
#   'InvoiceId': 9,
#   'CustomerId': 42,
#   'InvoiceDate': datetime.datetime(2009, 2, 2, 0, 0),
#   'BillingAddress': '9, Place Louis Barthou',
#   'BillingCity': 'Bordeaux',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '33000',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf254'),
#   'InvoiceId': 10,
#   'CustomerId': 46,
#   'InvoiceDate': datetime.datetime(2009, 2, 3, 0, 0),
#   'BillingAddress': '3 Chatham Street',
#   'BillingCity': 'Dublin',
#   'BillingState': 'Dublin',
#   'BillingCountry': 'Ireland',
#   'BillingPostalCode': None,
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf255'),
#   'InvoiceId': 11,
#   'CustomerId': 52,
#   'InvoiceDate': datetime.datetime(2009, 2, 6, 0, 0),
#   'BillingAddress': '202 Hoxton Street',
#   'BillingCity': 'London',
#   'BillingState': None,
#   'BillingCountry': 'United Kingdom',
#   'BillingPostalCode': 'N1 5LH',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf256'),
#   'InvoiceId': 12,
#   'CustomerId': 2,
#   'InvoiceDate': datetime.datetime(2009, 2, 11, 0, 0),
#   'BillingAddress': 'Theodor-Heuss-Straße 34',
#   'BillingCity': 'Stuttgart',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '70174',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf257'),
#   'InvoiceId': 13,
#   'CustomerId': 16,
#   'InvoiceDate': datetime.datetime(2009, 2, 19, 0, 0),
#   'BillingAddress': '1600 Amphitheatre Parkway',
#   'BillingCity': 'Mountain View',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '94043-1351',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf258'),
#   'InvoiceId': 14,
#   'CustomerId': 17,
#   'InvoiceDate': datetime.datetime(2009, 3, 4, 0, 0),
#   'BillingAddress': '1 Microsoft Way',
#   'BillingCity': 'Redmond',
#   'BillingState': 'WA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '98052-8300',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf259'),
#   'InvoiceId': 15,
#   'CustomerId': 19,
#   'InvoiceDate': datetime.datetime(2009, 3, 4, 0, 0),
#   'BillingAddress': '1 Infinite Loop',
#   'BillingCity': 'Cupertino',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '95014',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf25a'),
#   'InvoiceId': 16,
#   'CustomerId': 21,
#   'InvoiceDate': datetime.datetime(2009, 3, 5, 0, 0),
#   'BillingAddress': '801 W 4th Street',
#   'BillingCity': 'Reno',
#   'BillingState': 'NV',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '89503',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf25b'),
#   'InvoiceId': 17,
#   'CustomerId': 25,
#   'InvoiceDate': datetime.datetime(2009, 3, 6, 0, 0),
#   'BillingAddress': '319 N. Frances Street',
#   'BillingCity': 'Madison',
#   'BillingState': 'WI',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '53703',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf25c'),
#   'InvoiceId': 18,
#   'CustomerId': 31,
#   'InvoiceDate': datetime.datetime(2009, 3, 9, 0, 0),
#   'BillingAddress': '194A Chain Lake Drive',
#   'BillingCity': 'Halifax',
#   'BillingState': 'NS',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'B3S 1C5',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf25d'),
#   'InvoiceId': 19,
#   'CustomerId': 40,
#   'InvoiceDate': datetime.datetime(2009, 3, 14, 0, 0),
#   'BillingAddress': '8, Rue Hanovre',
#   'BillingCity': 'Paris',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '75002',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf25e'),
#   'InvoiceId': 20,
#   'CustomerId': 54,
#   'InvoiceDate': datetime.datetime(2009, 3, 22, 0, 0),
#   'BillingAddress': '110 Raeburn Pl',
#   'BillingCity': 'Edinburgh',
#   'BillingState': None,
#   'BillingCountry': 'United Kingdom',
#   'BillingPostalCode': 'EH4 1HH',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf25f'),
#   'InvoiceId': 21,
#   'CustomerId': 55,
#   'InvoiceDate': datetime.datetime(2009, 4, 4, 0, 0),
#   'BillingAddress': '421 Bourke Street',
#   'BillingCity': 'Sidney',
#   'BillingState': 'NSW',
#   'BillingCountry': 'Australia',
#   'BillingPostalCode': '2010',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf260'),
#   'InvoiceId': 22,
#   'CustomerId': 57,
#   'InvoiceDate': datetime.datetime(2009, 4, 4, 0, 0),
#   'BillingAddress': 'Calle Lira, 198',
#   'BillingCity': 'Santiago',
#   'BillingState': None,
#   'BillingCountry': 'Chile',
#   'BillingPostalCode': None,
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf261'),
#   'InvoiceId': 23,
#   'CustomerId': 59,
#   'InvoiceDate': datetime.datetime(2009, 4, 5, 0, 0),
#   'BillingAddress': '3,Raj Bhavan Road',
#   'BillingCity': 'Bangalore',
#   'BillingState': None,
#   'BillingCountry': 'India',
#   'BillingPostalCode': '560001',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf262'),
#   'InvoiceId': 24,
#   'CustomerId': 4,
#   'InvoiceDate': datetime.datetime(2009, 4, 6, 0, 0),
#   'BillingAddress': 'Ullevålsveien 14',
#   'BillingCity': 'Oslo',
#   'BillingState': None,
#   'BillingCountry': 'Norway',
#   'BillingPostalCode': '0171',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf263'),
#   'InvoiceId': 25,
#   'CustomerId': 10,
#   'InvoiceDate': datetime.datetime(2009, 4, 9, 0, 0),
#   'BillingAddress': 'Rua Dr. Falcão Filho, 155',
#   'BillingCity': 'São Paulo',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '01007-010',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf264'),
#   'InvoiceId': 26,
#   'CustomerId': 19,
#   'InvoiceDate': datetime.datetime(2009, 4, 14, 0, 0),
#   'BillingAddress': '1 Infinite Loop',
#   'BillingCity': 'Cupertino',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '95014',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf265'),
#   'InvoiceId': 27,
#   'CustomerId': 33,
#   'InvoiceDate': datetime.datetime(2009, 4, 22, 0, 0),
#   'BillingAddress': '5112 48 Street',
#   'BillingCity': 'Yellowknife',
#   'BillingState': 'NT',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'X1A 1N6',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf266'),
#   'InvoiceId': 28,
#   'CustomerId': 34,
#   'InvoiceDate': datetime.datetime(2009, 5, 5, 0, 0),
#   'BillingAddress': 'Rua da Assunção 53',
#   'BillingCity': 'Lisbon',
#   'BillingState': None,
#   'BillingCountry': 'Portugal',
#   'BillingPostalCode': None,
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf267'),
#   'InvoiceId': 29,
#   'CustomerId': 36,
#   'InvoiceDate': datetime.datetime(2009, 5, 5, 0, 0),
#   'BillingAddress': 'Tauentzienstraße 8',
#   'BillingCity': 'Berlin',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '10789',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf268'),
#   'InvoiceId': 30,
#   'CustomerId': 38,
#   'InvoiceDate': datetime.datetime(2009, 5, 6, 0, 0),
#   'BillingAddress': 'Barbarossastraße 19',
#   'BillingCity': 'Berlin',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '10779',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf269'),
#   'InvoiceId': 31,
#   'CustomerId': 42,
#   'InvoiceDate': datetime.datetime(2009, 5, 7, 0, 0),
#   'BillingAddress': '9, Place Louis Barthou',
#   'BillingCity': 'Bordeaux',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '33000',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf26a'),
#   'InvoiceId': 32,
#   'CustomerId': 48,
#   'InvoiceDate': datetime.datetime(2009, 5, 10, 0, 0),
#   'BillingAddress': 'Lijnbaansgracht 120bg',
#   'BillingCity': 'Amsterdam',
#   'BillingState': 'VV',
#   'BillingCountry': 'Netherlands',
#   'BillingPostalCode': '1016',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf26b'),
#   'InvoiceId': 33,
#   'CustomerId': 57,
#   'InvoiceDate': datetime.datetime(2009, 5, 15, 0, 0),
#   'BillingAddress': 'Calle Lira, 198',
#   'BillingCity': 'Santiago',
#   'BillingState': None,
#   'BillingCountry': 'Chile',
#   'BillingPostalCode': None,
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf26c'),
#   'InvoiceId': 34,
#   'CustomerId': 12,
#   'InvoiceDate': datetime.datetime(2009, 5, 23, 0, 0),
#   'BillingAddress': 'Praça Pio X, 119',
#   'BillingCity': 'Rio de Janeiro',
#   'BillingState': 'RJ',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '20040-020',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf26d'),
#   'InvoiceId': 35,
#   'CustomerId': 13,
#   'InvoiceDate': datetime.datetime(2009, 6, 5, 0, 0),
#   'BillingAddress': 'Qe 7 Bloco G',
#   'BillingCity': 'Brasília',
#   'BillingState': 'DF',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '71020-677',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf26e'),
#   'InvoiceId': 36,
#   'CustomerId': 15,
#   'InvoiceDate': datetime.datetime(2009, 6, 5, 0, 0),
#   'BillingAddress': '700 W Pender Street',
#   'BillingCity': 'Vancouver',
#   'BillingState': 'BC',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'V6C 1G8',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf26f'),
#   'InvoiceId': 37,
#   'CustomerId': 17,
#   'InvoiceDate': datetime.datetime(2009, 6, 6, 0, 0),
#   'BillingAddress': '1 Microsoft Way',
#   'BillingCity': 'Redmond',
#   'BillingState': 'WA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '98052-8300',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf270'),
#   'InvoiceId': 38,
#   'CustomerId': 21,
#   'InvoiceDate': datetime.datetime(2009, 6, 7, 0, 0),
#   'BillingAddress': '801 W 4th Street',
#   'BillingCity': 'Reno',
#   'BillingState': 'NV',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '89503',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf271'),
#   'InvoiceId': 39,
#   'CustomerId': 27,
#   'InvoiceDate': datetime.datetime(2009, 6, 10, 0, 0),
#   'BillingAddress': '1033 N Park Ave',
#   'BillingCity': 'Tucson',
#   'BillingState': 'AZ',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '85719',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf272'),
#   'InvoiceId': 40,
#   'CustomerId': 36,
#   'InvoiceDate': datetime.datetime(2009, 6, 15, 0, 0),
#   'BillingAddress': 'Tauentzienstraße 8',
#   'BillingCity': 'Berlin',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '10789',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf273'),
#   'InvoiceId': 41,
#   'CustomerId': 50,
#   'InvoiceDate': datetime.datetime(2009, 6, 23, 0, 0),
#   'BillingAddress': 'C/ San Bernardo 85',
#   'BillingCity': 'Madrid',
#   'BillingState': None,
#   'BillingCountry': 'Spain',
#   'BillingPostalCode': '28015',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf274'),
#   'InvoiceId': 42,
#   'CustomerId': 51,
#   'InvoiceDate': datetime.datetime(2009, 7, 6, 0, 0),
#   'BillingAddress': 'Celsiusg. 9',
#   'BillingCity': 'Stockholm',
#   'BillingState': None,
#   'BillingCountry': 'Sweden',
#   'BillingPostalCode': '11230',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf275'),
#   'InvoiceId': 43,
#   'CustomerId': 53,
#   'InvoiceDate': datetime.datetime(2009, 7, 6, 0, 0),
#   'BillingAddress': '113 Lupus St',
#   'BillingCity': 'London',
#   'BillingState': None,
#   'BillingCountry': 'United Kingdom',
#   'BillingPostalCode': 'SW1V 3EN',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf276'),
#   'InvoiceId': 44,
#   'CustomerId': 55,
#   'InvoiceDate': datetime.datetime(2009, 7, 7, 0, 0),
#   'BillingAddress': '421 Bourke Street',
#   'BillingCity': 'Sidney',
#   'BillingState': 'NSW',
#   'BillingCountry': 'Australia',
#   'BillingPostalCode': '2010',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf277'),
#   'InvoiceId': 45,
#   'CustomerId': 59,
#   'InvoiceDate': datetime.datetime(2009, 7, 8, 0, 0),
#   'BillingAddress': '3,Raj Bhavan Road',
#   'BillingCity': 'Bangalore',
#   'BillingState': None,
#   'BillingCountry': 'India',
#   'BillingPostalCode': '560001',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf278'),
#   'InvoiceId': 46,
#   'CustomerId': 6,
#   'InvoiceDate': datetime.datetime(2009, 7, 11, 0, 0),
#   'BillingAddress': 'Rilská 3174/6',
#   'BillingCity': 'Prague',
#   'BillingState': None,
#   'BillingCountry': 'Czech Republic',
#   'BillingPostalCode': '14300',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf279'),
#   'InvoiceId': 47,
#   'CustomerId': 15,
#   'InvoiceDate': datetime.datetime(2009, 7, 16, 0, 0),
#   'BillingAddress': '700 W Pender Street',
#   'BillingCity': 'Vancouver',
#   'BillingState': 'BC',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'V6C 1G8',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf27a'),
#   'InvoiceId': 48,
#   'CustomerId': 29,
#   'InvoiceDate': datetime.datetime(2009, 7, 24, 0, 0),
#   'BillingAddress': '796 Dundas Street West',
#   'BillingCity': 'Toronto',
#   'BillingState': 'ON',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'M6J 1V1',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf27b'),
#   'InvoiceId': 49,
#   'CustomerId': 30,
#   'InvoiceDate': datetime.datetime(2009, 8, 6, 0, 0),
#   'BillingAddress': '230 Elgin Street',
#   'BillingCity': 'Ottawa',
#   'BillingState': 'ON',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'K2P 1L7',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf27c'),
#   'InvoiceId': 50,
#   'CustomerId': 32,
#   'InvoiceDate': datetime.datetime(2009, 8, 6, 0, 0),
#   'BillingAddress': '696 Osborne Street',
#   'BillingCity': 'Winnipeg',
#   'BillingState': 'MB',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'R3L 2B9',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf27d'),
#   'InvoiceId': 51,
#   'CustomerId': 34,
#   'InvoiceDate': datetime.datetime(2009, 8, 7, 0, 0),
#   'BillingAddress': 'Rua da Assunção 53',
#   'BillingCity': 'Lisbon',
#   'BillingState': None,
#   'BillingCountry': 'Portugal',
#   'BillingPostalCode': None,
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf27e'),
#   'InvoiceId': 52,
#   'CustomerId': 38,
#   'InvoiceDate': datetime.datetime(2009, 8, 8, 0, 0),
#   'BillingAddress': 'Barbarossastraße 19',
#   'BillingCity': 'Berlin',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '10779',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf27f'),
#   'InvoiceId': 53,
#   'CustomerId': 44,
#   'InvoiceDate': datetime.datetime(2009, 8, 11, 0, 0),
#   'BillingAddress': 'Porthaninkatu 9',
#   'BillingCity': 'Helsinki',
#   'BillingState': None,
#   'BillingCountry': 'Finland',
#   'BillingPostalCode': '00530',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf280'),
#   'InvoiceId': 54,
#   'CustomerId': 53,
#   'InvoiceDate': datetime.datetime(2009, 8, 16, 0, 0),
#   'BillingAddress': '113 Lupus St',
#   'BillingCity': 'London',
#   'BillingState': None,
#   'BillingCountry': 'United Kingdom',
#   'BillingPostalCode': 'SW1V 3EN',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf281'),
#   'InvoiceId': 55,
#   'CustomerId': 8,
#   'InvoiceDate': datetime.datetime(2009, 8, 24, 0, 0),
#   'BillingAddress': 'Grétrystraat 63',
#   'BillingCity': 'Brussels',
#   'BillingState': None,
#   'BillingCountry': 'Belgium',
#   'BillingPostalCode': '1000',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf282'),
#   'InvoiceId': 56,
#   'CustomerId': 9,
#   'InvoiceDate': datetime.datetime(2009, 9, 6, 0, 0),
#   'BillingAddress': 'Sønder Boulevard 51',
#   'BillingCity': 'Copenhagen',
#   'BillingState': None,
#   'BillingCountry': 'Denmark',
#   'BillingPostalCode': '1720',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf283'),
#   'InvoiceId': 57,
#   'CustomerId': 11,
#   'InvoiceDate': datetime.datetime(2009, 9, 6, 0, 0),
#   'BillingAddress': 'Av. Paulista, 2022',
#   'BillingCity': 'São Paulo',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '01310-200',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf284'),
#   'InvoiceId': 58,
#   'CustomerId': 13,
#   'InvoiceDate': datetime.datetime(2009, 9, 7, 0, 0),
#   'BillingAddress': 'Qe 7 Bloco G',
#   'BillingCity': 'Brasília',
#   'BillingState': 'DF',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '71020-677',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf285'),
#   'InvoiceId': 59,
#   'CustomerId': 17,
#   'InvoiceDate': datetime.datetime(2009, 9, 8, 0, 0),
#   'BillingAddress': '1 Microsoft Way',
#   'BillingCity': 'Redmond',
#   'BillingState': 'WA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '98052-8300',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf286'),
#   'InvoiceId': 60,
#   'CustomerId': 23,
#   'InvoiceDate': datetime.datetime(2009, 9, 11, 0, 0),
#   'BillingAddress': '69 Salem Street',
#   'BillingCity': 'Boston',
#   'BillingState': 'MA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '2113',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf287'),
#   'InvoiceId': 61,
#   'CustomerId': 32,
#   'InvoiceDate': datetime.datetime(2009, 9, 16, 0, 0),
#   'BillingAddress': '696 Osborne Street',
#   'BillingCity': 'Winnipeg',
#   'BillingState': 'MB',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'R3L 2B9',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf288'),
#   'InvoiceId': 62,
#   'CustomerId': 46,
#   'InvoiceDate': datetime.datetime(2009, 9, 24, 0, 0),
#   'BillingAddress': '3 Chatham Street',
#   'BillingCity': 'Dublin',
#   'BillingState': 'Dublin',
#   'BillingCountry': 'Ireland',
#   'BillingPostalCode': None,
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf289'),
#   'InvoiceId': 63,
#   'CustomerId': 47,
#   'InvoiceDate': datetime.datetime(2009, 10, 7, 0, 0),
#   'BillingAddress': 'Via Degli Scipioni, 43',
#   'BillingCity': 'Rome',
#   'BillingState': 'RM',
#   'BillingCountry': 'Italy',
#   'BillingPostalCode': '00192',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf28a'),
#   'InvoiceId': 64,
#   'CustomerId': 49,
#   'InvoiceDate': datetime.datetime(2009, 10, 7, 0, 0),
#   'BillingAddress': 'Ordynacka 10',
#   'BillingCity': 'Warsaw',
#   'BillingState': None,
#   'BillingCountry': 'Poland',
#   'BillingPostalCode': '00-358',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf28b'),
#   'InvoiceId': 65,
#   'CustomerId': 51,
#   'InvoiceDate': datetime.datetime(2009, 10, 8, 0, 0),
#   'BillingAddress': 'Celsiusg. 9',
#   'BillingCity': 'Stockholm',
#   'BillingState': None,
#   'BillingCountry': 'Sweden',
#   'BillingPostalCode': '11230',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf28c'),
#   'InvoiceId': 66,
#   'CustomerId': 55,
#   'InvoiceDate': datetime.datetime(2009, 10, 9, 0, 0),
#   'BillingAddress': '421 Bourke Street',
#   'BillingCity': 'Sidney',
#   'BillingState': 'NSW',
#   'BillingCountry': 'Australia',
#   'BillingPostalCode': '2010',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf28d'),
#   'InvoiceId': 67,
#   'CustomerId': 2,
#   'InvoiceDate': datetime.datetime(2009, 10, 12, 0, 0),
#   'BillingAddress': 'Theodor-Heuss-Straße 34',
#   'BillingCity': 'Stuttgart',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '70174',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf28e'),
#   'InvoiceId': 68,
#   'CustomerId': 11,
#   'InvoiceDate': datetime.datetime(2009, 10, 17, 0, 0),
#   'BillingAddress': 'Av. Paulista, 2022',
#   'BillingCity': 'São Paulo',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '01310-200',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf28f'),
#   'InvoiceId': 69,
#   'CustomerId': 25,
#   'InvoiceDate': datetime.datetime(2009, 10, 25, 0, 0),
#   'BillingAddress': '319 N. Frances Street',
#   'BillingCity': 'Madison',
#   'BillingState': 'WI',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '53703',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf290'),
#   'InvoiceId': 70,
#   'CustomerId': 26,
#   'InvoiceDate': datetime.datetime(2009, 11, 7, 0, 0),
#   'BillingAddress': '2211 W Berry Street',
#   'BillingCity': 'Fort Worth',
#   'BillingState': 'TX',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '76110',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf291'),
#   'InvoiceId': 71,
#   'CustomerId': 28,
#   'InvoiceDate': datetime.datetime(2009, 11, 7, 0, 0),
#   'BillingAddress': '302 S 700 E',
#   'BillingCity': 'Salt Lake City',
#   'BillingState': 'UT',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '84102',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf292'),
#   'InvoiceId': 72,
#   'CustomerId': 30,
#   'InvoiceDate': datetime.datetime(2009, 11, 8, 0, 0),
#   'BillingAddress': '230 Elgin Street',
#   'BillingCity': 'Ottawa',
#   'BillingState': 'ON',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'K2P 1L7',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf293'),
#   'InvoiceId': 73,
#   'CustomerId': 34,
#   'InvoiceDate': datetime.datetime(2009, 11, 9, 0, 0),
#   'BillingAddress': 'Rua da Assunção 53',
#   'BillingCity': 'Lisbon',
#   'BillingState': None,
#   'BillingCountry': 'Portugal',
#   'BillingPostalCode': None,
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf294'),
#   'InvoiceId': 74,
#   'CustomerId': 40,
#   'InvoiceDate': datetime.datetime(2009, 11, 12, 0, 0),
#   'BillingAddress': '8, Rue Hanovre',
#   'BillingCity': 'Paris',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '75002',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf295'),
#   'InvoiceId': 75,
#   'CustomerId': 49,
#   'InvoiceDate': datetime.datetime(2009, 11, 17, 0, 0),
#   'BillingAddress': 'Ordynacka 10',
#   'BillingCity': 'Warsaw',
#   'BillingState': None,
#   'BillingCountry': 'Poland',
#   'BillingPostalCode': '00-358',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf296'),
#   'InvoiceId': 76,
#   'CustomerId': 4,
#   'InvoiceDate': datetime.datetime(2009, 11, 25, 0, 0),
#   'BillingAddress': 'Ullevålsveien 14',
#   'BillingCity': 'Oslo',
#   'BillingState': None,
#   'BillingCountry': 'Norway',
#   'BillingPostalCode': '0171',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf297'),
#   'InvoiceId': 77,
#   'CustomerId': 5,
#   'InvoiceDate': datetime.datetime(2009, 12, 8, 0, 0),
#   'BillingAddress': 'Klanova 9/506',
#   'BillingCity': 'Prague',
#   'BillingState': None,
#   'BillingCountry': 'Czech Republic',
#   'BillingPostalCode': '14700',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf298'),
#   'InvoiceId': 78,
#   'CustomerId': 7,
#   'InvoiceDate': datetime.datetime(2009, 12, 8, 0, 0),
#   'BillingAddress': 'Rotenturmstraße 4, 1010 Innere Stadt',
#   'BillingCity': 'Vienne',
#   'BillingState': None,
#   'BillingCountry': 'Austria',
#   'BillingPostalCode': '1010',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf299'),
#   'InvoiceId': 79,
#   'CustomerId': 9,
#   'InvoiceDate': datetime.datetime(2009, 12, 9, 0, 0),
#   'BillingAddress': 'Sønder Boulevard 51',
#   'BillingCity': 'Copenhagen',
#   'BillingState': None,
#   'BillingCountry': 'Denmark',
#   'BillingPostalCode': '1720',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf29a'),
#   'InvoiceId': 80,
#   'CustomerId': 13,
#   'InvoiceDate': datetime.datetime(2009, 12, 10, 0, 0),
#   'BillingAddress': 'Qe 7 Bloco G',
#   'BillingCity': 'Brasília',
#   'BillingState': 'DF',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '71020-677',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf29b'),
#   'InvoiceId': 81,
#   'CustomerId': 19,
#   'InvoiceDate': datetime.datetime(2009, 12, 13, 0, 0),
#   'BillingAddress': '1 Infinite Loop',
#   'BillingCity': 'Cupertino',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '95014',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf29c'),
#   'InvoiceId': 82,
#   'CustomerId': 28,
#   'InvoiceDate': datetime.datetime(2009, 12, 18, 0, 0),
#   'BillingAddress': '302 S 700 E',
#   'BillingCity': 'Salt Lake City',
#   'BillingState': 'UT',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '84102',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf29d'),
#   'InvoiceId': 83,
#   'CustomerId': 42,
#   'InvoiceDate': datetime.datetime(2009, 12, 26, 0, 0),
#   'BillingAddress': '9, Place Louis Barthou',
#   'BillingCity': 'Bordeaux',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '33000',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf29e'),
#   'InvoiceId': 84,
#   'CustomerId': 43,
#   'InvoiceDate': datetime.datetime(2010, 1, 8, 0, 0),
#   'BillingAddress': '68, Rue Jouvence',
#   'BillingCity': 'Dijon',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '21000',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf29f'),
#   'InvoiceId': 85,
#   'CustomerId': 45,
#   'InvoiceDate': datetime.datetime(2010, 1, 8, 0, 0),
#   'BillingAddress': 'Erzsébet krt. 58.',
#   'BillingCity': 'Budapest',
#   'BillingState': None,
#   'BillingCountry': 'Hungary',
#   'BillingPostalCode': 'H-1073',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a0'),
#   'InvoiceId': 86,
#   'CustomerId': 47,
#   'InvoiceDate': datetime.datetime(2010, 1, 9, 0, 0),
#   'BillingAddress': 'Via Degli Scipioni, 43',
#   'BillingCity': 'Rome',
#   'BillingState': 'RM',
#   'BillingCountry': 'Italy',
#   'BillingPostalCode': '00192',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a1'),
#   'InvoiceId': 87,
#   'CustomerId': 51,
#   'InvoiceDate': datetime.datetime(2010, 1, 10, 0, 0),
#   'BillingAddress': 'Celsiusg. 9',
#   'BillingCity': 'Stockholm',
#   'BillingState': None,
#   'BillingCountry': 'Sweden',
#   'BillingPostalCode': '11230',
#   'Total': 6.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a2'),
#   'InvoiceId': 88,
#   'CustomerId': 57,
#   'InvoiceDate': datetime.datetime(2010, 1, 13, 0, 0),
#   'BillingAddress': 'Calle Lira, 198',
#   'BillingCity': 'Santiago',
#   'BillingState': None,
#   'BillingCountry': 'Chile',
#   'BillingPostalCode': None,
#   'Total': 17.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a3'),
#   'InvoiceId': 89,
#   'CustomerId': 7,
#   'InvoiceDate': datetime.datetime(2010, 1, 18, 0, 0),
#   'BillingAddress': 'Rotenturmstraße 4, 1010 Innere Stadt',
#   'BillingCity': 'Vienne',
#   'BillingState': None,
#   'BillingCountry': 'Austria',
#   'BillingPostalCode': '1010',
#   'Total': 18.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a4'),
#   'InvoiceId': 90,
#   'CustomerId': 21,
#   'InvoiceDate': datetime.datetime(2010, 1, 26, 0, 0),
#   'BillingAddress': '801 W 4th Street',
#   'BillingCity': 'Reno',
#   'BillingState': 'NV',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '89503',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a5'),
#   'InvoiceId': 91,
#   'CustomerId': 22,
#   'InvoiceDate': datetime.datetime(2010, 2, 8, 0, 0),
#   'BillingAddress': '120 S Orange Ave',
#   'BillingCity': 'Orlando',
#   'BillingState': 'FL',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '32801',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a6'),
#   'InvoiceId': 92,
#   'CustomerId': 24,
#   'InvoiceDate': datetime.datetime(2010, 2, 8, 0, 0),
#   'BillingAddress': '162 E Superior Street',
#   'BillingCity': 'Chicago',
#   'BillingState': 'IL',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '60611',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a7'),
#   'InvoiceId': 93,
#   'CustomerId': 26,
#   'InvoiceDate': datetime.datetime(2010, 2, 9, 0, 0),
#   'BillingAddress': '2211 W Berry Street',
#   'BillingCity': 'Fort Worth',
#   'BillingState': 'TX',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '76110',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a8'),
#   'InvoiceId': 94,
#   'CustomerId': 30,
#   'InvoiceDate': datetime.datetime(2010, 2, 10, 0, 0),
#   'BillingAddress': '230 Elgin Street',
#   'BillingCity': 'Ottawa',
#   'BillingState': 'ON',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'K2P 1L7',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2a9'),
#   'InvoiceId': 95,
#   'CustomerId': 36,
#   'InvoiceDate': datetime.datetime(2010, 2, 13, 0, 0),
#   'BillingAddress': 'Tauentzienstraße 8',
#   'BillingCity': 'Berlin',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '10789',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2aa'),
#   'InvoiceId': 96,
#   'CustomerId': 45,
#   'InvoiceDate': datetime.datetime(2010, 2, 18, 0, 0),
#   'BillingAddress': 'Erzsébet krt. 58.',
#   'BillingCity': 'Budapest',
#   'BillingState': None,
#   'BillingCountry': 'Hungary',
#   'BillingPostalCode': 'H-1073',
#   'Total': 21.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2ab'),
#   'InvoiceId': 97,
#   'CustomerId': 59,
#   'InvoiceDate': datetime.datetime(2010, 2, 26, 0, 0),
#   'BillingAddress': '3,Raj Bhavan Road',
#   'BillingCity': 'Bangalore',
#   'BillingState': None,
#   'BillingCountry': 'India',
#   'BillingPostalCode': '560001',
#   'Total': 1.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2ac'),
#   'InvoiceId': 98,
#   'CustomerId': 1,
#   'InvoiceDate': datetime.datetime(2010, 3, 11, 0, 0),
#   'BillingAddress': 'Av. Brigadeiro Faria Lima, 2170',
#   'BillingCity': 'São José dos Campos',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '12227-000',
#   'Total': 3.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2ad'),
#   'InvoiceId': 99,
#   'CustomerId': 3,
#   'InvoiceDate': datetime.datetime(2010, 3, 11, 0, 0),
#   'BillingAddress': '1498 rue Bélanger',
#   'BillingCity': 'Montréal',
#   'BillingState': 'QC',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'H2G 1A7',
#   'Total': 3.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2ae'),
#   'InvoiceId': 100,
#   'CustomerId': 5,
#   'InvoiceDate': datetime.datetime(2010, 3, 12, 0, 0),
#   'BillingAddress': 'Klanova 9/506',
#   'BillingCity': 'Prague',
#   'BillingState': None,
#   'BillingCountry': 'Czech Republic',
#   'BillingPostalCode': '14700',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2af'),
#   'InvoiceId': 101,
#   'CustomerId': 9,
#   'InvoiceDate': datetime.datetime(2010, 3, 13, 0, 0),
#   'BillingAddress': 'Sønder Boulevard 51',
#   'BillingCity': 'Copenhagen',
#   'BillingState': None,
#   'BillingCountry': 'Denmark',
#   'BillingPostalCode': '1720',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b0'),
#   'InvoiceId': 102,
#   'CustomerId': 15,
#   'InvoiceDate': datetime.datetime(2010, 3, 16, 0, 0),
#   'BillingAddress': '700 W Pender Street',
#   'BillingCity': 'Vancouver',
#   'BillingState': 'BC',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'V6C 1G8',
#   'Total': 9.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b1'),
#   'InvoiceId': 103,
#   'CustomerId': 24,
#   'InvoiceDate': datetime.datetime(2010, 3, 21, 0, 0),
#   'BillingAddress': '162 E Superior Street',
#   'BillingCity': 'Chicago',
#   'BillingState': 'IL',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '60611',
#   'Total': 15.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b2'),
#   'InvoiceId': 104,
#   'CustomerId': 38,
#   'InvoiceDate': datetime.datetime(2010, 3, 29, 0, 0),
#   'BillingAddress': 'Barbarossastraße 19',
#   'BillingCity': 'Berlin',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '10779',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b3'),
#   'InvoiceId': 105,
#   'CustomerId': 39,
#   'InvoiceDate': datetime.datetime(2010, 4, 11, 0, 0),
#   'BillingAddress': '4, Rue Milton',
#   'BillingCity': 'Paris',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '75009',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b4'),
#   'InvoiceId': 106,
#   'CustomerId': 41,
#   'InvoiceDate': datetime.datetime(2010, 4, 11, 0, 0),
#   'BillingAddress': '11, Place Bellecour',
#   'BillingCity': 'Lyon',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '69002',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b5'),
#   'InvoiceId': 107,
#   'CustomerId': 43,
#   'InvoiceDate': datetime.datetime(2010, 4, 12, 0, 0),
#   'BillingAddress': '68, Rue Jouvence',
#   'BillingCity': 'Dijon',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '21000',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b6'),
#   'InvoiceId': 108,
#   'CustomerId': 47,
#   'InvoiceDate': datetime.datetime(2010, 4, 13, 0, 0),
#   'BillingAddress': 'Via Degli Scipioni, 43',
#   'BillingCity': 'Rome',
#   'BillingState': 'RM',
#   'BillingCountry': 'Italy',
#   'BillingPostalCode': '00192',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b7'),
#   'InvoiceId': 109,
#   'CustomerId': 53,
#   'InvoiceDate': datetime.datetime(2010, 4, 16, 0, 0),
#   'BillingAddress': '113 Lupus St',
#   'BillingCity': 'London',
#   'BillingState': None,
#   'BillingCountry': 'United Kingdom',
#   'BillingPostalCode': 'SW1V 3EN',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b8'),
#   'InvoiceId': 110,
#   'CustomerId': 3,
#   'InvoiceDate': datetime.datetime(2010, 4, 21, 0, 0),
#   'BillingAddress': '1498 rue Bélanger',
#   'BillingCity': 'Montréal',
#   'BillingState': 'QC',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'H2G 1A7',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2b9'),
#   'InvoiceId': 111,
#   'CustomerId': 17,
#   'InvoiceDate': datetime.datetime(2010, 4, 29, 0, 0),
#   'BillingAddress': '1 Microsoft Way',
#   'BillingCity': 'Redmond',
#   'BillingState': 'WA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '98052-8300',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2ba'),
#   'InvoiceId': 112,
#   'CustomerId': 18,
#   'InvoiceDate': datetime.datetime(2010, 5, 12, 0, 0),
#   'BillingAddress': '627 Broadway',
#   'BillingCity': 'New York',
#   'BillingState': 'NY',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '10012-2612',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2bb'),
#   'InvoiceId': 113,
#   'CustomerId': 20,
#   'InvoiceDate': datetime.datetime(2010, 5, 12, 0, 0),
#   'BillingAddress': '541 Del Medio Avenue',
#   'BillingCity': 'Mountain View',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '94040-111',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2bc'),
#   'InvoiceId': 114,
#   'CustomerId': 22,
#   'InvoiceDate': datetime.datetime(2010, 5, 13, 0, 0),
#   'BillingAddress': '120 S Orange Ave',
#   'BillingCity': 'Orlando',
#   'BillingState': 'FL',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '32801',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2bd'),
#   'InvoiceId': 115,
#   'CustomerId': 26,
#   'InvoiceDate': datetime.datetime(2010, 5, 14, 0, 0),
#   'BillingAddress': '2211 W Berry Street',
#   'BillingCity': 'Fort Worth',
#   'BillingState': 'TX',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '76110',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2be'),
#   'InvoiceId': 116,
#   'CustomerId': 32,
#   'InvoiceDate': datetime.datetime(2010, 5, 17, 0, 0),
#   'BillingAddress': '696 Osborne Street',
#   'BillingCity': 'Winnipeg',
#   'BillingState': 'MB',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'R3L 2B9',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2bf'),
#   'InvoiceId': 117,
#   'CustomerId': 41,
#   'InvoiceDate': datetime.datetime(2010, 5, 22, 0, 0),
#   'BillingAddress': '11, Place Bellecour',
#   'BillingCity': 'Lyon',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '69002',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c0'),
#   'InvoiceId': 118,
#   'CustomerId': 55,
#   'InvoiceDate': datetime.datetime(2010, 5, 30, 0, 0),
#   'BillingAddress': '421 Bourke Street',
#   'BillingCity': 'Sidney',
#   'BillingState': 'NSW',
#   'BillingCountry': 'Australia',
#   'BillingPostalCode': '2010',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c1'),
#   'InvoiceId': 119,
#   'CustomerId': 56,
#   'InvoiceDate': datetime.datetime(2010, 6, 12, 0, 0),
#   'BillingAddress': '307 Macacha Güemes',
#   'BillingCity': 'Buenos Aires',
#   'BillingState': None,
#   'BillingCountry': 'Argentina',
#   'BillingPostalCode': '1106',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c2'),
#   'InvoiceId': 120,
#   'CustomerId': 58,
#   'InvoiceDate': datetime.datetime(2010, 6, 12, 0, 0),
#   'BillingAddress': '12,Community Centre',
#   'BillingCity': 'Delhi',
#   'BillingState': None,
#   'BillingCountry': 'India',
#   'BillingPostalCode': '110017',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c3'),
#   'InvoiceId': 121,
#   'CustomerId': 1,
#   'InvoiceDate': datetime.datetime(2010, 6, 13, 0, 0),
#   'BillingAddress': 'Av. Brigadeiro Faria Lima, 2170',
#   'BillingCity': 'São José dos Campos',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '12227-000',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c4'),
#   'InvoiceId': 122,
#   'CustomerId': 5,
#   'InvoiceDate': datetime.datetime(2010, 6, 14, 0, 0),
#   'BillingAddress': 'Klanova 9/506',
#   'BillingCity': 'Prague',
#   'BillingState': None,
#   'BillingCountry': 'Czech Republic',
#   'BillingPostalCode': '14700',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c5'),
#   'InvoiceId': 123,
#   'CustomerId': 11,
#   'InvoiceDate': datetime.datetime(2010, 6, 17, 0, 0),
#   'BillingAddress': 'Av. Paulista, 2022',
#   'BillingCity': 'São Paulo',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '01310-200',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c6'),
#   'InvoiceId': 124,
#   'CustomerId': 20,
#   'InvoiceDate': datetime.datetime(2010, 6, 22, 0, 0),
#   'BillingAddress': '541 Del Medio Avenue',
#   'BillingCity': 'Mountain View',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '94040-111',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c7'),
#   'InvoiceId': 125,
#   'CustomerId': 34,
#   'InvoiceDate': datetime.datetime(2010, 6, 30, 0, 0),
#   'BillingAddress': 'Rua da Assunção 53',
#   'BillingCity': 'Lisbon',
#   'BillingState': None,
#   'BillingCountry': 'Portugal',
#   'BillingPostalCode': None,
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c8'),
#   'InvoiceId': 126,
#   'CustomerId': 35,
#   'InvoiceDate': datetime.datetime(2010, 7, 13, 0, 0),
#   'BillingAddress': 'Rua dos Campeões Europeus de Viena, 4350',
#   'BillingCity': 'Porto',
#   'BillingState': None,
#   'BillingCountry': 'Portugal',
#   'BillingPostalCode': None,
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2c9'),
#   'InvoiceId': 127,
#   'CustomerId': 37,
#   'InvoiceDate': datetime.datetime(2010, 7, 13, 0, 0),
#   'BillingAddress': 'Berger Straße 10',
#   'BillingCity': 'Frankfurt',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '60316',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2ca'),
#   'InvoiceId': 128,
#   'CustomerId': 39,
#   'InvoiceDate': datetime.datetime(2010, 7, 14, 0, 0),
#   'BillingAddress': '4, Rue Milton',
#   'BillingCity': 'Paris',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '75009',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2cb'),
#   'InvoiceId': 129,
#   'CustomerId': 43,
#   'InvoiceDate': datetime.datetime(2010, 7, 15, 0, 0),
#   'BillingAddress': '68, Rue Jouvence',
#   'BillingCity': 'Dijon',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '21000',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2cc'),
#   'InvoiceId': 130,
#   'CustomerId': 49,
#   'InvoiceDate': datetime.datetime(2010, 7, 18, 0, 0),
#   'BillingAddress': 'Ordynacka 10',
#   'BillingCity': 'Warsaw',
#   'BillingState': None,
#   'BillingCountry': 'Poland',
#   'BillingPostalCode': '00-358',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2cd'),
#   'InvoiceId': 131,
#   'CustomerId': 58,
#   'InvoiceDate': datetime.datetime(2010, 7, 23, 0, 0),
#   'BillingAddress': '12,Community Centre',
#   'BillingCity': 'Delhi',
#   'BillingState': None,
#   'BillingCountry': 'India',
#   'BillingPostalCode': '110017',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2ce'),
#   'InvoiceId': 132,
#   'CustomerId': 13,
#   'InvoiceDate': datetime.datetime(2010, 7, 31, 0, 0),
#   'BillingAddress': 'Qe 7 Bloco G',
#   'BillingCity': 'Brasília',
#   'BillingState': 'DF',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '71020-677',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2cf'),
#   'InvoiceId': 133,
#   'CustomerId': 14,
#   'InvoiceDate': datetime.datetime(2010, 8, 13, 0, 0),
#   'BillingAddress': '8210 111 ST NW',
#   'BillingCity': 'Edmonton',
#   'BillingState': 'AB',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'T6G 2C7',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d0'),
#   'InvoiceId': 134,
#   'CustomerId': 16,
#   'InvoiceDate': datetime.datetime(2010, 8, 13, 0, 0),
#   'BillingAddress': '1600 Amphitheatre Parkway',
#   'BillingCity': 'Mountain View',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '94043-1351',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d1'),
#   'InvoiceId': 135,
#   'CustomerId': 18,
#   'InvoiceDate': datetime.datetime(2010, 8, 14, 0, 0),
#   'BillingAddress': '627 Broadway',
#   'BillingCity': 'New York',
#   'BillingState': 'NY',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '10012-2612',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d2'),
#   'InvoiceId': 136,
#   'CustomerId': 22,
#   'InvoiceDate': datetime.datetime(2010, 8, 15, 0, 0),
#   'BillingAddress': '120 S Orange Ave',
#   'BillingCity': 'Orlando',
#   'BillingState': 'FL',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '32801',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d3'),
#   'InvoiceId': 137,
#   'CustomerId': 28,
#   'InvoiceDate': datetime.datetime(2010, 8, 18, 0, 0),
#   'BillingAddress': '302 S 700 E',
#   'BillingCity': 'Salt Lake City',
#   'BillingState': 'UT',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '84102',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d4'),
#   'InvoiceId': 138,
#   'CustomerId': 37,
#   'InvoiceDate': datetime.datetime(2010, 8, 23, 0, 0),
#   'BillingAddress': 'Berger Straße 10',
#   'BillingCity': 'Frankfurt',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '60316',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d5'),
#   'InvoiceId': 139,
#   'CustomerId': 51,
#   'InvoiceDate': datetime.datetime(2010, 8, 31, 0, 0),
#   'BillingAddress': 'Celsiusg. 9',
#   'BillingCity': 'Stockholm',
#   'BillingState': None,
#   'BillingCountry': 'Sweden',
#   'BillingPostalCode': '11230',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d6'),
#   'InvoiceId': 140,
#   'CustomerId': 52,
#   'InvoiceDate': datetime.datetime(2010, 9, 13, 0, 0),
#   'BillingAddress': '202 Hoxton Street',
#   'BillingCity': 'London',
#   'BillingState': None,
#   'BillingCountry': 'United Kingdom',
#   'BillingPostalCode': 'N1 5LH',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d7'),
#   'InvoiceId': 141,
#   'CustomerId': 54,
#   'InvoiceDate': datetime.datetime(2010, 9, 13, 0, 0),
#   'BillingAddress': '110 Raeburn Pl',
#   'BillingCity': 'Edinburgh',
#   'BillingState': None,
#   'BillingCountry': 'United Kingdom',
#   'BillingPostalCode': 'EH4 1HH',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d8'),
#   'InvoiceId': 142,
#   'CustomerId': 56,
#   'InvoiceDate': datetime.datetime(2010, 9, 14, 0, 0),
#   'BillingAddress': '307 Macacha Güemes',
#   'BillingCity': 'Buenos Aires',
#   'BillingState': None,
#   'BillingCountry': 'Argentina',
#   'BillingPostalCode': '1106',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2d9'),
#   'InvoiceId': 143,
#   'CustomerId': 1,
#   'InvoiceDate': datetime.datetime(2010, 9, 15, 0, 0),
#   'BillingAddress': 'Av. Brigadeiro Faria Lima, 2170',
#   'BillingCity': 'São José dos Campos',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '12227-000',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2da'),
#   'InvoiceId': 144,
#   'CustomerId': 7,
#   'InvoiceDate': datetime.datetime(2010, 9, 18, 0, 0),
#   'BillingAddress': 'Rotenturmstraße 4, 1010 Innere Stadt',
#   'BillingCity': 'Vienne',
#   'BillingState': None,
#   'BillingCountry': 'Austria',
#   'BillingPostalCode': '1010',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2db'),
#   'InvoiceId': 145,
#   'CustomerId': 16,
#   'InvoiceDate': datetime.datetime(2010, 9, 23, 0, 0),
#   'BillingAddress': '1600 Amphitheatre Parkway',
#   'BillingCity': 'Mountain View',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '94043-1351',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2dc'),
#   'InvoiceId': 146,
#   'CustomerId': 30,
#   'InvoiceDate': datetime.datetime(2010, 10, 1, 0, 0),
#   'BillingAddress': '230 Elgin Street',
#   'BillingCity': 'Ottawa',
#   'BillingState': 'ON',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'K2P 1L7',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2dd'),
#   'InvoiceId': 147,
#   'CustomerId': 31,
#   'InvoiceDate': datetime.datetime(2010, 10, 14, 0, 0),
#   'BillingAddress': '194A Chain Lake Drive',
#   'BillingCity': 'Halifax',
#   'BillingState': 'NS',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'B3S 1C5',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2de'),
#   'InvoiceId': 148,
#   'CustomerId': 33,
#   'InvoiceDate': datetime.datetime(2010, 10, 14, 0, 0),
#   'BillingAddress': '5112 48 Street',
#   'BillingCity': 'Yellowknife',
#   'BillingState': 'NT',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'X1A 1N6',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2df'),
#   'InvoiceId': 149,
#   'CustomerId': 35,
#   'InvoiceDate': datetime.datetime(2010, 10, 15, 0, 0),
#   'BillingAddress': 'Rua dos Campeões Europeus de Viena, 4350',
#   'BillingCity': 'Porto',
#   'BillingState': None,
#   'BillingCountry': 'Portugal',
#   'BillingPostalCode': None,
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2e0'),
#   'InvoiceId': 150,
#   'CustomerId': 39,
#   'InvoiceDate': datetime.datetime(2010, 10, 16, 0, 0),
#   'BillingAddress': '4, Rue Milton',
#   'BillingCity': 'Paris',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '75009',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2e1'),
#   'InvoiceId': 151,
#   'CustomerId': 45,
#   'InvoiceDate': datetime.datetime(2010, 10, 19, 0, 0),
#   'BillingAddress': 'Erzsébet krt. 58.',
#   'BillingCity': 'Budapest',
#   'BillingState': None,
#   'BillingCountry': 'Hungary',
#   'BillingPostalCode': 'H-1073',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf2e2'),
#   'InvoiceId': 152,
#   'CustomerId': 54,
#   'InvoiceDate': datetime.datetime(2010, 10, 24, 0, 0),
#   'BillingAddress': '110 Raeburn Pl',
# ...
#   'BillingPostalCode': 'T6G 2C7',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3b5'),
#   'InvoiceId': 363,
#   'CustomerId': 28,
#   'InvoiceDate': datetime.datetime(2013, 5, 19, 0, 0),
#   'BillingAddress': '302 S 700 E',
#   'BillingCity': 'Salt Lake City',
#   'BillingState': 'UT',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '84102',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3b6'),
#   'InvoiceId': 364,
#   'CustomerId': 29,
#   'InvoiceDate': datetime.datetime(2013, 6, 1, 0, 0),
#   'BillingAddress': '796 Dundas Street West',
#   'BillingCity': 'Toronto',
#   'BillingState': 'ON',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'M6J 1V1',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3b7'),
#   'InvoiceId': 365,
#   'CustomerId': 31,
#   'InvoiceDate': datetime.datetime(2013, 6, 1, 0, 0),
#   'BillingAddress': '194A Chain Lake Drive',
#   'BillingCity': 'Halifax',
#   'BillingState': 'NS',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'B3S 1C5',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3b8'),
#   'InvoiceId': 366,
#   'CustomerId': 33,
#   'InvoiceDate': datetime.datetime(2013, 6, 2, 0, 0),
#   'BillingAddress': '5112 48 Street',
#   'BillingCity': 'Yellowknife',
#   'BillingState': 'NT',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'X1A 1N6',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3b9'),
#   'InvoiceId': 367,
#   'CustomerId': 37,
#   'InvoiceDate': datetime.datetime(2013, 6, 3, 0, 0),
#   'BillingAddress': 'Berger Straße 10',
#   'BillingCity': 'Frankfurt',
#   'BillingState': None,
#   'BillingCountry': 'Germany',
#   'BillingPostalCode': '60316',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3ba'),
#   'InvoiceId': 368,
#   'CustomerId': 43,
#   'InvoiceDate': datetime.datetime(2013, 6, 6, 0, 0),
#   'BillingAddress': '68, Rue Jouvence',
#   'BillingCity': 'Dijon',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '21000',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3bb'),
#   'InvoiceId': 369,
#   'CustomerId': 52,
#   'InvoiceDate': datetime.datetime(2013, 6, 11, 0, 0),
#   'BillingAddress': '202 Hoxton Street',
#   'BillingCity': 'London',
#   'BillingState': None,
#   'BillingCountry': 'United Kingdom',
#   'BillingPostalCode': 'N1 5LH',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3bc'),
#   'InvoiceId': 370,
#   'CustomerId': 7,
#   'InvoiceDate': datetime.datetime(2013, 6, 19, 0, 0),
#   'BillingAddress': 'Rotenturmstraße 4, 1010 Innere Stadt',
#   'BillingCity': 'Vienne',
#   'BillingState': None,
#   'BillingCountry': 'Austria',
#   'BillingPostalCode': '1010',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3bd'),
#   'InvoiceId': 371,
#   'CustomerId': 8,
#   'InvoiceDate': datetime.datetime(2013, 7, 2, 0, 0),
#   'BillingAddress': 'Grétrystraat 63',
#   'BillingCity': 'Brussels',
#   'BillingState': None,
#   'BillingCountry': 'Belgium',
#   'BillingPostalCode': '1000',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3be'),
#   'InvoiceId': 372,
#   'CustomerId': 10,
#   'InvoiceDate': datetime.datetime(2013, 7, 2, 0, 0),
#   'BillingAddress': 'Rua Dr. Falcão Filho, 155',
#   'BillingCity': 'São Paulo',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '01007-010',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3bf'),
#   'InvoiceId': 373,
#   'CustomerId': 12,
#   'InvoiceDate': datetime.datetime(2013, 7, 3, 0, 0),
#   'BillingAddress': 'Praça Pio X, 119',
#   'BillingCity': 'Rio de Janeiro',
#   'BillingState': 'RJ',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '20040-020',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c0'),
#   'InvoiceId': 374,
#   'CustomerId': 16,
#   'InvoiceDate': datetime.datetime(2013, 7, 4, 0, 0),
#   'BillingAddress': '1600 Amphitheatre Parkway',
#   'BillingCity': 'Mountain View',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '94043-1351',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c1'),
#   'InvoiceId': 375,
#   'CustomerId': 22,
#   'InvoiceDate': datetime.datetime(2013, 7, 7, 0, 0),
#   'BillingAddress': '120 S Orange Ave',
#   'BillingCity': 'Orlando',
#   'BillingState': 'FL',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '32801',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c2'),
#   'InvoiceId': 376,
#   'CustomerId': 31,
#   'InvoiceDate': datetime.datetime(2013, 7, 12, 0, 0),
#   'BillingAddress': '194A Chain Lake Drive',
#   'BillingCity': 'Halifax',
#   'BillingState': 'NS',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'B3S 1C5',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c3'),
#   'InvoiceId': 377,
#   'CustomerId': 45,
#   'InvoiceDate': datetime.datetime(2013, 7, 20, 0, 0),
#   'BillingAddress': 'Erzsébet krt. 58.',
#   'BillingCity': 'Budapest',
#   'BillingState': None,
#   'BillingCountry': 'Hungary',
#   'BillingPostalCode': 'H-1073',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c4'),
#   'InvoiceId': 378,
#   'CustomerId': 46,
#   'InvoiceDate': datetime.datetime(2013, 8, 2, 0, 0),
#   'BillingAddress': '3 Chatham Street',
#   'BillingCity': 'Dublin',
#   'BillingState': 'Dublin',
#   'BillingCountry': 'Ireland',
#   'BillingPostalCode': None,
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c5'),
#   'InvoiceId': 379,
#   'CustomerId': 48,
#   'InvoiceDate': datetime.datetime(2013, 8, 2, 0, 0),
#   'BillingAddress': 'Lijnbaansgracht 120bg',
#   'BillingCity': 'Amsterdam',
#   'BillingState': 'VV',
#   'BillingCountry': 'Netherlands',
#   'BillingPostalCode': '1016',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c6'),
#   'InvoiceId': 380,
#   'CustomerId': 50,
#   'InvoiceDate': datetime.datetime(2013, 8, 3, 0, 0),
#   'BillingAddress': 'C/ San Bernardo 85',
#   'BillingCity': 'Madrid',
#   'BillingState': None,
#   'BillingCountry': 'Spain',
#   'BillingPostalCode': '28015',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c7'),
#   'InvoiceId': 381,
#   'CustomerId': 54,
#   'InvoiceDate': datetime.datetime(2013, 8, 4, 0, 0),
#   'BillingAddress': '110 Raeburn Pl',
#   'BillingCity': 'Edinburgh',
#   'BillingState': None,
#   'BillingCountry': 'United Kingdom',
#   'BillingPostalCode': 'EH4 1HH',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c8'),
#   'InvoiceId': 382,
#   'CustomerId': 1,
#   'InvoiceDate': datetime.datetime(2013, 8, 7, 0, 0),
#   'BillingAddress': 'Av. Brigadeiro Faria Lima, 2170',
#   'BillingCity': 'São José dos Campos',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '12227-000',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3c9'),
#   'InvoiceId': 383,
#   'CustomerId': 10,
#   'InvoiceDate': datetime.datetime(2013, 8, 12, 0, 0),
#   'BillingAddress': 'Rua Dr. Falcão Filho, 155',
#   'BillingCity': 'São Paulo',
#   'BillingState': 'SP',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '01007-010',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3ca'),
#   'InvoiceId': 384,
#   'CustomerId': 24,
#   'InvoiceDate': datetime.datetime(2013, 8, 20, 0, 0),
#   'BillingAddress': '162 E Superior Street',
#   'BillingCity': 'Chicago',
#   'BillingState': 'IL',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '60611',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3cb'),
#   'InvoiceId': 385,
#   'CustomerId': 25,
#   'InvoiceDate': datetime.datetime(2013, 9, 2, 0, 0),
#   'BillingAddress': '319 N. Frances Street',
#   'BillingCity': 'Madison',
#   'BillingState': 'WI',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '53703',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3cc'),
#   'InvoiceId': 386,
#   'CustomerId': 27,
#   'InvoiceDate': datetime.datetime(2013, 9, 2, 0, 0),
#   'BillingAddress': '1033 N Park Ave',
#   'BillingCity': 'Tucson',
#   'BillingState': 'AZ',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '85719',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3cd'),
#   'InvoiceId': 387,
#   'CustomerId': 29,
#   'InvoiceDate': datetime.datetime(2013, 9, 3, 0, 0),
#   'BillingAddress': '796 Dundas Street West',
#   'BillingCity': 'Toronto',
#   'BillingState': 'ON',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'M6J 1V1',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3ce'),
#   'InvoiceId': 388,
#   'CustomerId': 33,
#   'InvoiceDate': datetime.datetime(2013, 9, 4, 0, 0),
#   'BillingAddress': '5112 48 Street',
#   'BillingCity': 'Yellowknife',
#   'BillingState': 'NT',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'X1A 1N6',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3cf'),
#   'InvoiceId': 389,
#   'CustomerId': 39,
#   'InvoiceDate': datetime.datetime(2013, 9, 7, 0, 0),
#   'BillingAddress': '4, Rue Milton',
#   'BillingCity': 'Paris',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '75009',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d0'),
#   'InvoiceId': 390,
#   'CustomerId': 48,
#   'InvoiceDate': datetime.datetime(2013, 9, 12, 0, 0),
#   'BillingAddress': 'Lijnbaansgracht 120bg',
#   'BillingCity': 'Amsterdam',
#   'BillingState': 'VV',
#   'BillingCountry': 'Netherlands',
#   'BillingPostalCode': '1016',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d1'),
#   'InvoiceId': 391,
#   'CustomerId': 3,
#   'InvoiceDate': datetime.datetime(2013, 9, 20, 0, 0),
#   'BillingAddress': '1498 rue Bélanger',
#   'BillingCity': 'Montréal',
#   'BillingState': 'QC',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'H2G 1A7',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d2'),
#   'InvoiceId': 392,
#   'CustomerId': 4,
#   'InvoiceDate': datetime.datetime(2013, 10, 3, 0, 0),
#   'BillingAddress': 'Ullevålsveien 14',
#   'BillingCity': 'Oslo',
#   'BillingState': None,
#   'BillingCountry': 'Norway',
#   'BillingPostalCode': '0171',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d3'),
#   'InvoiceId': 393,
#   'CustomerId': 6,
#   'InvoiceDate': datetime.datetime(2013, 10, 3, 0, 0),
#   'BillingAddress': 'Rilská 3174/6',
#   'BillingCity': 'Prague',
#   'BillingState': None,
#   'BillingCountry': 'Czech Republic',
#   'BillingPostalCode': '14300',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d4'),
#   'InvoiceId': 394,
#   'CustomerId': 8,
#   'InvoiceDate': datetime.datetime(2013, 10, 4, 0, 0),
#   'BillingAddress': 'Grétrystraat 63',
#   'BillingCity': 'Brussels',
#   'BillingState': None,
#   'BillingCountry': 'Belgium',
#   'BillingPostalCode': '1000',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d5'),
#   'InvoiceId': 395,
#   'CustomerId': 12,
#   'InvoiceDate': datetime.datetime(2013, 10, 5, 0, 0),
#   'BillingAddress': 'Praça Pio X, 119',
#   'BillingCity': 'Rio de Janeiro',
#   'BillingState': 'RJ',
#   'BillingCountry': 'Brazil',
#   'BillingPostalCode': '20040-020',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d6'),
#   'InvoiceId': 396,
#   'CustomerId': 18,
#   'InvoiceDate': datetime.datetime(2013, 10, 8, 0, 0),
#   'BillingAddress': '627 Broadway',
#   'BillingCity': 'New York',
#   'BillingState': 'NY',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '10012-2612',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d7'),
#   'InvoiceId': 397,
#   'CustomerId': 27,
#   'InvoiceDate': datetime.datetime(2013, 10, 13, 0, 0),
#   'BillingAddress': '1033 N Park Ave',
#   'BillingCity': 'Tucson',
#   'BillingState': 'AZ',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '85719',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d8'),
#   'InvoiceId': 398,
#   'CustomerId': 41,
#   'InvoiceDate': datetime.datetime(2013, 10, 21, 0, 0),
#   'BillingAddress': '11, Place Bellecour',
#   'BillingCity': 'Lyon',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '69002',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3d9'),
#   'InvoiceId': 399,
#   'CustomerId': 42,
#   'InvoiceDate': datetime.datetime(2013, 11, 3, 0, 0),
#   'BillingAddress': '9, Place Louis Barthou',
#   'BillingCity': 'Bordeaux',
#   'BillingState': None,
#   'BillingCountry': 'France',
#   'BillingPostalCode': '33000',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3da'),
#   'InvoiceId': 400,
#   'CustomerId': 44,
#   'InvoiceDate': datetime.datetime(2013, 11, 3, 0, 0),
#   'BillingAddress': 'Porthaninkatu 9',
#   'BillingCity': 'Helsinki',
#   'BillingState': None,
#   'BillingCountry': 'Finland',
#   'BillingPostalCode': '00530',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3db'),
#   'InvoiceId': 401,
#   'CustomerId': 46,
#   'InvoiceDate': datetime.datetime(2013, 11, 4, 0, 0),
#   'BillingAddress': '3 Chatham Street',
#   'BillingCity': 'Dublin',
#   'BillingState': 'Dublin',
#   'BillingCountry': 'Ireland',
#   'BillingPostalCode': None,
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3dc'),
#   'InvoiceId': 402,
#   'CustomerId': 50,
#   'InvoiceDate': datetime.datetime(2013, 11, 5, 0, 0),
#   'BillingAddress': 'C/ San Bernardo 85',
#   'BillingCity': 'Madrid',
#   'BillingState': None,
#   'BillingCountry': 'Spain',
#   'BillingPostalCode': '28015',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3dd'),
#   'InvoiceId': 403,
#   'CustomerId': 56,
#   'InvoiceDate': datetime.datetime(2013, 11, 8, 0, 0),
#   'BillingAddress': '307 Macacha Güemes',
#   'BillingCity': 'Buenos Aires',
#   'BillingState': None,
#   'BillingCountry': 'Argentina',
#   'BillingPostalCode': '1106',
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3de'),
#   'InvoiceId': 404,
#   'CustomerId': 6,
#   'InvoiceDate': datetime.datetime(2013, 11, 13, 0, 0),
#   'BillingAddress': 'Rilská 3174/6',
#   'BillingCity': 'Prague',
#   'BillingState': None,
#   'BillingCountry': 'Czech Republic',
#   'BillingPostalCode': '14300',
#   'Total': 25.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3df'),
#   'InvoiceId': 405,
#   'CustomerId': 20,
#   'InvoiceDate': datetime.datetime(2013, 11, 21, 0, 0),
#   'BillingAddress': '541 Del Medio Avenue',
#   'BillingCity': 'Mountain View',
#   'BillingState': 'CA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '94040-111',
#   'Total': 0.99},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3e0'),
#   'InvoiceId': 406,
#   'CustomerId': 21,
#   'InvoiceDate': datetime.datetime(2013, 12, 4, 0, 0),
#   'BillingAddress': '801 W 4th Street',
#   'BillingCity': 'Reno',
#   'BillingState': 'NV',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '89503',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3e1'),
#   'InvoiceId': 407,
#   'CustomerId': 23,
#   'InvoiceDate': datetime.datetime(2013, 12, 4, 0, 0),
#   'BillingAddress': '69 Salem Street',
#   'BillingCity': 'Boston',
#   'BillingState': 'MA',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '2113',
#   'Total': 1.98},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3e2'),
#   'InvoiceId': 408,
#   'CustomerId': 25,
#   'InvoiceDate': datetime.datetime(2013, 12, 5, 0, 0),
#   'BillingAddress': '319 N. Frances Street',
#   'BillingCity': 'Madison',
#   'BillingState': 'WI',
#   'BillingCountry': 'USA',
#   'BillingPostalCode': '53703',
#   'Total': 3.96},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3e3'),
#   'InvoiceId': 409,
#   'CustomerId': 29,
#   'InvoiceDate': datetime.datetime(2013, 12, 6, 0, 0),
#   'BillingAddress': '796 Dundas Street West',
#   'BillingCity': 'Toronto',
#   'BillingState': 'ON',
#   'BillingCountry': 'Canada',
#   'BillingPostalCode': 'M6J 1V1',
#   'Total': 5.94},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3e4'),
#   'InvoiceId': 410,
#   'CustomerId': 35,
#   'InvoiceDate': datetime.datetime(2013, 12, 9, 0, 0),
#   'BillingAddress': 'Rua dos Campeões Europeus de Viena, 4350',
#   'BillingCity': 'Porto',
#   'BillingState': None,
#   'BillingCountry': 'Portugal',
#   'BillingPostalCode': None,
#   'Total': 8.91},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3e5'),
#   'InvoiceId': 411,
#   'CustomerId': 44,
#   'InvoiceDate': datetime.datetime(2013, 12, 14, 0, 0),
#   'BillingAddress': 'Porthaninkatu 9',
#   'BillingCity': 'Helsinki',
#   'BillingState': None,
#   'BillingCountry': 'Finland',
#   'BillingPostalCode': '00530',
#   'Total': 13.86},
#  {'_id': ObjectId('6081e178d46ebf23e5ecf3e6'),
#   'InvoiceId': 412,
#   'CustomerId': 58,
#   'InvoiceDate': datetime.datetime(2013, 12, 22, 0, 0),
#   'BillingAddress': '12,Community Centre',
#   'BillingCity': 'Delhi',
#   'BillingState': None,
#   'BillingCountry': 'India',
#   'BillingPostalCode': '110017',
#   'Total': 1.99}]

# %%
db.list_collection_names()
# Out:
# ['invoices', 'customers']

# %%
db = client.chinook

# %%
# Install pymongo
# !pip install pymongo

# %%
#first import libraries
import pymongo
from pymongo import MongoClient
import psycopg2 as pg
import pandas as pd, numpy as np

# %%
client = MongoClient('localhost', 27017)
# client = MongoClient('mongodb://localhost:27017/')

# %%
db = client.test_database
# db = client['test-database']

# %%
database_name = 'chinook'
db = client[database_name]

# %%
import os
#here we retirive the databse password which is stored as an environment variable
#best practice not to save passwords as plaintext in notebooks
#(we can also create env variables for port, database, user, and sslmode)
password = os.getenv('POSTGRES_PASSWORD')

# %%
conn = pg.connect(
    host="localhost",
    port="5433",
    database= database_name,
    user="postgres",
    password=password,
    sslmode="disable")
query = """SELECT * FROM "Customer" """ 
customer = pd.read_sql_query(query, conn)
query = """SELECT * FROM "Invoice" """ 
invoice = pd.read_sql_query(query, conn)

# %%
# table_df = customer
# documents = []
# for i in table_df.index:
#      documents.append(customer.iloc[i].to_dict())
# collection = customers
# collection.insert_many(documents)
# customers
cols
first_row = customer.iloc[0]
for col in cols:
    if type(first_row[col]) == np.int64:
        print(type(np.long(first_row[col])))
##InvalidDocument: cannot encode object: 1, of type: <class 'numpy.int64'>
# Out:
# <class 'int'>
# <class 'int'>

# %%
def df_to_mongo_collection(table_df):
    docs = []
    df_cols = [s for s in table_df.columns]
    for i in table_df.index:
        doc = {}
        for col in df_cols:
            #Mongo does not recognize np.int64
            #here we convert to n.long which is a valid type for Mongo
            #ideally, we should create a dict with numpy types 
            #which aren't recogniable in Mongo and their Mongo equivalent
            if type(table_df.iloc[i][col]) == np.int64:
                doc[col] = np.long(table_df.iloc[i][col])
            else:
                doc[col] = table_df.iloc[i][col]
        docs.append(doc)
    return docs

# %%
def convert_and_insert_df_as_collection(db, table_df, new_collection_name):
    if not db and table_df and new_collection_name:
        raise Exception('''One of the parameters you've entered are of type None''')
    collection = db[new_collection_name]
    docs = df_to_mongo_collection(table_df)
    collection.insert_many(docs)
    
customers = db.invoices
customers.drop()
invoices = db.invoices
invoices.drop()
convert_and_insert_df_as_collection(db, customer, 'customers')
convert_and_insert_df_as_collection(db, invoice, 'invoices')
# [s for s in invoice.columns]

# %%
len([s for s in db['invoices'].find()])
print([s for s in db['invoices'].find()])
# Out:
# [{'_id': ObjectId('6081e17ad46ebf23e5ecf423'), 'InvoiceId': 1, 'CustomerId': 2, 'InvoiceDate': datetime.datetime(2009, 1, 1, 0, 0), 'BillingAddress': 'Theodor-Heuss-Straße 34', 'BillingCity': 'Stuttgart', 'BillingState': None, 'BillingCountry': 'Germany', 'BillingPostalCode': '70174', 'Total': 1.98}, {'_id': ObjectId('6081e17ad46ebf23e5ecf424'), 'InvoiceId': 2, 'CustomerId': 4, 'InvoiceDate': datetime.datetime(2009, 1, 2, 0, 0), 'BillingAddress': 'Ullevålsveien 14', 'BillingCity': 'Oslo', 'BillingState': None, 'BillingCountry': 'Norway', 'BillingPostalCode': '0171', 'Total': 3.96}, {'_id': ObjectId('6081e17ad46ebf23e5ecf425'), 'InvoiceId': 3, 'CustomerId': 8, 'InvoiceDate': datetime.datetime(2009, 1, 3, 0, 0), 'BillingAddress': 'Grétrystraat 63', 'BillingCity': 'Brussels', 'BillingState': None, 'BillingCountry': 'Belgium', 'BillingPostalCode': '1000', 'Total': 5.94}, {'_id': ObjectId('6081e17ad46ebf23e5ecf426'), 'InvoiceId': 4, 'CustomerId': 14, 'InvoiceDate': datetime.datetime(2009, 1, 6, 0, 0), 'BillingAddress': '8210 111 ST NW', 'BillingCity': 'Edmonton', 'BillingState': 'AB', 'BillingCountry': 'Canada', 'BillingPostalCode': 'T6G 2C7', 'Total': 8.91}, {'_id': ObjectId('6081e17ad46ebf23e5ecf427'), 'InvoiceId': 5, 'CustomerId': 23, 'InvoiceDate': datetime.datetime(2009, 1, 11, 0, 0), 'BillingAddress': '69 Salem Street', 'BillingCity': 'Boston', 'BillingState': 'MA', 'BillingCountry': 'USA', 'BillingPostalCode': '2113', 'Total': 13.86}, {'_id': ObjectId('6081e17ad46ebf23e5ecf428'), 'InvoiceId': 6, 'CustomerId': 37, 'InvoiceDate': datetime.datetime(2009, 1, 19, 0, 0), 'BillingAddress': 'Berger Straße 10', 'BillingCity': 'Frankfurt', 'BillingState': None, 'BillingCountry': 'Germany', 'BillingPostalCode': '60316', 'Total': 0.99}, {'_id': ObjectId('6081e17ad46ebf23e5ecf429'), 'InvoiceId': 7, 'CustomerId': 38, 'InvoiceDate': datetime.datetime(2009, 2, 1, 0, 0), 'BillingAddress': 'Barbarossastraße 19', 'BillingCity': 'Berlin', 'BillingState': None, 'BillingCountry': 'Germany', 'BillingPostalCode': '10779', 'Total': 1.98}, {'_id': ObjectId('6081e17ad46ebf23e5ecf42a'), 'InvoiceId': 8, 'CustomerId': 40, 'InvoiceDate': datetime.datetime(2009, 2, 1, 0, 0), 'BillingAddress': '8, Rue Hanovre', 'BillingCity': 'Paris', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '75002', 'Total': 1.98}, {'_id': ObjectId('6081e17ad46ebf23e5ecf42b'), 'InvoiceId': 9, 'CustomerId': 42, 'InvoiceDate': datetime.datetime(2009, 2, 2, 0, 0), 'BillingAddress': '9, Place Louis Barthou', 'BillingCity': 'Bordeaux', 'BillingState': None, 'BillingCountry': 'France', 'BillingPostalCode': '33000', 'Total': 3.96}, {'_id': ObjectId('6081e17ad46ebf23e5ecf42c'), 'InvoiceId': 10, 'CustomerId': 46, 'InvoiceDate': datetime.datetime(2009, 2, 3, 0, 0), 'BillingAddress': '3 Chatham Street', 'BillingCity': 'Dublin', 'BillingState': 'Dublin', 'BillingCountry': 'Ireland', 'BillingPostalCode': None, 'Total': 5.94}, {'_id': ObjectId('6081e17ad46ebf23e5ecf42d'), 'InvoiceId': 11, 'CustomerId': 52, 'InvoiceDate': datetime.datetime(2009, 2, 6, 0, 0), 'BillingAddress': '202 Hoxton Street', 'BillingCity': 'London', 'BillingState': None, 'BillingCountry': 'United Kingdom', 'BillingPostalCode': 'N1 5LH', 'Total': 8.91}, {'_id': ObjectId('6081e17ad46ebf23e5ecf42e'), 'InvoiceId': 12, 'CustomerId': 2, 'InvoiceDate': datetime.datetime(2009, 2, 11, 0, 0), 'BillingAddress': 'Theodor-Heuss-Straße 34', 'BillingCity': 'Stuttgart', 'BillingState': None, 'BillingCountry': 'Germany', 'BillingPostalCode': '70174', 'Total': 13.86}, {'_id': ObjectId('6081e17ad46ebf23e5ecf42f'), 'InvoiceId': 13, 'CustomerId': 16, 'InvoiceDate': datetime.datetime(2009, 2, 19, 0, 0), 'BillingAddress': '1600 Amphitheatre Parkway', 'BillingCity': 'Mountain View', 'BillingState': 'CA', 'BillingCountry': 'USA', 'BillingPostalCode': '94043-1351', 'Total': 0.99}, {'_id': ObjectId('6081e17ad46ebf23e5ecf430'), 'InvoiceId': 14, 'CustomerId': 17, 'InvoiceDate': datetime.datetime(2009, 3, 4, 0, 0), 'BillingAddress': ...
